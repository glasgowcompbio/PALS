# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib
import pickle

sys.path.append('../pals')

# %%
import pandas as pd

# %%
from pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, get_ms1_intensities, get_ms1_peaks, get_formula_df, get_experimental_design
from feature_extraction import DataSource
from pathway_analysis import PALS
from common import *

# %% [markdown]
# # Load data

# %% [markdown]
# Generate token by logging in to PiMP

# %%
# username = 'joewandy' # PiMP username
# password = 'enter' # PiMP password
# host = 'localhost:8000' # server address and port
# token = get_authentication_token(host, username, password)

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id = 1321 # example beer analysis

# %%
int_df_filename = os.path.join(os.getcwd(), 'test_data', 'int_df.p')
try:
    int_df = pd.read_pickle(int_df_filename)
except FileNotFoundError:
    int_df = get_ms1_intensities(token, PIMP_HOST, analysis_id)
    int_df.to_pickle(int_df_filename)

int_df.head()
# Out:
#          Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# row_id
# 3033929        2.235291e+09        2.000478e+09        2.170697e+09
# 3033930        4.433491e+07        4.287387e+07        4.894853e+07
# 3033931        1.723985e+09        1.764235e+09        1.585143e+09
# 3033932        6.254237e+08        6.503417e+08        5.914975e+08
# 3033933        1.075022e+09        9.293474e+08        1.092635e+09
#
#          Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# row_id
# 3033929        2.242760e+09        2.279882e+09        1.959480e+09
# 3033930        4.760448e+07        4.217280e+07        3.908452e+07
# 3033931        1.543961e+09        1.579320e+09        1.555666e+09
# 3033932        4.635929e+08        4.298382e+08        4.038747e+08
# 3033933        1.130720e+09        1.118146e+09        1.192834e+09
#
#          Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# row_id
# 3033929        2.079356e+09        2.110473e+09        2.243653e+09
# 3033930        3.825778e+07        3.770192e+07        4.087189e+07
# 3033931        1.698130e+09        1.481824e+09        1.508645e+09
# 3033932        4.292837e+08        3.708761e+08        4.778932e+08
# 3033933        1.231442e+09        1.262046e+09        1.460653e+09
#
#          Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# row_id
# 3033929        1.817065e+09        1.746443e+09        1.779827e+09
# 3033930        3.330477e+07        3.153630e+07        3.102410e+07
# 3033931        1.642510e+09        1.723919e+09        1.697806e+09
# 3033932        3.903165e+08        4.080995e+08        4.309892e+08
# 3033933        1.009838e+09        9.085111e+08        9.967176e+08

# %%
formula_df_filename = os.path.join(os.getcwd(), 'test_data', 'formula_df.p')
try:
    formula_df = pd.read_pickle(formula_df_filename)
except FileNotFoundError:
    formula_df = get_formula_df(token, PIMP_HOST, analysis_id, database_name, polarity='positive')
    formula_df.to_pickle(formula_df_filename)

formula_df.head()
# Out:
#         entity_id
# row_id
# 3033929    C00148
# 3036581    C00148
# 3036855    C00148
# 3038249    C00148
# 3033929    C00163

# %%
experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
try:
    experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
    with open(experimental_design_filename, 'rb') as f:
        experimental_design = pickle.load(f)
except FileNotFoundError:
    experimental_design = get_experimental_design(token, PIMP_HOST, analysis_id)
    with open(experimental_design_filename, 'wb') as f:
        pickle.dump(experimental_design, f)
        
experimental_design
# Out:
# {'comparisons': [{'case': 'beer1', 'control': 'beer2', 'name': 'beer1/beer2'},
#   {'case': 'beer3', 'control': 'beer4', 'name': 'beer3/beer4'}],
#  'groups': {'beer4': ['Beer_4_full3.mzXML',
#    'Beer_4_full2.mzXML',
#    'Beer_4_full1.mzXML'],
#   'beer3': ['Beer_3_full3.mzXML', 'Beer_3_full2.mzXML', 'Beer_3_full1.mzXML'],
#   'beer2': ['Beer_2_full3.mzXML', 'Beer_2_full1.mzXML', 'Beer_2_full2.mzXML'],
#   'beer1': ['Beer_1_full2.mzXML', 'Beer_1_full1.mzXML', 'Beer_1_full3.mzXML']}}

# %% [markdown]
# # PALS analysis using KEGG database exported from PiMP

# %%
ds = DataSource(int_df, formula_df, experimental_design, DATABASE_PIMP_KEGG)
# Out:
# 2019-11-01 10:41:33.418 | DEBUG    | feature_extraction:__init__:42 - Loading C:\Users\joewa\Work\git\PALS\pals\data\PiMP_KEGG.json

# %%
pals = PALS(ds, min_replace=5000, num_resamples=500)
pathway_df = pals.get_pathway_df(resample=True)
# Out:
# 2019-11-01 10:41:34.474 | DEBUG    | pathway_analysis:_change_zero_peak_ints:243 - Setting the zero intensity values in the dataframe
# 2019-11-01 10:41:34.504 | DEBUG    | pathway_analysis:_standardize_intensity_df:217 - Scaling the data across the sample: zero mean and unit variance
# 2019-11-01 10:41:34.510 | DEBUG    | pathway_analysis:_standardize_intensity_df:229 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-11-01 10:41:34.511 | DEBUG    | pathway_analysis:_standardize_intensity_df:230 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2019-11-01 10:41:35.622 | INFO     | pathway_analysis:set_up_resample_plage_p_df:69 - Calculating plage p-values with resampling
# 2019-11-01 10:41:35.623 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:73 - Comparison beer1/beer2
# 2019-11-01 10:41:35.623 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 0/500
# 2019-11-01 10:41:35.721 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 100/500
# 2019-11-01 10:41:35.814 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 200/500
# 2019-11-01 10:41:35.910 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 300/500
# 2019-11-01 10:41:36.007 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 400/500
# 2019-11-01 10:41:36.108 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:87 - Total time 0
# 2019-11-01 10:41:36.262 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:73 - Comparison beer3/beer4
# 2019-11-01 10:41:36.263 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 0/500
# ../pals\pathway_analysis.py:308: RuntimeWarning: invalid value encountered in true_divide
#   tvalues = (m1 - m2) / se_total
# 2019-11-01 10:41:36.375 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 100/500
# 2019-11-01 10:41:36.474 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 200/500
# 2019-11-01 10:41:36.576 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 300/500
# 2019-11-01 10:41:36.678 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 400/500
# 2019-11-01 10:41:36.779 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:87 - Total time 0
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# 2019-11-01 10:41:36.905 | INFO     | pathway_analysis:_calculate_coverage_df:328 - Calculating dataset formula coverage
# 2019-11-01 10:41:36.908 | INFO     | pathway_analysis:calculate_hg_values:148 - Calculating the hyper-geometric p-values
# 2019-11-01 10:41:37.071 | INFO     | pathway_analysis:calculate_hg_values:180 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                             pw_name  beer1/beer2 p-value  \
# map04960  Aldosterone-regulated sodium reabsorption             0.076472
# map00073       Cutin, suberine and wax biosynthesis             0.562182
# map00984                        Steroid degradation             0.104815
# map04970                         Salivary secretion             0.096035
# map00908                        Zeatin biosynthesis             0.244191
# ...                                             ...                  ...
# map00440     Phosphonate and phosphinate metabolism             0.632006
# map00340                       Histidine metabolism             0.881671
# map04974           Protein digestion and absorption             0.041403
# map04726                       Serotonergic synapse             0.223791
# map00642                   Ethylbenzene degradation             0.107059
#
#           beer3/beer4 p-value  unq_pw_F  tot_ds_F  F_coverage            sf  \
# map04960             0.740572         6         2       33.33  1.893178e-01
# map00073             0.015700        18        12       66.67  2.114165e-05
# map00984             1.000000        12         3       25.00  3.253097e-01
# map04970             0.240913        16         2       12.50  7.662196e-01
# map00908             0.115535        30         5       16.67  7.206403e-01
# ...                       ...       ...       ...         ...           ...
# map00440             1.000000        44         4        9.09  9.836618e-01
# map00340             0.090063        41        20       48.78  6.556217e-05
# map04974             0.021765        42        25       59.52  6.038427e-08
# map04726             0.508238        20        10       50.00  2.384251e-03
# map00642             0.409716        14         8       57.14  1.739591e-03
#
#           exp_F  Ex_Cov  beer1/beer2 comb_p  beer3/beer4 comb_p
# map04960   1.34   22.33            0.057730            0.677213
# map00073   4.01   22.28            0.257988            0.001789
# map00984   2.67   22.25            0.093577            1.000000
# map04970   3.57   22.31            0.127837            0.292106
# map00908   6.69   22.30            0.286122            0.144646
# ...         ...     ...                 ...                 ...
# map00440   9.81   22.30            0.773232            1.000000
# map00340   9.14   22.29            0.659240            0.019492
# map04974   9.36   22.29            0.003083            0.001275
# map04726   4.46   22.30            0.097110            0.296933
# map00642   3.12   22.29            0.036629            0.212763
#
# [226 rows x 11 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'pathway_df_pimp_kegg.csv')
pathway_df.to_csv(output)

# %% [markdown]
# # PALS analysis using KEGG database exported from Reactome

# %%
ds = DataSource(int_df, formula_df, experimental_design, DATABASE_REACTOME_KEGG, 
                reactome_species=REACTOME_SPECIES_HOMO_SAPIENS, reactome_metabolic_pathway_only=True)
# Out:
# 2019-11-01 10:41:37.529 | DEBUG    | feature_extraction:__init__:42 - Loading C:\Users\joewa\Work\git\PALS\pals\data\reactome\metabolic_pathways\KEGG\Homo sapiens.json.zip

# %%
pals = PALS(ds, min_replace=5000, num_resamples=500)
pathway_df = pals.get_pathway_df(resample=True)
# Out:
# 2019-11-01 10:41:38.527 | DEBUG    | pathway_analysis:_change_zero_peak_ints:243 - Setting the zero intensity values in the dataframe
# 2019-11-01 10:41:38.567 | DEBUG    | pathway_analysis:_standardize_intensity_df:217 - Scaling the data across the sample: zero mean and unit variance
# 2019-11-01 10:41:38.573 | DEBUG    | pathway_analysis:_standardize_intensity_df:229 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-11-01 10:41:38.574 | DEBUG    | pathway_analysis:_standardize_intensity_df:230 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2019-11-01 10:41:39.210 | INFO     | pathway_analysis:set_up_resample_plage_p_df:69 - Calculating plage p-values with resampling
# 2019-11-01 10:41:39.211 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:73 - Comparison beer1/beer2
# 2019-11-01 10:41:39.211 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 0/500
# 2019-11-01 10:41:39.309 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 100/500
# 2019-11-01 10:41:39.410 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 200/500
# 2019-11-01 10:41:39.504 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 300/500
# 2019-11-01 10:41:39.605 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 400/500
# 2019-11-01 10:41:39.710 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:87 - Total time 0
# 2019-11-01 10:41:39.807 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:73 - Comparison beer3/beer4
# 2019-11-01 10:41:39.808 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 0/500
# 2019-11-01 10:41:39.904 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 100/500
# 2019-11-01 10:41:40.008 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 200/500
# 2019-11-01 10:41:40.111 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 300/500
# 2019-11-01 10:41:40.210 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 400/500
# 2019-11-01 10:41:40.302 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:87 - Total time 0
# 2019-11-01 10:41:40.453 | INFO     | pathway_analysis:_calculate_coverage_df:328 - Calculating dataset formula coverage
# 2019-11-01 10:41:40.458 | INFO     | pathway_analysis:calculate_hg_values:148 - Calculating the hyper-geometric p-values
# 2019-11-01 10:41:40.575 | INFO     | pathway_analysis:calculate_hg_values:180 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                                          pw_name  \
# R-HSA-8849175                               Threonine catabolism
# R-HSA-1660662                       Glycosphingolipid metabolism
# R-HSA-74217                                       Purine salvage
# R-HSA-1855167         Synthesis of pyrophosphates in the cytosol
# R-HSA-141333   Biogenic amines are oxidatively deaminated to ...
# ...                                                          ...
# R-HSA-2408499            Formation of selenosugars for excretion
# R-HSA-1237112                         Methionine salvage pathway
# R-HSA-6814848                     Glycerophospholipid catabolism
# R-HSA-196807                               Nicotinate metabolism
# R-HSA-975634                   Retinoid metabolism and transport
#
#                beer1/beer2 p-value  beer3/beer4 p-value  unq_pw_F  tot_ds_F  \
# R-HSA-8849175             1.000000             0.078801        10         1
# R-HSA-1660662             0.083410             0.291544        10         1
# R-HSA-74217               0.145503             0.015719        27        13
# R-HSA-1855167             0.336771             0.098248         7         1
# R-HSA-141333              0.393340             0.143729        11         5
# ...                            ...                  ...       ...       ...
# R-HSA-2408499             0.241030             0.016758         4         1
# R-HSA-1237112             0.373375             0.132532         9         2
# R-HSA-6814848             0.157409             1.000000         2         1
# R-HSA-196807              0.404487             0.088461        17         3
# R-HSA-975634              1.000000             0.129110        10         1
#
#                F_coverage        sf  exp_F  Ex_Cov  beer1/beer2 comb_p  \
# R-HSA-8849175       10.00  0.915664   3.21   32.10            1.000000
# R-HSA-1660662       10.00  0.915664   3.21   32.10            0.138807
# R-HSA-74217         48.15  0.030998   8.66   32.07            0.080543
# R-HSA-1855167       14.29  0.786975   2.25   32.14            0.398587
# R-HSA-141333        45.45  0.149815   3.53   32.09            0.319611
# ...                   ...       ...    ...     ...                 ...
# R-HSA-2408499       25.00  0.515172   1.28   32.00            0.247657
# R-HSA-1237112       22.22  0.674184   2.89   32.11            0.409780
# R-HSA-6814848       50.00  0.242187   0.64   32.00            0.130764
# R-HSA-196807        17.65  0.883992   5.46   32.12            0.498938
# R-HSA-975634        10.00  0.915664   3.21   32.10            1.000000
#
#                beer3/beer4 comb_p
# R-HSA-8849175            0.132256
# R-HSA-1660662            0.394246
# R-HSA-74217              0.006649
# R-HSA-1855167            0.133410
# R-HSA-141333             0.106295
# ...                           ...
# R-HSA-2408499            0.018896
# R-HSA-1237112            0.157614
# R-HSA-6814848            1.000000
# R-HSA-196807             0.137928
# R-HSA-975634             0.200818
#
# [160 rows x 11 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'pathway_df_reactome_kegg.csv')
pathway_df.to_csv(output)
