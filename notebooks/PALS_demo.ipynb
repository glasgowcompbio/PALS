# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib
import pickle

sys.path.append('../pals')

# %%
import pandas as pd

# %%
from pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, get_ms1_intensities, get_ms1_peaks, get_formula_df, get_experimental_design
from feature_extraction import DataSource
from pathway_analysis import PALS
from common import *

# %% [markdown]
# # Load data

# %% [markdown]
# Generate token by logging in to PiMP

# %%
# username = 'joewandy' # PiMP username
# password = 'enter' # PiMP password
# host = 'localhost:8000' # server address and port
# token = get_authentication_token(host, username, password)

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id = 1321 # example beer analysis

# %%
int_df_filename = os.path.join(os.getcwd(), 'test_data', 'int_df.p')
try:
    int_df = pd.read_pickle(int_df_filename)
except FileNotFoundError:
    int_df = get_ms1_intensities(token, PIMP_HOST, analysis_id)
    int_df.to_pickle(int_df_filename)

int_df.head()
# Out:
#          Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# row_id
# 3033929        2.235291e+09        2.000478e+09        2.170697e+09
# 3033930        4.433491e+07        4.287387e+07        4.894853e+07
# 3033931        1.723985e+09        1.764235e+09        1.585143e+09
# 3033932        6.254237e+08        6.503417e+08        5.914975e+08
# 3033933        1.075022e+09        9.293474e+08        1.092635e+09
#
#          Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# row_id
# 3033929        2.242760e+09        2.279882e+09        1.959480e+09
# 3033930        4.760448e+07        4.217280e+07        3.908452e+07
# 3033931        1.543961e+09        1.579320e+09        1.555666e+09
# 3033932        4.635929e+08        4.298382e+08        4.038747e+08
# 3033933        1.130720e+09        1.118146e+09        1.192834e+09
#
#          Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# row_id
# 3033929        2.079356e+09        2.110473e+09        2.243653e+09
# 3033930        3.825778e+07        3.770192e+07        4.087189e+07
# 3033931        1.698130e+09        1.481824e+09        1.508645e+09
# 3033932        4.292837e+08        3.708761e+08        4.778932e+08
# 3033933        1.231442e+09        1.262046e+09        1.460653e+09
#
#          Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# row_id
# 3033929        1.817065e+09        1.746443e+09        1.779827e+09
# 3033930        3.330477e+07        3.153630e+07        3.102410e+07
# 3033931        1.642510e+09        1.723919e+09        1.697806e+09
# 3033932        3.903165e+08        4.080995e+08        4.309892e+08
# 3033933        1.009838e+09        9.085111e+08        9.967176e+08

# %%
formula_df_filename = os.path.join(os.getcwd(), 'test_data', 'formula_df.p')
try:
    formula_df = pd.read_pickle(formula_df_filename)
except FileNotFoundError:
    formula_df = get_formula_df(token, PIMP_HOST, analysis_id, database_name, polarity='positive')
    formula_df.to_pickle(formula_df_filename)

formula_df.head()
# Out:
#         entity_id
# row_id
# 3033929    C00148
# 3036581    C00148
# 3036855    C00148
# 3038249    C00148
# 3033929    C00163

# %%
experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
try:
    experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
    with open(experimental_design_filename, 'rb') as f:
        experimental_design = pickle.load(f)
except FileNotFoundError:
    experimental_design = get_experimental_design(token, PIMP_HOST, analysis_id)
    with open(experimental_design_filename, 'wb') as f:
        pickle.dump(experimental_design, f)
        
experimental_design
# Out:
# {'comparisons': [{'case': 'beer1', 'control': 'beer2', 'name': 'beer1/beer2'},
#   {'case': 'beer3', 'control': 'beer4', 'name': 'beer3/beer4'}],
#  'groups': {'beer4': ['Beer_4_full3.mzXML',
#    'Beer_4_full2.mzXML',
#    'Beer_4_full1.mzXML'],
#   'beer3': ['Beer_3_full3.mzXML', 'Beer_3_full2.mzXML', 'Beer_3_full1.mzXML'],
#   'beer2': ['Beer_2_full3.mzXML', 'Beer_2_full1.mzXML', 'Beer_2_full2.mzXML'],
#   'beer1': ['Beer_1_full2.mzXML', 'Beer_1_full1.mzXML', 'Beer_1_full3.mzXML']}}

# %% [markdown]
# # PALS analysis using KEGG database exported from PiMP

# %%
ds = DataSource(int_df, formula_df, experimental_design, DATABASE_PIMP_KEGG)
# Out:
# 2019-11-05 15:23:08.548 | DEBUG    | feature_extraction:__init__:33 - Loading C:\Users\joewa\Work\git\PALS\pals\data\PiMP_KEGG.json.zip

# %%
pals = PALS(ds, min_replace=5000)
pathway_df = pals.get_pathway_df()
# Out:
# 2019-11-05 15:23:10.528 | DEBUG    | pathway_analysis:_change_zero_peak_ints:248 - Setting the zero intensity values in the dataframe
# 2019-11-05 15:23:10.563 | DEBUG    | pathway_analysis:_standardize_intensity_df:228 - Scaling the data across the sample: zero mean and unit variance
# 2019-11-05 15:23:10.567 | DEBUG    | pathway_analysis:get_plage_activity_df:67 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-11-05 15:23:10.568 | DEBUG    | pathway_analysis:get_plage_activity_df:68 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2019-11-05 15:23:11.651 | INFO     | pathway_analysis:set_up_resample_plage_p_df:79 - Calculating plage p-values with resampling
# 2019-11-05 15:23:11.652 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:83 - Comparison beer1/beer2
# 2019-11-05 15:23:11.653 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 0/1000
# 2019-11-05 15:23:11.746 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 100/1000
# 2019-11-05 15:23:11.839 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 200/1000
# 2019-11-05 15:23:11.932 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 300/1000
# 2019-11-05 15:23:12.030 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 400/1000
# 2019-11-05 15:23:12.129 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 500/1000
# 2019-11-05 15:23:12.247 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 600/1000
# 2019-11-05 15:23:12.362 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 700/1000
# 2019-11-05 15:23:12.487 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 800/1000
# 2019-11-05 15:23:12.588 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 900/1000
# 2019-11-05 15:23:12.682 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:97 - Total time 1
# 2019-11-05 15:23:12.835 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:83 - Comparison beer3/beer4
# 2019-11-05 15:23:12.836 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 0/1000
# ../pals\pathway_analysis.py:313: RuntimeWarning: invalid value encountered in true_divide
#   tvalues = (m1 - m2) / se_total
# 2019-11-05 15:23:12.937 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 100/1000
# 2019-11-05 15:23:13.034 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 200/1000
# 2019-11-05 15:23:13.133 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 300/1000
# 2019-11-05 15:23:13.228 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 400/1000
# 2019-11-05 15:23:13.324 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 500/1000
# 2019-11-05 15:23:13.419 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 600/1000
# 2019-11-05 15:23:13.512 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 700/1000
# 2019-11-05 15:23:13.607 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 800/1000
# 2019-11-05 15:23:13.698 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 900/1000
# 2019-11-05 15:23:13.792 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:97 - Total time 0
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# 2019-11-05 15:23:13.949 | INFO     | pathway_analysis:_calculate_coverage_df:333 - Calculating dataset formula coverage
# 2019-11-05 15:23:13.953 | INFO     | pathway_analysis:calculate_hg_values:158 - Calculating the hyper-geometric p-values
# 2019-11-05 15:23:14.113 | INFO     | pathway_analysis:calculate_hg_values:190 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                            pw_name  beer1/beer2 p-value  \
# map00903           Limonene and pinene degradation             1.000000
# map00040  Pentose and glucuronate interconversions             0.142520
# map00590               Arachidonic acid metabolism             0.143525
# map00061                   Fatty acid biosynthesis             0.173073
# map00943                 Isoflavonoid biosynthesis             0.134400
# ...                                            ...                  ...
# map02010                          ABC transporters             0.109829
# map00440    Phosphonate and phosphinate metabolism             0.608104
# map05146                                Amoebiasis             0.038655
# map00983           Drug metabolism - other enzymes             0.415817
# map00930                   Caprolactam degradation             0.999320
#
#           beer3/beer4 p-value  unq_pw_F  tot_ds_F  F_coverage            sf  \
# map00903             0.036342        17         7       41.18  2.999476e-02
# map00040             1.000000        23        14       60.87  2.439305e-05
# map00590             0.259994        19        10       52.63  1.416461e-03
# map00061             0.386406        10         7       70.00  5.053093e-04
# map00943             0.048090        31         4       12.90  8.726532e-01
# ...                       ...       ...       ...         ...           ...
# map02010             0.054413        79        39       49.37  3.120709e-08
# map00440             1.000000        44         4        9.09  9.836618e-01
# map05146             0.050819         8         2       25.00  3.236155e-01
# map00983             0.452513        38         3        7.89  9.850392e-01
# map00930             0.059205        19         8       42.11  1.981745e-02
#
#           exp_F  Ex_Cov  PiMP_KEGG beer1/beer2  comb_p  \
# map00903   3.79   22.29                       1.000000
# map00040   5.13   22.30                       0.032533
# map00590   4.23   22.26                       0.051613
# map00061   2.23   22.30                       0.058378
# map00943   6.91   22.29                       0.194625
# ...         ...     ...                            ...
# map02010  17.61   22.29                       0.011758
# map00440   9.81   22.30                       0.754262
# map05146   1.78   22.25                       0.034231
# map00983   8.47   22.29                       0.586018
# map00930   4.23   22.26                       0.996901
#
#           PiMP_KEGG beer3/beer4  comb_p
# map00903                       0.016634
# map00040                       1.000000
# map00590                       0.111928
# map00061                       0.176747
# map00943                       0.079569
# ...                                 ...
# map02010                       0.004223
# map00440                       1.000000
# map05146                       0.045045
# map00983                       0.621261
# map00930                       0.026515
#
# [226 rows x 11 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'pathway_df_pimp_kegg.csv')
pathway_df.to_csv(output)

# %% [markdown]
# # PALS analysis using KEGG database exported from Reactome

# %%
ds = DataSource(int_df, formula_df, experimental_design, DATABASE_REACTOME_KEGG, 
                reactome_species=REACTOME_SPECIES_HOMO_SAPIENS, reactome_metabolic_pathway_only=True)
# Out:
# 2019-11-05 15:23:23.472 | DEBUG    | feature_extraction:__init__:41 - Loading ../pals\data\reactome\metabolic_pathways\COMPOUND\Homo sapiens.json.zip

# %%
pals = PALS(ds, min_replace=5000)
pathway_df = pals.get_pathway_df()
# Out:
# 2019-11-05 15:23:25.168 | DEBUG    | pathway_analysis:_change_zero_peak_ints:248 - Setting the zero intensity values in the dataframe
# 2019-11-05 15:23:25.199 | DEBUG    | pathway_analysis:_standardize_intensity_df:228 - Scaling the data across the sample: zero mean and unit variance
# 2019-11-05 15:23:25.205 | DEBUG    | pathway_analysis:get_plage_activity_df:67 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-11-05 15:23:25.206 | DEBUG    | pathway_analysis:get_plage_activity_df:68 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2019-11-05 15:23:25.824 | INFO     | pathway_analysis:set_up_resample_plage_p_df:79 - Calculating plage p-values with resampling
# 2019-11-05 15:23:25.825 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:83 - Comparison beer1/beer2
# 2019-11-05 15:23:25.825 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 0/1000
# 2019-11-05 15:23:25.931 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 100/1000
# 2019-11-05 15:23:26.026 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 200/1000
# 2019-11-05 15:23:26.121 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 300/1000
# 2019-11-05 15:23:26.213 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 400/1000
# 2019-11-05 15:23:26.306 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 500/1000
# 2019-11-05 15:23:26.402 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 600/1000
# 2019-11-05 15:23:26.504 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 700/1000
# 2019-11-05 15:23:26.598 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 800/1000
# 2019-11-05 15:23:26.694 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 900/1000
# 2019-11-05 15:23:26.794 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:97 - Total time 0
# 2019-11-05 15:23:26.918 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:83 - Comparison beer3/beer4
# 2019-11-05 15:23:26.919 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 0/1000
# 2019-11-05 15:23:27.023 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 100/1000
# 2019-11-05 15:23:27.124 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 200/1000
# 2019-11-05 15:23:27.218 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 300/1000
# 2019-11-05 15:23:27.314 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 400/1000
# 2019-11-05 15:23:27.404 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 500/1000
# 2019-11-05 15:23:27.497 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 600/1000
# 2019-11-05 15:23:27.591 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 700/1000
# 2019-11-05 15:23:27.681 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 800/1000
# 2019-11-05 15:23:27.772 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 900/1000
# 2019-11-05 15:23:27.868 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:97 - Total time 0
# 2019-11-05 15:23:28.032 | INFO     | pathway_analysis:_calculate_coverage_df:333 - Calculating dataset formula coverage
# 2019-11-05 15:23:28.034 | INFO     | pathway_analysis:calculate_hg_values:158 - Calculating the hyper-geometric p-values
# 2019-11-05 15:23:28.161 | INFO     | pathway_analysis:calculate_hg_values:190 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                                          pw_name  \
# R-HSA-1614558           Degradation of cysteine and homocysteine
# R-HSA-70614    Amino acid synthesis and interconversion (tran...
# R-HSA-434316   Fatty Acids bound to GPR40 (FFAR1) regulate in...
# R-HSA-389599                        Alpha-oxidation of phytanate
# R-HSA-141334                   PAOs oxidise polyamines to amines
# ...                                                          ...
# R-HSA-71336                            Pentose phosphate pathway
# R-HSA-2022928                                HS-GAG biosynthesis
# R-HSA-947581                    Molybdenum cofactor biosynthesis
# R-HSA-1483152                                  Hydrolysis of LPE
# R-HSA-2408550  Metabolism of ingested H2SeO4 and H2SeO3 into ...
#
#                beer1/beer2 p-value  beer3/beer4 p-value  unq_pw_F  tot_ds_F  \
# R-HSA-1614558             0.095154             0.130615        14         3
# R-HSA-70614               0.056865             0.035311        33        13
# R-HSA-434316              0.905603             0.230810         6         2
# R-HSA-389599              0.929793             0.131441        13         2
# R-HSA-141334              1.000000             0.929363         7         1
# ...                            ...                  ...       ...       ...
# R-HSA-71336               0.048790             0.124670        17         3
# R-HSA-2022928             0.684306             0.101420         7         1
# R-HSA-947581              0.048064             0.080705        12         2
# R-HSA-1483152             0.182512             1.000000         2         1
# R-HSA-2408550             0.408389             0.024774        10         2
#
#                F_coverage        sf  exp_F  Ex_Cov  \
# R-HSA-1614558       21.43  0.806371   4.73   33.79
# R-HSA-70614         39.39  0.219808  11.15   33.79
# R-HSA-434316        33.33  0.439733   2.03   33.83
# R-HSA-389599        15.38  0.905116   4.39   33.77
# R-HSA-141334        14.29  0.815076   2.36   33.71
# ...                   ...       ...    ...     ...
# R-HSA-71336         17.65  0.910559   5.74   33.76
# R-HSA-2022928       14.29  0.815076   2.36   33.71
# R-HSA-947581        16.67  0.872928   4.05   33.75
# R-HSA-1483152       50.00  0.264649   0.68   34.00
# R-HSA-2408550       20.00  0.779264   3.38   33.80
#
#                COMPOUND beer1/beer2  comb_p  COMPOUND beer3/beer4  comb_p
# R-HSA-1614558                      0.132496                      0.175639
# R-HSA-70614                        0.044331                      0.027155
# R-HSA-434316                       0.895966                      0.226138
# R-HSA-389599                       0.955696                      0.200258
# R-HSA-141334                       1.000000                      0.947208
# ...                                     ...                           ...
# R-HSA-71336                        0.086772                      0.193255
# R-HSA-2022928                      0.740966                      0.141658
# R-HSA-947581                       0.079570                      0.125172
# R-HSA-1483152                      0.155861                      1.000000
# R-HSA-2408550                      0.469615                      0.037969
#
# [167 rows x 11 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'pathway_df_reactome_kegg.csv')
pathway_df.to_csv(output)

# %% [markdown]
# # PALS analysis by connecting to local Reactome

# %%
ds = DataSource(int_df, formula_df, experimental_design, DATABASE_REACTOME_KEGG, 
                reactome_species=REACTOME_SPECIES_HOMO_SAPIENS, reactome_metabolic_pathway_only=True, reactome_query=True)
# Out:
# 2019-11-05 15:23:55.201 | DEBUG    | feature_extraction:__init__:45 - Retrieving data for Homo sapiens from Reactome COMPOUND

# %%
pals = PALS(ds, min_replace=5000)
pathway_df = pals.get_pathway_df()
# Out:
# 2019-11-05 15:24:03.752 | DEBUG    | pathway_analysis:_change_zero_peak_ints:248 - Setting the zero intensity values in the dataframe
# 2019-11-05 15:24:03.779 | DEBUG    | pathway_analysis:_standardize_intensity_df:228 - Scaling the data across the sample: zero mean and unit variance
# 2019-11-05 15:24:03.784 | DEBUG    | pathway_analysis:get_plage_activity_df:67 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-11-05 15:24:03.785 | DEBUG    | pathway_analysis:get_plage_activity_df:68 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2019-11-05 15:24:04.403 | INFO     | pathway_analysis:set_up_resample_plage_p_df:79 - Calculating plage p-values with resampling
# 2019-11-05 15:24:04.403 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:83 - Comparison beer1/beer2
# 2019-11-05 15:24:04.404 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 0/1000
# 2019-11-05 15:24:04.498 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 100/1000
# 2019-11-05 15:24:04.606 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 200/1000
# 2019-11-05 15:24:04.715 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 300/1000
# 2019-11-05 15:24:04.814 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 400/1000
# 2019-11-05 15:24:04.911 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 500/1000
# 2019-11-05 15:24:05.011 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 600/1000
# 2019-11-05 15:24:05.102 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 700/1000
# 2019-11-05 15:24:05.191 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 800/1000
# 2019-11-05 15:24:05.282 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 900/1000
# 2019-11-05 15:24:05.375 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:97 - Total time 0
# 2019-11-05 15:24:05.503 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:83 - Comparison beer3/beer4
# 2019-11-05 15:24:05.503 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 0/1000
# 2019-11-05 15:24:05.610 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 100/1000
# 2019-11-05 15:24:05.725 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 200/1000
# 2019-11-05 15:24:05.840 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 300/1000
# 2019-11-05 15:24:05.950 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 400/1000
# 2019-11-05 15:24:06.046 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 500/1000
# 2019-11-05 15:24:06.155 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 600/1000
# 2019-11-05 15:24:06.256 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 700/1000
# 2019-11-05 15:24:06.358 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 800/1000
# 2019-11-05 15:24:06.460 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:91 - Resampling 900/1000
# 2019-11-05 15:24:06.553 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:97 - Total time 1
# 2019-11-05 15:24:06.743 | INFO     | pathway_analysis:_calculate_coverage_df:333 - Calculating dataset formula coverage
# 2019-11-05 15:24:06.746 | INFO     | pathway_analysis:calculate_hg_values:158 - Calculating the hyper-geometric p-values
# 2019-11-05 15:24:06.895 | INFO     | pathway_analysis:calculate_hg_values:190 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                                          pw_name  \
# R-HSA-1614558           Degradation of cysteine and homocysteine
# R-HSA-70614    Amino acid synthesis and interconversion (tran...
# R-HSA-434316   Fatty Acids bound to GPR40 (FFAR1) regulate in...
# R-HSA-389599                        Alpha-oxidation of phytanate
# R-HSA-141334                   PAOs oxidise polyamines to amines
# ...                                                          ...
# R-HSA-71336                            Pentose phosphate pathway
# R-HSA-2022928                                HS-GAG biosynthesis
# R-HSA-947581                    Molybdenum cofactor biosynthesis
# R-HSA-1483152                                  Hydrolysis of LPE
# R-HSA-2408550  Metabolism of ingested H2SeO4 and H2SeO3 into ...
#
#                beer1/beer2 p-value  beer3/beer4 p-value  unq_pw_F  tot_ds_F  \
# R-HSA-1614558             0.087371             0.129187        14         3
# R-HSA-70614               0.051624             0.033859        33        13
# R-HSA-434316              0.895040             0.231183         6         2
# R-HSA-389599              0.928261             0.125975        13         2
# R-HSA-141334              1.000000             0.917867         7         1
# ...                            ...                  ...       ...       ...
# R-HSA-71336               0.045889             0.119614        17         3
# R-HSA-2022928             0.665729             0.097737         7         1
# R-HSA-947581              0.045176             0.078174        12         2
# R-HSA-1483152             0.170216             1.000000         2         1
# R-HSA-2408550             0.389669             0.024697        10         2
#
#                F_coverage        sf  exp_F  Ex_Cov  \
# R-HSA-1614558       21.43  0.806371   4.73   33.79
# R-HSA-70614         39.39  0.219808  11.15   33.79
# R-HSA-434316        33.33  0.439733   2.03   33.83
# R-HSA-389599        15.38  0.905116   4.39   33.77
# R-HSA-141334        14.29  0.815076   2.36   33.71
# ...                   ...       ...    ...     ...
# R-HSA-71336         17.65  0.910559   5.74   33.76
# R-HSA-2022928       14.29  0.815076   2.36   33.71
# R-HSA-947581        16.67  0.872928   4.05   33.75
# R-HSA-1483152       50.00  0.264649   0.68   34.00
# R-HSA-2408550       20.00  0.779264   3.38   33.80
#
#                COMPOUND beer1/beer2  comb_p  COMPOUND beer3/beer4  comb_p
# R-HSA-1614558                      0.122779                      0.173934
# R-HSA-70614                        0.040125                      0.026010
# R-HSA-434316                       0.884871                      0.226500
# R-HSA-389599                       0.954649                      0.193185
# R-HSA-141334                       1.000000                      0.938186
# ...                                     ...                           ...
# R-HSA-71336                        0.082305                      0.186615
# R-HSA-2022928                      0.724314                      0.137077
# R-HSA-947581                       0.075356                      0.121747
# R-HSA-1483152                      0.144989                      1.000000
# R-HSA-2408550                      0.450742                      0.037862
#
# [167 rows x 11 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'pathway_df_reactome_query_kegg.csv')
pathway_df.to_csv(output)
