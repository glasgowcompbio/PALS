# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib
import pickle

sys.path.append('../pals')

# %%
import pandas as pd

# %%
from pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, get_ms1_intensities, get_ms1_peaks, get_formula_df, get_experimental_design
from feature_extraction import DataSource
from pathway_analysis import PALS
from common import *

# %% [markdown]
# # Load data

# %% [markdown]
# Generate token by logging in to PiMP

# %%
# username = 'joewandy' # PiMP username
# password = 'enter' # PiMP password
# host = 'localhost:8000' # server address and port
# token = get_authentication_token(host, username, password)

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id = 1321 # example beer analysis

# %%
int_df_filename = os.path.join(os.getcwd(), 'test_data', 'int_df.p')
try:
    int_df = pd.read_pickle(int_df_filename)
except FileNotFoundError:
    int_df = get_ms1_intensities(token, PIMP_HOST, analysis_id)
    int_df.to_pickle(int_df_filename)

int_df.head()
# Out:
#          Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# row_id
# 3033929        2.235291e+09        2.000478e+09        2.170697e+09
# 3033930        4.433491e+07        4.287387e+07        4.894853e+07
# 3033931        1.723985e+09        1.764235e+09        1.585143e+09
# 3033932        6.254237e+08        6.503417e+08        5.914975e+08
# 3033933        1.075022e+09        9.293474e+08        1.092635e+09
#
#          Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# row_id
# 3033929        2.242760e+09        2.279882e+09        1.959480e+09
# 3033930        4.760448e+07        4.217280e+07        3.908452e+07
# 3033931        1.543961e+09        1.579320e+09        1.555666e+09
# 3033932        4.635929e+08        4.298382e+08        4.038747e+08
# 3033933        1.130720e+09        1.118146e+09        1.192834e+09
#
#          Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# row_id
# 3033929        2.079356e+09        2.110473e+09        2.243653e+09
# 3033930        3.825778e+07        3.770192e+07        4.087189e+07
# 3033931        1.698130e+09        1.481824e+09        1.508645e+09
# 3033932        4.292837e+08        3.708761e+08        4.778932e+08
# 3033933        1.231442e+09        1.262046e+09        1.460653e+09
#
#          Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# row_id
# 3033929        1.817065e+09        1.746443e+09        1.779827e+09
# 3033930        3.330477e+07        3.153630e+07        3.102410e+07
# 3033931        1.642510e+09        1.723919e+09        1.697806e+09
# 3033932        3.903165e+08        4.080995e+08        4.309892e+08
# 3033933        1.009838e+09        9.085111e+08        9.967176e+08

# %%
formula_df_filename = os.path.join(os.getcwd(), 'test_data', 'formula_df.p')
try:
    formula_df = pd.read_pickle(formula_df_filename)
except FileNotFoundError:
    formula_df = get_formula_df(token, PIMP_HOST, analysis_id, database_name, polarity='positive')
    formula_df.to_pickle(formula_df_filename)

formula_df.head()
# Out:
#         entity_id
# row_id
# 3033929    C00148
# 3036581    C00148
# 3036855    C00148
# 3038249    C00148
# 3033929    C00163

# %%
experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
try:
    experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
    with open(experimental_design_filename, 'rb') as f:
        experimental_design = pickle.load(f)
except FileNotFoundError:
    experimental_design = get_experimental_design(token, PIMP_HOST, analysis_id)
    with open(experimental_design_filename, 'wb') as f:
        pickle.dump(experimental_design, f)
        
experimental_design
# Out:
# {'comparisons': [{'case': 'beer1', 'control': 'beer2', 'name': 'beer1/beer2'},
#   {'case': 'beer3', 'control': 'beer4', 'name': 'beer3/beer4'}],
#  'groups': {'beer4': ['Beer_4_full3.mzXML',
#    'Beer_4_full2.mzXML',
#    'Beer_4_full1.mzXML'],
#   'beer3': ['Beer_3_full3.mzXML', 'Beer_3_full2.mzXML', 'Beer_3_full1.mzXML'],
#   'beer2': ['Beer_2_full3.mzXML', 'Beer_2_full1.mzXML', 'Beer_2_full2.mzXML'],
#   'beer1': ['Beer_1_full2.mzXML', 'Beer_1_full1.mzXML', 'Beer_1_full3.mzXML']}}

# %% [markdown]
# # PALS analysis using KEGG database exported from PiMP

# %%
ds = DataSource(int_df, formula_df, experimental_design, DATABASE_PIMP_KEGG)
# Out:
# 2019-11-01 16:34:32.948 | DEBUG    | feature_extraction:__init__:38 - Loading C:\Users\joewa\Work\git\PALS\pals\data\PiMP_KEGG.json.zip

# %%
pals = PALS(ds, min_replace=5000)
pathway_df = pals.get_pathway_df()
# Out:
# 2019-11-01 16:34:33.941 | DEBUG    | pathway_analysis:_change_zero_peak_ints:243 - Setting the zero intensity values in the dataframe
# 2019-11-01 16:34:33.969 | DEBUG    | pathway_analysis:_standardize_intensity_df:217 - Scaling the data across the sample: zero mean and unit variance
# 2019-11-01 16:34:33.975 | DEBUG    | pathway_analysis:_standardize_intensity_df:229 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-11-01 16:34:33.976 | DEBUG    | pathway_analysis:_standardize_intensity_df:230 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2019-11-01 16:34:35.138 | INFO     | pathway_analysis:set_up_resample_plage_p_df:69 - Calculating plage p-values with resampling
# 2019-11-01 16:34:35.138 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:73 - Comparison beer1/beer2
# 2019-11-01 16:34:35.139 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 0/1000
# 2019-11-01 16:34:35.238 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 100/1000
# 2019-11-01 16:34:35.333 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 200/1000
# 2019-11-01 16:34:35.432 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 300/1000
# 2019-11-01 16:34:35.524 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 400/1000
# 2019-11-01 16:34:35.625 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 500/1000
# 2019-11-01 16:34:35.722 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 600/1000
# 2019-11-01 16:34:35.817 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 700/1000
# 2019-11-01 16:34:35.916 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 800/1000
# 2019-11-01 16:34:36.008 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 900/1000
# 2019-11-01 16:34:36.100 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:87 - Total time 0
# 2019-11-01 16:34:36.272 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:73 - Comparison beer3/beer4
# 2019-11-01 16:34:36.273 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 0/1000
# ../pals\pathway_analysis.py:308: RuntimeWarning: invalid value encountered in true_divide
#   tvalues = (m1 - m2) / se_total
# 2019-11-01 16:34:36.375 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 100/1000
# 2019-11-01 16:34:36.469 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 200/1000
# 2019-11-01 16:34:36.564 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 300/1000
# 2019-11-01 16:34:36.660 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 400/1000
# 2019-11-01 16:34:36.756 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 500/1000
# 2019-11-01 16:34:36.857 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 600/1000
# 2019-11-01 16:34:36.957 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 700/1000
# 2019-11-01 16:34:37.049 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 800/1000
# 2019-11-01 16:34:37.142 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 900/1000
# 2019-11-01 16:34:37.236 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:87 - Total time 0
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# 2019-11-01 16:34:37.382 | INFO     | pathway_analysis:_calculate_coverage_df:328 - Calculating dataset formula coverage
# 2019-11-01 16:34:37.385 | INFO     | pathway_analysis:calculate_hg_values:148 - Calculating the hyper-geometric p-values
# 2019-11-01 16:34:37.563 | INFO     | pathway_analysis:calculate_hg_values:180 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                                     pw_name  \
# map00960  Tropane, piperidine and pyridine alkaloid bios...
# map04977                   Vitamin digestion and absorption
# map00625          Chloroalkane and chloroalkene degradation
# map00010                       Glycolysis / Gluconeogenesis
# map00550                         Peptidoglycan biosynthesis
# ...                                                     ...
# map07217                Renin-angiotensin system inhibitors
# map01057        Biosynthesis of type II polyketide products
# map07227      Histamine H2/H3 receptor agonists/antagonists
# map00944                  Flavone and flavonol biosynthesis
# map00254                             Aflatoxin biosynthesis
#
#           beer1/beer2 p-value  beer3/beer4 p-value  unq_pw_F  tot_ds_F  \
# map00960             0.224350             0.032757        51        25
# map04977             0.074429             0.020100        30         6
# map00625             0.158972             0.159610        32         4
# map00010             0.840771             0.041923        20         5
# map00550             0.181969             0.023358        26         5
# ...                       ...                  ...       ...       ...
# map07217             0.188659             0.999734         2         1
# map01057             0.799221             0.059428       102         3
# map07227             1.000000             0.208634        10         1
# map00944             1.000000             0.039060        33         9
# map00254             1.000000             1.000000        24         3
#
#           F_coverage        sf  exp_F  Ex_Cov  beer1/beer2 comb_p  \
# map00960       49.02  0.000009  11.37   22.29            0.056491
# map04977       20.00  0.554894   6.69   22.30            0.082497
# map00625       12.50  0.889609   7.13   22.28            0.229904
# map00010       25.00  0.319348   4.46   22.30            0.812239
# map00550       19.23  0.578747   5.79   22.27            0.197304
# ...              ...       ...    ...     ...                 ...
# map07217       50.00  0.126786   0.45   22.50            0.137942
# map01057        2.94  1.000000  22.73   22.28            0.971730
# map07227       10.00  0.741182   2.23   22.30            1.000000
# map00944       27.27  0.208761   7.36   22.30            1.000000
# map00254       12.50  0.841854   5.35   22.29            1.000000
#
#           beer3/beer4 comb_p
# map00960            0.004048
# map04977            0.023585
# map00625            0.230688
# map00010            0.036944
# map00550            0.027985
# ...                      ...
# map07217            0.999245
# map01057            0.328155
# map07227            0.251897
# map00944            0.029615
# map00254            1.000000
#
# [226 rows x 11 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'pathway_df_pimp_kegg.csv')
pathway_df.to_csv(output)

# %% [markdown]
# # PALS analysis using KEGG database exported from Reactome

# %%
ds = DataSource(int_df, formula_df, experimental_design, DATABASE_REACTOME_KEGG, 
                reactome_species=REACTOME_SPECIES_HOMO_SAPIENS, reactome_metabolic_pathway_only=True)
# Out:
# 2019-11-01 16:34:38.004 | DEBUG    | feature_extraction:__init__:38 - Loading C:\Users\joewa\Work\git\PALS\pals\data\reactome\metabolic_pathways\COMPOUND\Homo sapiens.json.zip

# %%
pals = PALS(ds, min_replace=5000)
pathway_df = pals.get_pathway_df()
# Out:
# 2019-11-01 16:34:39.045 | DEBUG    | pathway_analysis:_change_zero_peak_ints:243 - Setting the zero intensity values in the dataframe
# 2019-11-01 16:34:39.073 | DEBUG    | pathway_analysis:_standardize_intensity_df:217 - Scaling the data across the sample: zero mean and unit variance
# 2019-11-01 16:34:39.079 | DEBUG    | pathway_analysis:_standardize_intensity_df:229 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-11-01 16:34:39.080 | DEBUG    | pathway_analysis:_standardize_intensity_df:230 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2019-11-01 16:34:39.697 | INFO     | pathway_analysis:set_up_resample_plage_p_df:69 - Calculating plage p-values with resampling
# 2019-11-01 16:34:39.698 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:73 - Comparison beer1/beer2
# 2019-11-01 16:34:39.699 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 0/1000
# 2019-11-01 16:34:39.804 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 100/1000
# 2019-11-01 16:34:39.900 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 200/1000
# 2019-11-01 16:34:39.995 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 300/1000
# 2019-11-01 16:34:40.091 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 400/1000
# 2019-11-01 16:34:40.190 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 500/1000
# 2019-11-01 16:34:40.300 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 600/1000
# 2019-11-01 16:34:40.396 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 700/1000
# 2019-11-01 16:34:40.492 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 800/1000
# 2019-11-01 16:34:40.589 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 900/1000
# 2019-11-01 16:34:40.689 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:87 - Total time 0
# 2019-11-01 16:34:40.834 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:73 - Comparison beer3/beer4
# 2019-11-01 16:34:40.835 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 0/1000
# 2019-11-01 16:34:40.934 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 100/1000
# 2019-11-01 16:34:41.027 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 200/1000
# 2019-11-01 16:34:41.125 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 300/1000
# 2019-11-01 16:34:41.228 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 400/1000
# 2019-11-01 16:34:41.330 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 500/1000
# 2019-11-01 16:34:41.424 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 600/1000
# 2019-11-01 16:34:41.519 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 700/1000
# 2019-11-01 16:34:41.617 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 800/1000
# 2019-11-01 16:34:41.717 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 900/1000
# 2019-11-01 16:34:41.808 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:87 - Total time 0
# 2019-11-01 16:34:41.963 | INFO     | pathway_analysis:_calculate_coverage_df:328 - Calculating dataset formula coverage
# 2019-11-01 16:34:41.966 | INFO     | pathway_analysis:calculate_hg_values:148 - Calculating the hyper-geometric p-values
# 2019-11-01 16:34:42.083 | INFO     | pathway_analysis:calculate_hg_values:180 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                                          pw_name  \
# R-HSA-400042   Adrenaline,noradrenaline inhibits insulin secr...
# R-HSA-75896                             Plasmalogen biosynthesis
# R-HSA-209931                Serotonin and melatonin biosynthesis
# R-HSA-389661       Glyoxylate metabolism and glycine degradation
# R-HSA-211981                                         Xenobiotics
# ...                                                          ...
# R-HSA-1483152                                  Hydrolysis of LPE
# R-HSA-140180                                       COX reactions
# R-HSA-71032                             Propionyl-CoA catabolism
# R-HSA-156581                                         Methylation
# R-HSA-9018896           Biosynthesis of E-series 18(S)-resolvins
#
#                beer1/beer2 p-value  beer3/beer4 p-value  unq_pw_F  tot_ds_F  \
# R-HSA-400042              0.102443             0.123733         4         2
# R-HSA-75896               1.000000             0.121155         7         1
# R-HSA-209931              1.000000             0.200388        14         4
# R-HSA-389661              0.060927             0.154972        20         3
# R-HSA-211981              0.259071             0.092699        20         2
# ...                            ...                  ...       ...       ...
# R-HSA-1483152             0.169778             1.000000         2         1
# R-HSA-140180              0.297507             0.153609         4         1
# R-HSA-71032               0.300065             0.092031         6         1
# R-HSA-156581              0.063400             0.047066        25         5
# R-HSA-9018896             0.231273             0.012800        10         1
#
#                F_coverage        sf  exp_F  Ex_Cov  beer1/beer2 comb_p  \
# R-HSA-400042        50.00  0.215222   1.35   33.75            0.081093
# R-HSA-75896         14.29  0.815076   2.36   33.71            1.000000
# R-HSA-209931        28.57  0.613379   4.73   33.79            1.000000
# R-HSA-389661        15.00  0.961907   6.76   33.80            0.121156
# R-HSA-211981        10.00  0.990138   6.76   33.80            0.429986
# ...                   ...       ...    ...     ...                 ...
# R-HSA-1483152       50.00  0.264649   0.68   34.00            0.144602
# R-HSA-140180        25.00  0.548821   1.35   33.75            0.309523
# R-HSA-71032         16.67  0.747290   2.03   33.83            0.350703
# R-HSA-156581        20.00  0.924829   8.45   33.80            0.112161
# R-HSA-9018896       10.00  0.931926   3.38   33.80            0.334280
#
#                beer3/beer4 comb_p
# R-HSA-400042             0.098753
# R-HSA-75896              0.165859
# R-HSA-209931             0.221419
# R-HSA-389661             0.258539
# R-HSA-211981             0.200077
# ...                           ...
# R-HSA-1483152            1.000000
# R-HSA-140180             0.164238
# R-HSA-71032              0.120609
# R-HSA-156581             0.087008
# R-HSA-9018896            0.028940
#
# [167 rows x 11 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'pathway_df_reactome_kegg.csv')
pathway_df.to_csv(output)
