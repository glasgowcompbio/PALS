# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib
import pickle

sys.path.append('../pals')

# %%
import pandas as pd

# %%
from pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, get_ms1_intensities, get_ms1_peaks, get_formula_df, get_experimental_design
from feature_extraction import DataSource
from pathway_analysis import PALS

# %% [markdown]
# # Load data

# %%
database_name = 'kegg'

# %% [markdown]
# Generate token by logging in to PiMP

# %%
# username = 'joewandy' # PiMP username
# password = 'enter' # PiMP password
# host = 'localhost:8000' # server address and port
# token = get_authentication_token(host, username, password)

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id = 1321 # example beer analysis

# %%
int_df_filename = os.path.join(os.getcwd(), 'test_data', 'int_df.p')
try:
    int_df = pd.read_pickle(int_df_filename)
except FileNotFoundError:
    int_df = get_ms1_intensities(token, PIMP_HOST, analysis_id)
    int_df.to_pickle(int_df_filename)

int_df.head()
# Out:
#          Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# 3033929        2.235291e+09        2.000478e+09        2.170697e+09
# 3033930        4.433491e+07        4.287387e+07        4.894853e+07
# 3033931        1.723985e+09        1.764235e+09        1.585143e+09
# 3033932        6.254237e+08        6.503417e+08        5.914975e+08
# 3033933        1.075022e+09        9.293474e+08        1.092635e+09
#
#          Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# 3033929        2.242760e+09        2.279882e+09        1.959480e+09
# 3033930        4.760448e+07        4.217280e+07        3.908452e+07
# 3033931        1.543961e+09        1.579320e+09        1.555666e+09
# 3033932        4.635929e+08        4.298382e+08        4.038747e+08
# 3033933        1.130720e+09        1.118146e+09        1.192834e+09
#
#          Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# 3033929        2.079356e+09        2.110473e+09        2.243653e+09
# 3033930        3.825778e+07        3.770192e+07        4.087189e+07
# 3033931        1.698130e+09        1.481824e+09        1.508645e+09
# 3033932        4.292837e+08        3.708761e+08        4.778932e+08
# 3033933        1.231442e+09        1.262046e+09        1.460653e+09
#
#          Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# 3033929        1.817065e+09        1.746443e+09        1.779827e+09
# 3033930        3.330477e+07        3.153630e+07        3.102410e+07
# 3033931        1.642510e+09        1.723919e+09        1.697806e+09
# 3033932        3.903165e+08        4.080995e+08        4.309892e+08
# 3033933        1.009838e+09        9.085111e+08        9.967176e+08

# %%
formula_df_filename = os.path.join(os.getcwd(), 'test_data', 'formula_df.p')
try:
    formula_df = pd.read_pickle(formula_df_filename)
except FileNotFoundError:
    formula_df = get_formula_df(token, PIMP_HOST, analysis_id, database_name, polarity='positive')
    formula_df.to_pickle(formula_df_filename)

formula_df.head()
# Out:
#          sec_id        mass          rt  polarity  cmpd_id  formula   adduct  \
# pid
# 3033929       1  116.070550  577.986827  positive        2  C5H9NO2      M+H
# 3036581    2653  157.097190  469.781817  positive        2  C5H9NO2  M+ACN+H
# 3036855    2927  157.097154  569.557760  positive        2  C5H9NO2  M+ACN+H
# 3033929       1  116.070550  577.986827  positive        3   C3H6O2  M+ACN+H
# 3033929       1  116.070550  577.986827  positive        5  C5H9NO2      M+H
#
#          identified     rc_id             compound    db identifier  \
# pid
# 3033929        True  15367697            L-Proline  kegg     C00148
# 3036581        True  15390527            L-Proline  kegg     C00148
# 3036855        True  15392569            L-Proline  kegg     C00148
# 3033929        True  15367700           Propanoate  kegg     C00163
# 3033929        True  15367704  3-Acetamidopropanal  kegg     C18170
#
#                                                frank_annot  \
# pid
# 3033929  {'frank_cmpd_name': 'L-Proline', 'inchikey': N...
# 3036581                                               None
# 3036855                                               None
# 3033929  {'frank_cmpd_name': 'L-Proline', 'inchikey': N...
# 3033929  {'frank_cmpd_name': 'L-Proline', 'inchikey': N...
#
#                             inchikey
# pid
# 3033929  ONIBWKKTOPOVIA-BYPYZUCNSA-N
# 3036581  ONIBWKKTOPOVIA-BYPYZUCNSA-N
# 3036855  ONIBWKKTOPOVIA-BYPYZUCNSA-N
# 3033929  XBDQKXXYIPTUBI-UHFFFAOYSA-N
# 3033929  ARJPPNFIEQKVBB-UHFFFAOYSA-N

# %%
experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
try:
    experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
    with open(experimental_design_filename, 'rb') as f:
        experimental_design = pickle.load(f)
except FileNotFoundError:
    experimental_design = get_experimental_design(token, PIMP_HOST, analysis_id)
    with open(experimental_design_filename, 'wb') as f:
        pickle.dump(experimental_design, f)
        
experimental_design
# Out:
# {'comparisons': [{'case': 'beer1', 'control': 'beer2', 'name': 'beer1/beer2'},
#   {'case': 'beer3', 'control': 'beer4', 'name': 'beer3/beer4'}],
#  'groups': {'beer4': ['Beer_4_full3.mzXML',
#    'Beer_4_full2.mzXML',
#    'Beer_4_full1.mzXML'],
#   'beer3': ['Beer_3_full3.mzXML', 'Beer_3_full2.mzXML', 'Beer_3_full1.mzXML'],
#   'beer2': ['Beer_2_full3.mzXML', 'Beer_2_full1.mzXML', 'Beer_2_full2.mzXML'],
#   'beer1': ['Beer_1_full2.mzXML', 'Beer_1_full1.mzXML', 'Beer_1_full3.mzXML']}}

# %% [markdown]
# # Set-up KEGG Data Source

# %%
ds = DataSource(int_df, formula_df, experimental_design, database_name)
# Out:
# 2019-10-29 16:04:03.734 | DEBUG    | feature_extraction:__init__:24 - Loading C:\Users\joewa\Work\git\PALS\pals\data\kegg.json

# %% [markdown]
# We pick a particular pathway map00730 for checking

# %%
mapid = 'map00730'

# %%
ds.pathway_dict[mapid]
# Out:
# 'Thiamine metabolism'

# %%
len(ds.pathway_cmpd_dict[mapid]), sorted(ds.pathway_cmpd_dict[mapid])
# Out:
# (26,
#  ['1-Deoxy-D-xylulose 5-phosphate',
#   '2-Methyl-4-amino-5-hydroxymethylpyrimidine diphosphate',
#   '4-Amino-2-methyl-5-phosphomethylpyrimidine',
#   '4-Amino-5-hydroxymethyl-2-methylpyrimidine',
#   '4-Methyl-5-(2-phosphoethyl)-thiazole',
#   '5-(2-Hydroxyethyl)-4-methylthiazole',
#   'Aminoimidazole ribotide',
#   'C15810',
#   'C15813',
#   'C15814',
#   'C15815',
#   'D-Glyceraldehyde 3-phosphate',
#   'Glycine',
#   'Heteropyrithiamine',
#   'Iminoglycine',
#   'L-Cysteine',
#   'L-Tyrosine',
#   'Pyruvate',
#   'Thiamin diphosphate',
#   'Thiamin monophosphate',
#   'Thiamin triphosphate',
#   'Thiamine',
#   'Thiamine acetic acid',
#   'Thiamine aldehyde',
#   '[Enzyme]-S-sulfanylcysteine',
#   '[Enzyme]-cysteine'])

# %%
len(ds.pw_cmpd_id_dict[mapid]), ds.pw_cmpd_id_dict[mapid]
# Out:
# (20,
#  ['C00022',
#   'C00068',
#   'C00118',
#   'C00037',
#   'C00082',
#   'C03373',
#   'C00097',
#   'C00378',
#   'C01081',
#   'C01279',
#   'C02691',
#   'C02892',
#   'C03028',
#   'C04294',
#   'C04327',
#   'C04556',
#   'C04752',
#   'C05856',
#   'C11437',
#   'C15809'])

# %%
len(ds.pw_cmpd_formula_dict[mapid]), sorted(ds.pw_cmpd_formula_dict[mapid])
# Out:
# (20,
#  ['C11H13N4',
#   'C12H15N4O2S',
#   'C12H15N4OS',
#   'C12H17N4OS',
#   'C12H18N4O4PS',
#   'C12H19N4O7P2S',
#   'C12H20N4O10P3S',
#   'C2H3NO2',
#   'C2H5NO2',
#   'C3H4O3',
#   'C3H7NO2S',
#   'C3H7O6P',
#   'C5H11O7P',
#   'C6H10N3O4P',
#   'C6H10NO4PS',
#   'C6H11N3O7P2',
#   'C6H9N3O',
#   'C6H9NOS',
#   'C8H14N3O7P',
#   'C9H11NO3'])

# %% [markdown]
# Found 6 here

# %%
ds.get_ds_pw_compounds([mapid])
# Out:
# [6]

# %% [markdown]
# But in PiMP, we only found 4
# ```
# From PiMP
# Assigned formulas 4
# Total formulas 20
#
# cid	Name				Formula		pid
# C00022	Puryvate			C3H4O3		66, 4595
# C11437	1-Deoxy-D-xylulose-5-phosphate	C5H11O7P	758, 1109, 5208, 5209
# C03373	Aminoimadazole ribotide		C8H14N3O7P	2307
# C00082	L-Tyrosine			C9H11NO3	143
# ```

# %% [markdown]
# Here are the 6 formulas we found

# %%
ds.pw_cmpd_formula_dict[mapid].intersection(ds.ds_formulas)
# Out:
# {'C11H13N4', 'C3H4O3', 'C3H7O6P', 'C5H11O7P', 'C8H14N3O7P', 'C9H11NO3'}

# %% [markdown]
# And their corresponding peaks

# %%
pd.set_option('display.max_rows', 500)

# %%
pids = ds.ds_pathways_peak_ids[mapid]
pids
# Out:
# [3033994,
#  3036235,
#  3034686,
#  3035037,
#  3035414,
#  3035634,
#  3034071,
#  3034508,
#  3035214,
#  3035622,
#  3035754,
#  3035904,
#  3036017,
#  3037535]

# %%
sorted(ds.pw_cmpd_formula_dict[mapid].intersection(formula_df.loc[pids]['formula'].unique()))
# Out:
# ['C11H13N4', 'C3H4O3', 'C3H7O6P', 'C5H11O7P', 'C8H14N3O7P', 'C9H11NO3']

# %% [markdown]
# Here are the peaks annotated as the 4 found formulas

# %%
formula_df[formula_df['formula'].isin(['C3H4O3', 'C5H11O7P', 'C8H14N3O7P', 'C9H11NO3'])].sort_values('formula')
# Out:
#          sec_id        mass           rt  polarity  cmpd_id     formula  \
# pid
# 3033994      66  130.049887   483.560944  positive      641      C3H4O3
# 3033994      66  130.049887   483.560944  positive      642      C3H4O3
# 3033994      66  130.049887   483.560944  positive      650      C3H4O3
# 3033994      66  130.049887   483.560944  positive      652      C3H4O3
# 3035037    1109  256.058814  1255.710347  positive     5511    C5H11O7P
# 3034686     758  256.057793   422.286094  positive     5514    C5H11O7P
# 3035037    1109  256.058814  1255.710347  positive     5514    C5H11O7P
# 3034686     758  256.057793   422.286094  positive     5525    C5H11O7P
# 3035037    1109  256.058814  1255.710347  positive     5525    C5H11O7P
# 3034686     758  256.057793   422.286094  positive     5526    C5H11O7P
# 3034686     758  256.057793   422.286094  positive     5511    C5H11O7P
# 3035037    1109  256.058814  1255.710347  positive     5526    C5H11O7P
# 3036235    2307  296.064245   475.548971  positive     2549  C8H14N3O7P
# 3034071     143  182.081183   585.617818  positive    16209    C9H11NO3
# 3035214    1286  223.107648   509.695119  positive     1145    C9H11NO3
# 3035622    1694  223.107691   345.283112  positive     1145    C9H11NO3
# 3035754    1826  182.081181   413.128792  positive     1145    C9H11NO3
# 3035904    1976  182.081188   491.918228  positive     1145    C9H11NO3
# 3036017    2089  182.081206   393.028575  positive     1145    C9H11NO3
# 3037535    3607  223.107660   773.807393  positive     1145    C9H11NO3
# 3034071     143  182.081183   585.617818  positive     1146    C9H11NO3
# 3034508     580  182.081165   430.915716  positive     1146    C9H11NO3
# 3035214    1286  223.107648   509.695119  positive     1146    C9H11NO3
# 3035754    1826  182.081181   413.128792  positive     1146    C9H11NO3
# 3035904    1976  182.081188   491.918228  positive     1146    C9H11NO3
# 3036017    2089  182.081206   393.028575  positive     1146    C9H11NO3
# 3037535    3607  223.107660   773.807393  positive     1146    C9H11NO3
# 3034508     580  182.081165   430.915716  positive     1145    C9H11NO3
# 3035904    1976  182.081188   491.918228  positive    16370    C9H11NO3
# 3035754    1826  182.081181   413.128792  positive    16360    C9H11NO3
# 3035622    1694  223.107691   345.283112  positive    16353    C9H11NO3
# 3035214    1286  223.107648   509.695119  positive    16318    C9H11NO3
# 3034508     580  182.081165   430.915716  positive    16262    C9H11NO3
# 3035622    1694  223.107691   345.283112  positive     1146    C9H11NO3
# 3034071     143  182.081183   585.617818  positive     1145    C9H11NO3
# 3036017    2089  182.081206   393.028575  positive     1144    C9H11NO3
# 3036017    2089  182.081206   393.028575  positive    16379    C9H11NO3
# 3034071     143  182.081183   585.617818  positive     1139    C9H11NO3
# 3034508     580  182.081165   430.915716  positive     1139    C9H11NO3
# 3035214    1286  223.107648   509.695119  positive     1139    C9H11NO3
# 3035622    1694  223.107691   345.283112  positive     1139    C9H11NO3
# 3035754    1826  182.081181   413.128792  positive     1139    C9H11NO3
# 3035904    1976  182.081188   491.918228  positive     1139    C9H11NO3
# 3036017    2089  182.081206   393.028575  positive     1139    C9H11NO3
# 3037535    3607  223.107660   773.807393  positive     1139    C9H11NO3
# 3034071     143  182.081183   585.617818  positive     1141    C9H11NO3
# 3034508     580  182.081165   430.915716  positive     1141    C9H11NO3
# 3035214    1286  223.107648   509.695119  positive     1141    C9H11NO3
# 3035622    1694  223.107691   345.283112  positive     1141    C9H11NO3
# 3035754    1826  182.081181   413.128792  positive     1141    C9H11NO3
# 3035904    1976  182.081188   491.918228  positive     1141    C9H11NO3
# 3037535    3607  223.107660   773.807393  positive     1144    C9H11NO3
# 3036017    2089  182.081206   393.028575  positive     1141    C9H11NO3
# 3034071     143  182.081183   585.617818  positive     1143    C9H11NO3
# 3034508     580  182.081165   430.915716  positive     1143    C9H11NO3
# 3035214    1286  223.107648   509.695119  positive     1143    C9H11NO3
# 3035622    1694  223.107691   345.283112  positive     1143    C9H11NO3
# 3035754    1826  182.081181   413.128792  positive     1143    C9H11NO3
# 3035904    1976  182.081188   491.918228  positive     1143    C9H11NO3
# 3036017    2089  182.081206   393.028575  positive     1143    C9H11NO3
# 3037535    3607  223.107660   773.807393  positive     1143    C9H11NO3
# 3034071     143  182.081183   585.617818  positive     1144    C9H11NO3
# 3034508     580  182.081165   430.915716  positive     1144    C9H11NO3
# 3035214    1286  223.107648   509.695119  positive     1144    C9H11NO3
# 3035622    1694  223.107691   345.283112  positive     1144    C9H11NO3
# 3035754    1826  182.081181   413.128792  positive     1144    C9H11NO3
# 3035904    1976  182.081188   491.918228  positive     1144    C9H11NO3
# 3037535    3607  223.107660   773.807393  positive     1141    C9H11NO3
# 3037535    3607  223.107660   773.807393  positive    16451    C9H11NO3
#
#           adduct  identified     rc_id                               compound  \
# pid
# 3033994  M+ACN+H        True  15368350                               Pyruvate
# 3033994  M+ACN+H        True  15368353                        3-Oxopropanoate
# 3033994  M+ACN+H        True  15368363                     Ethylene carbonate
# 3033994  M+ACN+H        True  15368365                    3-Hydroxypropenoate
# 3035037  M+ACN+H        True  15375924              5-Deoxyribose-1-phosphate
# 3034686  M+ACN+H        True  15373309         1-Deoxy-D-xylulose 5-phosphate
# 3035037  M+ACN+H        True  15375928         1-Deoxy-D-xylulose 5-phosphate
# 3034686  M+ACN+H        True  15373321           2-Deoxy-D-ribose 5-phosphate
# 3035037  M+ACN+H        True  15375932           2-Deoxy-D-ribose 5-phosphate
# 3034686  M+ACN+H        True  15373322           2-Deoxy-D-ribose 1-phosphate
# 3034686  M+ACN+H        True  15373305              5-Deoxyribose-1-phosphate
# 3035037  M+ACN+H        True  15375933           2-Deoxy-D-ribose 1-phosphate
# 3036235      M+H        True  15387527                Aminoimidazole ribotide
# 3034071      M+H        True  15368850                             L-Tyrosine
# 3035214  M+ACN+H        True  15377269                            DL-Tyrosine
# 3035622  M+ACN+H        True  15380926                            DL-Tyrosine
# 3035754      M+H        True  15382477                            DL-Tyrosine
# 3035904      M+H        True  15383954                            DL-Tyrosine
# 3036017      M+H        True  15385047                            DL-Tyrosine
# 3037535  M+ACN+H        True  15397772                            DL-Tyrosine
# 3034071      M+H        True  15368849                 L-threo-3-Phenylserine
# 3034508      M+H        True  15372175                 L-threo-3-Phenylserine
# 3035214  M+ACN+H        True  15377270                 L-threo-3-Phenylserine
# 3035754      M+H        True  15382481                 L-threo-3-Phenylserine
# 3035904      M+H        True  15383958                 L-threo-3-Phenylserine
# 3036017      M+H        True  15385051                 L-threo-3-Phenylserine
# 3037535  M+ACN+H        True  15397773                 L-threo-3-Phenylserine
# 3034508      M+H        True  15372171                            DL-Tyrosine
# 3035904      M+H        True  15383959                             L-Tyrosine
# 3035754      M+H        True  15382482                             L-Tyrosine
# 3035622  M+ACN+H        True  15380928                             L-Tyrosine
# 3035214  M+ACN+H        True  15377271                             L-Tyrosine
# 3034508      M+H        True  15372176                             L-Tyrosine
# 3035622  M+ACN+H        True  15380927                 L-threo-3-Phenylserine
# 3034071      M+H        True  15368845                            DL-Tyrosine
# 3036017      M+H        True  15385044                             D-Tyrosine
# 3036017      M+H        True  15385052                             L-Tyrosine
# 3034071      M+H        True  15368835      gamma-Hydroxy-3-pyridinebutanoate
# 3034508      M+H        True  15372161      gamma-Hydroxy-3-pyridinebutanoate
# 3035214  M+ACN+H        True  15377263      gamma-Hydroxy-3-pyridinebutanoate
# 3035622  M+ACN+H        True  15380920      gamma-Hydroxy-3-pyridinebutanoate
# 3035754      M+H        True  15382467      gamma-Hydroxy-3-pyridinebutanoate
# 3035904      M+H        True  15383944      gamma-Hydroxy-3-pyridinebutanoate
# 3036017      M+H        True  15385037      gamma-Hydroxy-3-pyridinebutanoate
# 3037535  M+ACN+H        True  15397766      gamma-Hydroxy-3-pyridinebutanoate
# 3034071      M+H        True  15368840  3-Amino-3-(4-hydroxyphenyl)propanoate
# 3034508      M+H        True  15372166  3-Amino-3-(4-hydroxyphenyl)propanoate
# 3035214  M+ACN+H        True  15377266  3-Amino-3-(4-hydroxyphenyl)propanoate
# 3035622  M+ACN+H        True  15380923  3-Amino-3-(4-hydroxyphenyl)propanoate
# 3035754      M+H        True  15382472  3-Amino-3-(4-hydroxyphenyl)propanoate
# 3035904      M+H        True  15383949  3-Amino-3-(4-hydroxyphenyl)propanoate
# 3037535  M+ACN+H        True  15397771                             D-Tyrosine
# 3036017      M+H        True  15385042  3-Amino-3-(4-hydroxyphenyl)propanoate
# 3034071      M+H        True  15368841              N-Hydroxy-L-phenylalanine
# 3034508      M+H        True  15372167              N-Hydroxy-L-phenylalanine
# 3035214  M+ACN+H        True  15377267              N-Hydroxy-L-phenylalanine
# 3035622  M+ACN+H        True  15380924              N-Hydroxy-L-phenylalanine
# 3035754      M+H        True  15382473              N-Hydroxy-L-phenylalanine
# 3035904      M+H        True  15383950              N-Hydroxy-L-phenylalanine
# 3036017      M+H        True  15385043              N-Hydroxy-L-phenylalanine
# 3037535  M+ACN+H        True  15397770              N-Hydroxy-L-phenylalanine
# 3034071      M+H        True  15368842                             D-Tyrosine
# 3034508      M+H        True  15372168                             D-Tyrosine
# 3035214  M+ACN+H        True  15377268                             D-Tyrosine
# 3035622  M+ACN+H        True  15380925                             D-Tyrosine
# 3035754      M+H        True  15382474                             D-Tyrosine
# 3035904      M+H        True  15383951                             D-Tyrosine
# 3037535  M+ACN+H        True  15397769  3-Amino-3-(4-hydroxyphenyl)propanoate
# 3037535  M+ACN+H        True  15397774                             L-Tyrosine
#
#            db identifier                                        frank_annot  \
# pid
# 3033994  kegg     C00022  {'frank_cmpd_name': 'L-Pyroglutamic acid', 'in...
# 3033994  kegg     C00222  {'frank_cmpd_name': 'L-Pyroglutamic acid', 'in...
# 3033994  kegg     C20363  {'frank_cmpd_name': 'L-Pyroglutamic acid', 'in...
# 3033994  kegg     C12069  {'frank_cmpd_name': 'L-Pyroglutamic acid', 'in...
# 3035037  kegg     C16637                                               None
# 3034686  kegg     C11437                                               None
# 3035037  kegg     C11437                                               None
# 3034686  kegg     C00673                                               None
# 3035037  kegg     C00673                                               None
# 3034686  kegg     C00672                                               None
# 3034686  kegg     C16637                                               None
# 3035037  kegg     C00672                                               None
# 3036235  kegg     C03373                                               None
# 3034071  kegg     C00082  {'frank_cmpd_name': 'Tyrosine', 'inchikey': No...
# 3035214  kegg     C01536                                               None
# 3035622  kegg     C01536                                               None
# 3035754  kegg     C01536                                               None
# 3035904  kegg     C01536                                               None
# 3036017  kegg     C01536                                               None
# 3037535  kegg     C01536                                               None
# 3034071  kegg     C03290  {'frank_cmpd_name': 'Tyrosine', 'inchikey': No...
# 3034508  kegg     C03290  {'frank_cmpd_name': 'L-Tyrosine', 'inchikey': ...
# 3035214  kegg     C03290                                               None
# 3035754  kegg     C03290                                               None
# 3035904  kegg     C03290                                               None
# 3036017  kegg     C03290                                               None
# 3037535  kegg     C03290                                               None
# 3034508  kegg     C01536  {'frank_cmpd_name': 'L-Tyrosine', 'inchikey': ...
# 3035904  kegg     C00082                                               None
# 3035754  kegg     C00082                                               None
# 3035622  kegg     C00082                                               None
# 3035214  kegg     C00082                                               None
# 3034508  kegg     C00082  {'frank_cmpd_name': 'L-Tyrosine', 'inchikey': ...
# 3035622  kegg     C03290                                               None
# 3034071  kegg     C01536  {'frank_cmpd_name': 'Tyrosine', 'inchikey': No...
# 3036017  kegg     C06420                                               None
# 3036017  kegg     C00082                                               None
# 3034071  kegg     C19579  {'frank_cmpd_name': 'Tyrosine', 'inchikey': No...
# 3034508  kegg     C19579  {'frank_cmpd_name': 'L-Tyrosine', 'inchikey': ...
# 3035214  kegg     C19579                                               None
# 3035622  kegg     C19579                                               None
# 3035754  kegg     C19579                                               None
# 3035904  kegg     C19579                                               None
# 3036017  kegg     C19579                                               None
# 3037535  kegg     C19579                                               None
# 3034071  kegg     C04368  {'frank_cmpd_name': 'Tyrosine', 'inchikey': No...
# 3034508  kegg     C04368  {'frank_cmpd_name': 'L-Tyrosine', 'inchikey': ...
# 3035214  kegg     C04368                                               None
# 3035622  kegg     C04368                                               None
# 3035754  kegg     C04368                                               None
# 3035904  kegg     C04368                                               None
# 3037535  kegg     C06420                                               None
# 3036017  kegg     C04368                                               None
# 3034071  kegg     C19712  {'frank_cmpd_name': 'Tyrosine', 'inchikey': No...
# 3034508  kegg     C19712  {'frank_cmpd_name': 'L-Tyrosine', 'inchikey': ...
# 3035214  kegg     C19712                                               None
# 3035622  kegg     C19712                                               None
# 3035754  kegg     C19712                                               None
# 3035904  kegg     C19712                                               None
# 3036017  kegg     C19712                                               None
# 3037535  kegg     C19712                                               None
# 3034071  kegg     C06420  {'frank_cmpd_name': 'Tyrosine', 'inchikey': No...
# 3034508  kegg     C06420  {'frank_cmpd_name': 'L-Tyrosine', 'inchikey': ...
# 3035214  kegg     C06420                                               None
# 3035622  kegg     C06420                                               None
# 3035754  kegg     C06420                                               None
# 3035904  kegg     C06420                                               None
# 3037535  kegg     C04368                                               None
# 3037535  kegg     C00082                                               None
#
#                             inchikey
# pid
# 3033994  LCTONWCANYUPML-UHFFFAOYSA-N
# 3033994  OAKURXIZZOAYBC-UHFFFAOYSA-N
# 3033994  KMTRUDSVKNLOMY-UHFFFAOYSA-N
# 3033994  ZJKIBABOSPFBNO-OWOJBTEDSA-N
# 3035037  XXQFKXPJJNBLSU-TXICZTDVSA-N
# 3034686  AJPADPZSRRUGHI-RFZPGFLSSA-N
# 3035037  AJPADPZSRRUGHI-RFZPGFLSSA-N
# 3034686  KKZFLSZAWCYPOC-PYHARJCCSA-N
# 3035037  KKZFLSZAWCYPOC-PYHARJCCSA-N
# 3034686  KBDKAJNTYKVSEK-VPENINKCSA-N
# 3034686  XXQFKXPJJNBLSU-TXICZTDVSA-N
# 3035037  KBDKAJNTYKVSEK-VPENINKCSA-N
# 3036235  PDACUKOKVHBVHJ-XVFCMESISA-N
# 3034071                         None
# 3035214  OUYCCCASQSFEME-UHFFFAOYSA-N
# 3035622  OUYCCCASQSFEME-UHFFFAOYSA-N
# 3035754  OUYCCCASQSFEME-UHFFFAOYSA-N
# 3035904  OUYCCCASQSFEME-UHFFFAOYSA-N
# 3036017  OUYCCCASQSFEME-UHFFFAOYSA-N
# 3037535  OUYCCCASQSFEME-UHFFFAOYSA-N
# 3034071  VHVGNTVUSQUXPS-JGVFFNPUSA-N
# 3034508  VHVGNTVUSQUXPS-JGVFFNPUSA-N
# 3035214  VHVGNTVUSQUXPS-JGVFFNPUSA-N
# 3035754  VHVGNTVUSQUXPS-JGVFFNPUSA-N
# 3035904  VHVGNTVUSQUXPS-JGVFFNPUSA-N
# 3036017  VHVGNTVUSQUXPS-JGVFFNPUSA-N
# 3037535  VHVGNTVUSQUXPS-JGVFFNPUSA-N
# 3034508  OUYCCCASQSFEME-UHFFFAOYSA-N
# 3035904                         None
# 3035754                         None
# 3035622                         None
# 3035214                         None
# 3034508                         None
# 3035622  VHVGNTVUSQUXPS-JGVFFNPUSA-N
# 3034071  OUYCCCASQSFEME-UHFFFAOYSA-N
# 3036017  OUYCCCASQSFEME-MRVPVSSYSA-N
# 3036017                         None
# 3034071  STZOZPPVGWNSMC-UHFFFAOYSA-N
# 3034508  STZOZPPVGWNSMC-UHFFFAOYSA-N
# 3035214  STZOZPPVGWNSMC-UHFFFAOYSA-N
# 3035622  STZOZPPVGWNSMC-UHFFFAOYSA-N
# 3035754  STZOZPPVGWNSMC-UHFFFAOYSA-N
# 3035904  STZOZPPVGWNSMC-UHFFFAOYSA-N
# 3036017  STZOZPPVGWNSMC-UHFFFAOYSA-N
# 3037535  STZOZPPVGWNSMC-UHFFFAOYSA-N
# 3034071  JYPHNHPXFNEZBR-UHFFFAOYSA-N
# 3034508  JYPHNHPXFNEZBR-UHFFFAOYSA-N
# 3035214  JYPHNHPXFNEZBR-UHFFFAOYSA-N
# 3035622  JYPHNHPXFNEZBR-UHFFFAOYSA-N
# 3035754  JYPHNHPXFNEZBR-UHFFFAOYSA-N
# 3035904  JYPHNHPXFNEZBR-UHFFFAOYSA-N
# 3037535  OUYCCCASQSFEME-MRVPVSSYSA-N
# 3036017  JYPHNHPXFNEZBR-UHFFFAOYSA-N
# 3034071  VTPJSQTVPKSYCB-QMMMGPOBSA-N
# 3034508  VTPJSQTVPKSYCB-QMMMGPOBSA-N
# 3035214  VTPJSQTVPKSYCB-QMMMGPOBSA-N
# 3035622  VTPJSQTVPKSYCB-QMMMGPOBSA-N
# 3035754  VTPJSQTVPKSYCB-QMMMGPOBSA-N
# 3035904  VTPJSQTVPKSYCB-QMMMGPOBSA-N
# 3036017  VTPJSQTVPKSYCB-QMMMGPOBSA-N
# 3037535  VTPJSQTVPKSYCB-QMMMGPOBSA-N
# 3034071  OUYCCCASQSFEME-MRVPVSSYSA-N
# 3034508  OUYCCCASQSFEME-MRVPVSSYSA-N
# 3035214  OUYCCCASQSFEME-MRVPVSSYSA-N
# 3035622  OUYCCCASQSFEME-MRVPVSSYSA-N
# 3035754  OUYCCCASQSFEME-MRVPVSSYSA-N
# 3035904  OUYCCCASQSFEME-MRVPVSSYSA-N
# 3037535  JYPHNHPXFNEZBR-UHFFFAOYSA-N
# 3037535                         None

# %% [markdown]
# And here are the peaks that are not found in PiMP

# %%
formula_df[formula_df['formula'].isin(['C11H13N4', 'C3H7O6P'])]
# Out:
#          sec_id        mass          rt  polarity  cmpd_id   formula   adduct  \
# pid
# 3035414    1486  224.102981  454.038681  positive     8828  C11H13N4     M+Na
# 3035634    1706  212.032018  430.311987  positive     9471   C3H7O6P  M+ACN+H
# 3035634    1706  212.032018  430.311987  positive     9472   C3H7O6P  M+ACN+H
# 3035634    1706  212.032018  430.311987  positive     9473   C3H7O6P  M+ACN+H
# 3035634    1706  212.032018  430.311987  positive     9474   C3H7O6P  M+ACN+H
#
#          identified     rc_id                       compound    db identifier  \
# pid
# 3035414        True  15378999             Heteropyrithiamine  kegg     C02691
# 3035634        True  15381038            Glycerone phosphate  kegg     C00111
# 3035634        True  15381040  DL-Glyceraldehyde 3-phosphate  kegg     C00661
# 3035634        True  15381045          (2S)-2-Phospholactate  kegg     C19156
# 3035634        True  15381046   D-Glyceraldehyde 3-phosphate  kegg     C00118
#
#         frank_annot                     inchikey
# pid
# 3035414        None  SPQICHFDXHERAC-UHFFFAOYSA-N
# 3035634        None  GNGACRATGGDKBX-UHFFFAOYSA-N
# 3035634        None  LXJXRIRHZLFYRP-UHFFFAOYSA-N
# 3035634        None  CSZRNWHGZPKNKY-REOHCLBHSA-N
# 3035634        None  LXJXRIRHZLFYRP-VKHMYHEASA-N
