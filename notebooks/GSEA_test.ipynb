# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from loguru import logger
import seaborn as sns
import pandas as pd

# %%
import os
import sys
sys.path.append('..')

# %%
from pals.pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, download_from_pimp
from pals.evaluation import run_experiment, _select_significant_entries, _compute_prec_rec_f1
from pals.common import save_obj, set_log_level_debug, set_log_level_info, set_log_level_warning, DATABASE_PIMP_KEGG, SIGNIFICANT_THRESHOLD
from pals.feature_extraction import DataSource
from pals.PALS import PALS
from pals.ORA import ORA
from pals.GSEA import GSEA
# Out:
# 2020-01-07 13:24:11.170 | WARNING  | pals.reactome:get_neo4j_driver:14 - Using a default neo4j server: bolt://localhost:7687
# 2020-01-07 13:24:11.170 | WARNING  | pals.reactome:get_neo4j_driver:19 - Using a default neo4j username or password: neo4j
# 2020-01-07 13:24:12.244 | INFO     | pals.reactome:get_neo4j_driver:24 - Created graph database driver for bolt://localhost:7687 (neo4j)

# %% [markdown]
# # HAT Data Analysis

# %% [markdown]
# ### Load data

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id_plasma = 636
int_df_plasma, annotation_df_plasma, experimental_design_plasma = download_from_pimp(token, PIMP_HOST, analysis_id_plasma, 'kegg')
# Out:
# 2020-01-07 13:24:12.417 | DEBUG    | pals.pimp_tools:download_from_pimp:119 - Trying to load data from temp file: C:\Users\joewa\AppData\Local\Temp\pimp_analysis_636.p

# %% [markdown]
# ### Create Data Sources

# %%
database_name = DATABASE_PIMP_KEGG
ds_plasma = DataSource(int_df_plasma, annotation_df_plasma, experimental_design_plasma, database_name)
# Out:
# 2020-01-07 13:24:12.541 | DEBUG    | pals.feature_extraction:__init__:42 - Using PiMP_KEGG as database
# 2020-01-07 13:24:12.541 | DEBUG    | pals.feature_extraction:get_database:105 - Loading C:\Users\joewa\Work\git\PALS\pals\data\PiMP_KEGG.json.zip
# 2020-01-07 13:24:12.564 | DEBUG    | pals.feature_extraction:__init__:55 - Mapping pathway to unique ids
# 2020-01-07 13:24:12.569 | DEBUG    | pals.feature_extraction:__init__:69 - Creating dataset to pathway mapping
# 2020-01-07 13:24:12.904 | DEBUG    | pals.feature_extraction:__init__:97 - Computing unique id counts

# %% [markdown]
# ### Run the different methods

# %%
significant_column = 'PiMP_KEGG Stage1/Control comb_p'
pals_plage_weight = 5
pals_hg_weight = 1
pals_num_resamples = 1000
pals_resample = True if pals_num_resamples > 0 else False
case = 'Stage1'
control = 'Control'
N = 20
threshold = SIGNIFICANT_THRESHOLD

# %% [markdown]
# #### Run PALS

# %%
pals = PALS(ds_plasma, plage_weight=pals_plage_weight, hg_weight=pals_hg_weight, num_resamples=pals_num_resamples)
pals_df = pals.get_pathway_df(resample=pals_resample)
pals_df.sort_values(significant_column, inplace=True)
# Out:
# 2020-01-07 13:24:13.064 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:280 - Setting the zero intensity values in the dataframe
# 2020-01-07 13:24:13.150 | DEBUG    | pals.feature_extraction:standardize_intensity_df:261 - Scaling the data across the sample: zero mean and unit variance
# 2020-01-07 13:24:13.213 | DEBUG    | pals.PALS:get_plage_activity_df:75 - Mean values of the rows in the DF is [ 0. -0.  0. ... -0. -0. -0.]
# 2020-01-07 13:24:13.214 | DEBUG    | pals.PALS:get_plage_activity_df:76 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2020-01-07 13:24:15.322 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:87 - Calculating plage p-values with resampling
# 2020-01-07 13:24:15.323 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:91 - Comparison Stage2/Stage1
# 2020-01-07 13:24:15.323 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 0/1000
# 2020-01-07 13:24:15.427 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 100/1000
# 2020-01-07 13:24:15.527 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 200/1000
# 2020-01-07 13:24:15.626 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 300/1000
# 2020-01-07 13:24:15.729 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 400/1000
# 2020-01-07 13:24:15.835 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 500/1000
# 2020-01-07 13:24:15.946 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 600/1000
# 2020-01-07 13:24:16.048 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 700/1000
# 2020-01-07 13:24:16.149 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 800/1000
# 2020-01-07 13:24:16.248 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 900/1000
# 2020-01-07 13:24:16.345 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:105 - Total time 1
# 2020-01-07 13:24:16.445 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:91 - Comparison Stage1/Control
# 2020-01-07 13:24:16.446 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 0/1000
# 2020-01-07 13:24:16.554 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 100/1000
# 2020-01-07 13:24:16.661 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 200/1000
# 2020-01-07 13:24:16.763 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 300/1000
# 2020-01-07 13:24:16.864 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 400/1000
# 2020-01-07 13:24:16.962 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 500/1000
# 2020-01-07 13:24:17.062 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 600/1000
# 2020-01-07 13:24:17.162 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 700/1000
# 2020-01-07 13:24:17.261 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 800/1000
# 2020-01-07 13:24:17.363 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 900/1000
# 2020-01-07 13:24:17.460 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:105 - Total time 1
# 2020-01-07 13:24:17.567 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:91 - Comparison Stage2/Control
# 2020-01-07 13:24:17.568 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 0/1000
# 2020-01-07 13:24:17.668 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 100/1000
# 2020-01-07 13:24:17.765 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 200/1000
# 2020-01-07 13:24:17.867 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 300/1000
# 2020-01-07 13:24:17.966 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 400/1000
# 2020-01-07 13:24:18.066 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 500/1000
# 2020-01-07 13:24:18.173 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 600/1000
# 2020-01-07 13:24:18.281 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 700/1000
# 2020-01-07 13:24:18.387 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 800/1000
# 2020-01-07 13:24:18.488 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:99 - Resampling 900/1000
# 2020-01-07 13:24:18.584 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:105 - Total time 1
# 2020-01-07 13:24:18.709 | DEBUG    | pals.feature_extraction:_calculate_coverage_df:301 - Calculating dataset formula coverage
# 2020-01-07 13:24:18.713 | DEBUG    | pals.PALS:calculate_hg_values:166 - Calculating the hyper-geometric p-values
# 2020-01-07 13:24:18.854 | DEBUG    | pals.PALS:calculate_hg_values:206 - Calculating the combined p-values

# %%
pals_df
# Out:
#                                                     pw_name  \
# map04961  Endocrine and other factor-regulated calcium r...
# map07226  Progesterone, androgen and estrogen receptor a...
# map00903                    Limonene and pinene degradation
# map00622                                 Xylene degradation
# map00930                            Caprolactam degradation
# ...                                                     ...
# map03320                             PPAR signaling pathway
# map00627                          Aminobenzoate degradation
# map00785                             Lipoic acid metabolism
# map00960  Tropane, piperidine and pyridine alkaloid bios...
# map04672       Intestinal immune network for IgA production
#
#           Stage2/Stage1 p-value  Stage1/Control p-value  \
# map04961               0.000000            0.000000e+00
# map07226               0.000000            0.000000e+00
# map00903               0.059113            3.640822e-10
# map00622               0.867021            2.191707e-08
# map00930               0.999999            7.410467e-07
# ...                         ...                     ...
# map03320               1.000000            1.000000e+00
# map00627               1.000000            1.000000e+00
# map00785               1.000000            1.000000e+00
# map00960               0.770239            1.000000e+00
# map04672               1.000000            1.000000e+00
#
#           Stage2/Control p-value  unq_pw_F  tot_ds_F  F_coverage  \
# map04961            1.000000e+00         7         1       14.29
# map07226            1.000000e+00         5         1       20.00
# map00903            1.985833e-06        17         5       29.41
# map00622            2.104320e-05        24        10       41.67
# map00930            7.565146e-09        19        12       63.16
# ...                          ...       ...       ...         ...
# map03320            1.000000e+00         4         1       25.00
# map00627            1.000000e+00        65        11       16.92
# map00785            1.000000e+00         2         1       50.00
# map00960            8.421661e-01        51        17       33.33
# map04672            1.000000e+00         1         1      100.00
#
#                     sf  exp_F  Ex_Cov  PiMP_KEGG Stage2/Stage1 comb_p  \
# map04961  5.514965e-01   0.76   10.86                        0.000000
# map07226  4.359032e-01   0.54   10.80                        0.000000
# map00903  2.960171e-02   1.84   10.82                        0.028590
# map00622  9.271170e-05   2.59   10.79                        0.639723
# map00930  5.218894e-08   2.05   10.79                        0.999864
# ...                ...    ...     ...                             ...
# map03320  3.674136e-01   0.43   10.75                        1.000000
# map00627  8.580683e-02   7.03   10.82                        1.000000
# map00785  2.045795e-01   0.22   11.00                        1.000000
# map00960  1.161925e-05   5.51   10.80                        0.458367
# map04672  1.081176e-01   0.11   11.00                        1.000000
#
#           PiMP_KEGG Stage1/Control comb_p  PiMP_KEGG Stage2/Control comb_p
# map04961                     0.000000e+00                     1.000000e+00
# map07226                     0.000000e+00                     1.000000e+00
# map00903                     7.264882e-11                     4.958223e-07
# map00622                     5.255528e-10                     1.020707e-06
# map00930                     4.124591e-09                     2.150882e-11
# ...                                   ...                              ...
# map03320                     1.000000e+00                     1.000000e+00
# map00627                     1.000000e+00                     1.000000e+00
# map00785                     1.000000e+00                     1.000000e+00
# map00960                     1.000000e+00                     5.612332e-01
# map04672                     1.000000e+00                     1.000000e+00
#
# [206 rows x 13 columns]

# %%
_select_significant_entries(pals_df, significant_column, threshold, None)
# Out:
#                                                         pw_name       p_value  \
# map04961      Endocrine and other factor-regulated calcium r...  0.000000e+00
# map07226      Progesterone, androgen and estrogen receptor a...  0.000000e+00
# map00903                        Limonene and pinene degradation  7.264882e-11
# map00622                                     Xylene degradation  5.255528e-10
# map00930                                Caprolactam degradation  4.124591e-09
# map00902                             Monoterpenoid biosynthesis  2.055552e-08
# map00626                                Naphthalene degradation  2.840158e-08
# map00623                                    Toluene degradation  2.005946e-07
# map00981                            Insect hormone biosynthesis  1.140786e-06
# map00982                      Drug metabolism - cytochrome P450  1.393897e-06
# map05215                                        Prostate cancer  1.723682e-06
# map04913                                Ovarian steroidogenesis  3.193917e-06
# map00660                    C5-Branched dibasic acid metabolism  7.040981e-05
# map00440                 Phosphonate and phosphinate metabolism  2.154554e-04
# map00061                                Fatty acid biosynthesis  4.005644e-04
# map00592                        alpha-Linolenic acid metabolism  6.480834e-04
# map00590                            Arachidonic acid metabolism  2.484551e-03
# map05211                                   Renal cell carcinoma  4.611098e-03
# map00281                                   Geraniol degradation  1.520979e-02
# map05111                       Vibrio cholerae pathogenic cycle  1.680615e-02
# map00901                           Indole alkaloid biosynthesis  1.699823e-02
# map04626                             Plant-pathogen interaction  2.455430e-02
# ingenza00009                         Pantathenoate biosynthesis  3.855221e-02
# map00642                               Ethylbenzene degradation  4.826758e-02
#
#                         sf  unq_pw_F  tot_ds_F  F_coverage
# map04961      5.514965e-01         7         1       14.29
# map07226      4.359032e-01         5         1       20.00
# map00903      2.960171e-02        17         5       29.41
# map00622      9.271170e-05        24        10       41.67
# map00930      5.218894e-08        19        12       63.16
# map00902      4.650501e-02        19         5       26.32
# map00626      5.036634e-01        43         5       11.63
# map00623      4.102787e-01        30         4       13.33
# map00981      4.002601e-01        21         3       14.29
# map00982      5.302196e-01        63         7       11.11
# map05215      2.532519e-01         9         2       22.22
# map04913      5.630889e-01        17         2       11.76
# map00660      6.812754e-02        21         5       23.81
# map00440      8.702634e-01        44         3        6.82
# map00061      2.277381e-03        10         5       50.00
# map00592      4.570189e-02        25         6       24.00
# map00590      6.252249e-01        19         2       10.53
# map05211      2.906386e-01         3         1       33.33
# map00281      4.939258e-01        15         2       13.33
# map05111      2.906386e-01         3         1       33.33
# map00901      8.516562e-01        30         2        6.67
# map04626      5.514965e-01         7         1       14.29
# ingenza00009  6.140288e-04         5         4       80.00
# map00642      2.830501e-04        14         7       50.00

# %% [markdown]
# #### Run ORA

# %%
ora = ORA(ds_plasma)
ora_df = ora.get_pathway_df()
ora_df.sort_values(significant_column, inplace=True)
# Out:
# 2020-01-07 13:24:19.394 | DEBUG    | pals.ORA:get_pathway_df:31 - Calculating ORA
# 2020-01-07 13:24:19.395 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:280 - Setting the zero intensity values in the dataframe
# 2020-01-07 13:24:35.022 | DEBUG    | pals.ORA:get_pathway_df:91 - Correcting for multiple t-tests
# 2020-01-07 13:24:35.029 | DEBUG    | pals.feature_extraction:_calculate_coverage_df:301 - Calculating dataset formula coverage

# %%
ora_df
# Out:
#                                                pw_name  Stage2/Stage1 p-value  \
# map00930                       Caprolactam degradation               0.020308
# map00622                            Xylene degradation               0.037897
# map00642                      Ethylbenzene degradation               0.361732
# map00460                    Cyanoamino acid metabolism               0.007631
# map00061                       Fatty acid biosynthesis               0.274202
# ...                                                ...                    ...
# map00365                          Furfural degradation               1.000000
# map00627                     Aminobenzoate degradation               0.614098
# map05140                                 Leishmaniasis               1.000000
# map04713                         Circadian entrainment               1.000000
# map04672  Intestinal immune network for IgA production               1.000000
#
#           Stage1/Control p-value  Stage2/Control p-value  \
# map00930            2.629191e-07            1.609888e-05
# map00622            2.634549e-05            3.445397e-07
# map00642            1.388231e-04            2.024196e-06
# map00460            1.323420e-04            3.541736e-02
# map00061            4.188068e-04            3.087144e-03
# ...                          ...                     ...
# map00365            1.000000e+00            1.000000e+00
# map00627            7.409747e-01            3.362318e-01
# map05140            1.000000e+00            1.201963e-01
# map04713            1.000000e+00            1.000000e+00
# map04672            1.000000e+00            1.000000e+00
#
#           PiMP_KEGG Stage2/Stage1 comb_p  PiMP_KEGG Stage1/Control comb_p  \
# map00930                        0.209176                         0.000054
# map00622                        0.281996                         0.002714
# map00642                        0.856515                         0.007149
# map00460                        0.120925                         0.007149
# map00061                        0.724174                         0.017255
# ...                                  ...                              ...
# map00365                        1.000000                         1.000000
# map00627                        1.000000                         1.000000
# map05140                        1.000000                         1.000000
# map04713                        1.000000                         1.000000
# map04672                        1.000000                         1.000000
#
#           PiMP_KEGG Stage2/Control comb_p  unq_pw_F  tot_ds_F  F_coverage
# map00930                         0.001105        19        12       63.16
# map00622                         0.000071        24        10       41.67
# map00642                         0.000208        14         7       50.00
# map00460                         0.455999        40        23       57.50
# map00061                         0.057814        10         5       50.00
# ...                                   ...       ...       ...         ...
# map00365                         1.000000        12         2       16.67
# map00627                         1.000000        65        11       16.92
# map05140                         0.825348         4         1       25.00
# map04713                         1.000000         8         1       12.50
# map04672                         1.000000         1         1      100.00
#
# [206 rows x 10 columns]

# %%
_select_significant_entries(ora_df, significant_column, threshold, None)
# Out:
#                                    pw_name   p_value  unq_pw_F  tot_ds_F  \
# map00930           Caprolactam degradation  0.000054        19        12
# map00622                Xylene degradation  0.002714        24        10
# map00642          Ethylbenzene degradation  0.007149        14         7
# map00460        Cyanoamino acid metabolism  0.007149        40        23
# map00061           Fatty acid biosynthesis  0.017255        10         5
# map00643               Styrene degradation  0.017939        18         9
# map00360          Phenylalanine metabolism  0.029064        55        16
# ingenza00007  IG-Amino-acid Biosynthesis 2  0.029064         6         5
# map00350               Tyrosine metabolism  0.029064        53        11
#
#               F_coverage
# map00930           63.16
# map00622           41.67
# map00642           50.00
# map00460           57.50
# map00061           50.00
# map00643           50.00
# map00360           29.09
# ingenza00007       83.33
# map00350           20.75

# %% [markdown]
# #### Run GSEA

# %%
gsea = GSEA(ds_plasma, random_sets=100, pbar=True)
gsea_df = gsea.get_pathway_df()
gsea_df.sort_values(significant_column, inplace=True)
# Out:
# 2020-01-07 13:24:35.263 | DEBUG    | pals.GSEA:get_pathway_df:28 - Calculating GSEA
# 2020-01-07 13:24:35.265 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:280 - Setting the zero intensity values in the dataframe
# 2020-01-07 13:24:35.369 | DEBUG    | pals.GSEA:get_pathway_df:55 - Running comparison case=Stage2 control=Stage1
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:46<00:00,  1.06s/it]
# 2020-01-07 13:26:22.548 | DEBUG    | pals.GSEA:get_pathway_df:55 - Running comparison case=Stage1 control=Control
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:45<00:00,  1.05s/it]
# 2020-01-07 13:28:08.817 | DEBUG    | pals.GSEA:get_pathway_df:55 - Running comparison case=Stage2 control=Control
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:52<00:00,  1.13s/it]
# 2020-01-07 13:30:02.683 | DEBUG    | pals.feature_extraction:_calculate_coverage_df:301 - Calculating dataset formula coverage

# %%
gsea_df
# Out:
#                                                         pw_name  \
# map00903                        Limonene and pinene degradation
# map00930                                Caprolactam degradation
# map00940                           Phenylpropanoid biosynthesis
# map00642                               Ethylbenzene degradation
# map07226      Progesterone, androgen and estrogen receptor a...
# ...                                                         ...
# ingenza00002                                    1,2-Propanediol
# map00785                                 Lipoic acid metabolism
# map00280             Valine, leucine and isoleucine degradation
# map00760                 Nicotinate and nicotinamide metabolism
# map05133                                              Pertussis
#
#               Stage2/Stage1 ES_score  Stage2/Stage1 p-value  \
# map00903                   -1.473959               0.085106
# map00930                   -1.563411               0.096154
# map00940                   -1.436027               0.145455
# map00642                   -1.094570               0.318182
# map07226                    1.331980               0.000000
# ...                              ...                    ...
# ingenza00002                0.826378               0.716981
# map00785                   -0.664858               0.877551
# map00280                   -0.969021               0.562500
# map00760                   -0.816514               0.717391
# map05133                    1.128708               0.307692
#
#               PiMP_KEGG Stage2/Stage1 comb_p  Stage1/Control ES_score  \
# map00903                            0.085106                -2.075759
# map00930                            0.096154                -2.094391
# map00940                            0.145455                 1.772935
# map00642                            0.318182                -1.665460
# map07226                            0.000000                -1.275313
# ...                                      ...                      ...
# ingenza00002                        0.716981                -0.524094
# map00785                            0.877551                 0.610267
# map00280                            0.562500                 0.504715
# map00760                            0.717391                -0.565150
# map05133                            0.307692                -0.659993
#
#               Stage1/Control p-value  PiMP_KEGG Stage1/Control comb_p  \
# map00903                    0.000000                         0.000000
# map00930                    0.000000                         0.000000
# map00940                    0.000000                         0.000000
# map00642                    0.000000                         0.000000
# map07226                    0.000000                         0.000000
# ...                              ...                              ...
# ingenza00002                0.948276                         0.948276
# map00785                    0.978261                         0.978261
# map00280                    0.980769                         0.980769
# map00760                    0.983607                         0.983607
# map05133                    1.000000                         1.000000
#
#               Stage2/Control ES_score  Stage2/Control p-value  \
# map00903                    -1.405121                0.137255
# map00930                    -1.493230                0.080000
# map00940                    -1.558353                0.035088
# map00642                    -1.035182                0.460000
# map07226                     1.314259                0.069767
# ...                               ...                     ...
# ingenza00002                 0.748704                0.830189
# map00785                    -0.650110                0.936170
# map00280                    -1.054278                0.416667
# map00760                    -0.808606                0.787234
# map05133                     1.058881                0.436364
#
#               PiMP_KEGG Stage2/Control comb_p  unq_pw_F  tot_ds_F  F_coverage
# map00903                             0.137255        17         5       29.41
# map00930                             0.080000        19        12       63.16
# map00940                             0.035088        50        12       24.00
# map00642                             0.460000        14         7       50.00
# map07226                             0.069767         5         1       20.00
# ...                                       ...       ...       ...         ...
# ingenza00002                         0.830189         4         3       75.00
# map00785                             0.936170         2         1       50.00
# map00280                             0.416667        24         6       25.00
# map00760                             0.787234        40        15       37.50
# map05133                             0.436364         5         1       20.00
#
# [206 rows x 13 columns]

# %%
_select_significant_entries(gsea_df, significant_column, threshold, None)
# Out:
#                                                         pw_name   p_value  \
# map00903                        Limonene and pinene degradation  0.000000
# map04961      Endocrine and other factor-regulated calcium r...  0.000000
# map00440                 Phosphonate and phosphinate metabolism  0.000000
# map05200                                     Pathways in cancer  0.000000
# map00592                        alpha-Linolenic acid metabolism  0.000000
# map00622                                     Xylene degradation  0.000000
# map00981                            Insect hormone biosynthesis  0.000000
# map07226      Progesterone, androgen and estrogen receptor a...  0.000000
# map00642                               Ethylbenzene degradation  0.000000
# map00940                           Phenylpropanoid biosynthesis  0.000000
# map00930                                Caprolactam degradation  0.000000
# map00902                             Monoterpenoid biosynthesis  0.000000
# map00860                   Porphyrin and chlorophyll metabolism  0.017544
# map00061                                Fatty acid biosynthesis  0.019608
# map00524                    Butirosin and neomycin biosynthesis  0.021739
# map00643                                    Styrene degradation  0.025000
# map00363                                  Bisphenol degradation  0.025000
# map00300                                    Lysine biosynthesis  0.037037
# map00906                                Carotenoid biosynthesis  0.037037
# map02060                        Phosphotransferase system (PTS)  0.037736
# map04913                                Ovarian steroidogenesis  0.041667
# map00941                                 Flavonoid biosynthesis  0.041667
# ingenza00007                       IG-Amino-acid Biosynthesis 2  0.043478
# map00623                                    Toluene degradation  0.043478
# ingenza00006                       IG-Amino-acid Biosynthesis 1  0.045455
#
#               unq_pw_F  tot_ds_F  F_coverage
# map00903            17         5       29.41
# map04961             7         1       14.29
# map00440            44         3        6.82
# map05200            15         4       26.67
# map00592            25         6       24.00
# map00622            24        10       41.67
# map00981            21         3       14.29
# map07226             5         1       20.00
# map00642            14         7       50.00
# map00940            50        12       24.00
# map00930            19        12       63.16
# map00902            19         5       26.32
# map00860            89         9       10.11
# map00061            10         5       50.00
# map00524            24         3       12.50
# map00643            18         9       50.00
# map00363            22         6       27.27
# map00300            27         7       25.93
# map00906            66         1        1.52
# map02060            25         3       12.00
# map04913            17         2       11.76
# map00941            38         3        7.89
# ingenza00007         6         5       83.33
# map00623            30         4       13.33
# ingenza00006         3         2       66.67
