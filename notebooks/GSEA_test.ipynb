# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from loguru import logger
import seaborn as sns
import pandas as pd

# %%
import os
import sys
sys.path.append('..')

# %%
from pals.pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, download_from_pimp
from pals.evaluation import _select_significant_entries, _compute_prec_rec_f1
from pals.common import save_obj, set_log_level_debug, set_log_level_info, set_log_level_warning, DATABASE_PIMP_KEGG, SIGNIFICANT_THRESHOLD
from pals.feature_extraction import DataSource
from pals.common import *
from pals.PALS import PALS
from pals.ORA import ORA
from pals.GSEA import GSEA
# Out:
# 2020-01-31 12:02:31.454 | WARNING  | pals.reactome:get_neo4j_driver:14 - Using a default neo4j server: bolt://localhost:7687
# 2020-01-31 12:02:31.457 | WARNING  | pals.reactome:get_neo4j_driver:19 - Using a default neo4j username or password: neo4j
# 2020-01-31 12:02:32.578 | INFO     | pals.reactome:get_neo4j_driver:24 - Created graph database driver for bolt://localhost:7687 (neo4j)

# %% [markdown]
# # HAT Data Analysis

# %% [markdown]
# ### Load data

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id_plasma = 636
int_df_plasma, annotation_df_plasma, experimental_design_plasma = download_from_pimp(token, PIMP_HOST, analysis_id_plasma, 'kegg')
# Out:
# 2020-01-31 12:02:32.953 | DEBUG    | pals.pimp_tools:download_from_pimp:119 - Trying to load data from temp file: C:\Users\joewa\AppData\Local\Temp\pimp_analysis_636.p

# %% [markdown]
# ### Create Data Sources

# %%
database_name = DATABASE_PIMP_KEGG
ds_plasma = DataSource(int_df_plasma, annotation_df_plasma, experimental_design_plasma, database_name)
# Out:
# 2020-01-31 12:02:33.168 | DEBUG    | pals.feature_extraction:__init__:42 - Using PiMP_KEGG as database
# 2020-01-31 12:02:33.170 | DEBUG    | pals.feature_extraction:get_database:105 - Loading C:\Users\joewa\Work\git\PALS\pals\data\PiMP_KEGG.json.zip
# 2020-01-31 12:02:33.268 | DEBUG    | pals.feature_extraction:__init__:55 - Mapping pathway to unique ids
# 2020-01-31 12:02:33.277 | DEBUG    | pals.feature_extraction:__init__:69 - Creating dataset to pathway mapping
# 2020-01-31 12:02:34.294 | DEBUG    | pals.feature_extraction:__init__:97 - Computing unique id counts

# %% [markdown]
# ### Run the different methods

# %%
significant_column = 'PiMP_KEGG Stage1/Control comb_p'
pals_plage_weight = 5
pals_hg_weight = 1
num_resamples = 1000
pals_resample = True if num_resamples > 0 else False
case = 'Stage1'
control = 'Control'
N = None
threshold = SIGNIFICANT_THRESHOLD

# %% [markdown]
# #### Run PALS

# %%
pals = PALS(ds_plasma, plage_weight=pals_plage_weight, hg_weight=pals_hg_weight, num_resamples=num_resamples, case=case, control=control)
pals_df = pals.get_pathway_df(resample=pals_resample)
pals_df.sort_values(significant_column, inplace=True)
# Out:
# 2020-01-31 12:02:34.752 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:283 - Setting the zero intensity values in the dataframe
# 2020-01-31 12:02:34.956 | DEBUG    | pals.feature_extraction:standardize_intensity_df:264 - Scaling the data across the sample: zero mean and unit variance
# 2020-01-31 12:02:35.104 | DEBUG    | pals.PALS:get_plage_activity_df:79 - Mean values of the rows in the DF is [ 0. -0.  0. ... -0. -0. -0.]
# 2020-01-31 12:02:35.106 | DEBUG    | pals.PALS:get_plage_activity_df:80 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2020-01-31 12:02:39.596 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:91 - Calculating plage p-values with resampling
# 2020-01-31 12:02:39.598 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:98 - Comparison Stage1/Control
# 2020-01-31 12:02:39.599 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 0/1000
# 2020-01-31 12:02:39.853 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 100/1000
# 2020-01-31 12:02:40.071 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 200/1000
# 2020-01-31 12:02:40.303 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 300/1000
# 2020-01-31 12:02:40.491 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 400/1000
# 2020-01-31 12:02:40.691 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 500/1000
# 2020-01-31 12:02:40.883 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 600/1000
# 2020-01-31 12:02:41.065 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 700/1000
# 2020-01-31 12:02:41.232 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 800/1000
# 2020-01-31 12:02:41.502 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 900/1000
# 2020-01-31 12:02:41.732 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:112 - Total time 2
# 2020-01-31 12:02:41.994 | DEBUG    | pals.feature_extraction:_calculate_coverage_df:304 - Calculating dataset formula coverage
# 2020-01-31 12:02:42.000 | DEBUG    | pals.PALS:calculate_hg_values:176 - Calculating the hyper-geometric p-values
# 2020-01-31 12:02:42.317 | DEBUG    | pals.PALS:calculate_hg_values:216 - Calculating the combined p-values

# %%
pals_df
# Out:
#                                                     pw_name  \
# map07226  Progesterone, androgen and estrogen receptor a...
# map04961  Endocrine and other factor-regulated calcium r...
# map00903                    Limonene and pinene degradation
# map00622                                 Xylene degradation
# map00930                            Caprolactam degradation
# ...                                                     ...
# map00460                         Cyanoamino acid metabolism
# map00941                             Flavonoid biosynthesis
# map00950                 Isoquinoline alkaloid biosynthesis
# map03320                             PPAR signaling pathway
# map00620                                Pyruvate metabolism
#
#           Stage1/Control p-value  unq_pw_F  tot_ds_F  F_coverage  \
# map07226            0.000000e+00         5         1       20.00
# map04961            0.000000e+00         7         1       14.29
# map00903            1.153790e-08        17         5       29.41
# map00622            5.560178e-07        24        10       41.67
# map00930            3.018462e-06        19        12       63.16
# ...                          ...       ...       ...         ...
# map00460            1.000000e+00        40        23       57.50
# map00941            1.000000e+00        38         3        7.89
# map00950            1.000000e+00        64         6        9.38
# map03320            1.000000e+00         4         1       25.00
# map00620            1.000000e+00        24         6       25.00
#
#                     sf  exp_F  Ex_Cov  PiMP_KEGG Stage1/Control comb_p
# map07226  4.359032e-01   0.54   10.80                     0.000000e+00
# map04961  5.514965e-01   0.76   10.86                     0.000000e+00
# map00903  2.960171e-02   1.84   10.82                     2.476997e-09
# map00622  9.271170e-05   2.59   10.79                     1.802196e-08
# map00930  5.218894e-08   2.05   10.79                     2.122471e-08
# ...                ...    ...     ...                              ...
# map00460  4.468022e-13   4.32   10.80                     1.000000e+00
# map00941  7.957853e-01   4.11   10.82                     1.000000e+00
# map00950  7.060864e-01   6.92   10.81                     1.000000e+00
# map03320  3.674136e-01   0.43   10.75                     1.000000e+00
# map00620  3.806430e-02   2.59   10.79                     1.000000e+00
#
# [206 rows x 9 columns]

# %%
_select_significant_entries(pals_df, significant_column, threshold, N)
# Out:
#                                                         pw_name       p_value  \
# map07226      Progesterone, androgen and estrogen receptor a...  0.000000e+00
# map04961      Endocrine and other factor-regulated calcium r...  0.000000e+00
# map00903                        Limonene and pinene degradation  2.476997e-09
# map00622                                     Xylene degradation  1.802196e-08
# map00930                                Caprolactam degradation  2.122471e-08
# map00902                             Monoterpenoid biosynthesis  1.496150e-07
# map00626                                Naphthalene degradation  7.335063e-07
# map00623                                    Toluene degradation  2.292016e-06
# map00981                            Insect hormone biosynthesis  4.274722e-06
# map05215                                        Prostate cancer  5.594201e-06
# map00982                      Drug metabolism - cytochrome P450  8.976411e-06
# map04913                                Ovarian steroidogenesis  1.027992e-05
# map00660                    C5-Branched dibasic acid metabolism  1.313525e-04
# map00440                 Phosphonate and phosphinate metabolism  4.396176e-04
# map00061                                Fatty acid biosynthesis  4.985593e-04
# map00592                        alpha-Linolenic acid metabolism  8.183494e-04
# map00590                            Arachidonic acid metabolism  3.048393e-03
# map05211                                   Renal cell carcinoma  5.100343e-03
# map00281                                   Geraniol degradation  1.613818e-02
# map05111                       Vibrio cholerae pathogenic cycle  1.662919e-02
# map00901                           Indole alkaloid biosynthesis  1.784816e-02
# map04626                             Plant-pathogen interaction  2.548171e-02
# ingenza00009                         Pantathenoate biosynthesis  3.411687e-02
# map00642                               Ethylbenzene degradation  4.679649e-02
#
#                         sf  unq_pw_F  tot_ds_F  F_coverage
# map07226      4.359032e-01         5         1       20.00
# map04961      5.514965e-01         7         1       14.29
# map00903      2.960171e-02        17         5       29.41
# map00622      9.271170e-05        24        10       41.67
# map00930      5.218894e-08        19        12       63.16
# map00902      4.650501e-02        19         5       26.32
# map00626      5.036634e-01        43         5       11.63
# map00623      4.102787e-01        30         4       13.33
# map00981      4.002601e-01        21         3       14.29
# map05215      2.532519e-01         9         2       22.22
# map00982      5.302196e-01        63         7       11.11
# map04913      5.630889e-01        17         2       11.76
# map00660      6.812754e-02        21         5       23.81
# map00440      8.702634e-01        44         3        6.82
# map00061      2.277381e-03        10         5       50.00
# map00592      4.570189e-02        25         6       24.00
# map00590      6.252249e-01        19         2       10.53
# map05211      2.906386e-01         3         1       33.33
# map00281      4.939258e-01        15         2       13.33
# map05111      2.906386e-01         3         1       33.33
# map00901      8.516562e-01        30         2        6.67
# map04626      5.514965e-01         7         1       14.29
# ingenza00009  6.140288e-04         5         4       80.00
# map00642      2.830501e-04        14         7       50.00

# %% [markdown]
# #### Run ORA

# %%
ora = ORA(ds_plasma, case=case, control=control)
ora_df = ora.get_pathway_df()
ora_df.sort_values(significant_column, inplace=True)
# Out:
# 2020-01-31 12:02:43.213 | DEBUG    | pals.ORA:get_pathway_df:34 - Calculating ORA
# 2020-01-31 12:02:43.215 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:283 - Setting the zero intensity values in the dataframe
# 2020-01-31 12:02:55.254 | DEBUG    | pals.ORA:get_pathway_df:97 - Correcting for multiple t-tests
# 2020-01-31 12:02:55.260 | DEBUG    | pals.feature_extraction:_calculate_coverage_df:304 - Calculating dataset formula coverage

# %%
ora_df
# Out:
#                                                pw_name  \
# map00930                       Caprolactam degradation
# map00622                            Xylene degradation
# map00642                      Ethylbenzene degradation
# map00460                    Cyanoamino acid metabolism
# map00061                       Fatty acid biosynthesis
# ...                                                ...
# map04672  Intestinal immune network for IgA production
# map00232                           Caffeine metabolism
# map00365                          Furfural degradation
# map04724                         Glutamatergic synapse
# map00624   Polycyclic aromatic hydrocarbon degradation
#
#           Stage1/Control p-value  PiMP_KEGG Stage1/Control comb_p  unq_pw_F  \
# map00930            2.629191e-07                         0.000054        19
# map00622            2.634549e-05                         0.002714        24
# map00642            1.388231e-04                         0.007149        14
# map00460            1.323420e-04                         0.007149        40
# map00061            4.188068e-04                         0.017255        10
# ...                          ...                              ...       ...
# map04672            1.000000e+00                         1.000000         1
# map00232            1.000000e+00                         1.000000        15
# map00365            1.000000e+00                         1.000000        12
# map04724            1.000000e+00                         1.000000         7
# map00624            8.866948e-01                         1.000000        53
#
#           tot_ds_F  F_coverage
# map00930        12       63.16
# map00622        10       41.67
# map00642         7       50.00
# map00460        23       57.50
# map00061         5       50.00
# ...            ...         ...
# map04672         1      100.00
# map00232         7       46.67
# map00365         2       16.67
# map04724         2       28.57
# map00624         4        7.55
#
# [206 rows x 6 columns]

# %%
_select_significant_entries(ora_df, significant_column, threshold, N)
# Out:
#                                    pw_name   p_value  unq_pw_F  tot_ds_F  \
# map00930           Caprolactam degradation  0.000054        19        12
# map00622                Xylene degradation  0.002714        24        10
# map00642          Ethylbenzene degradation  0.007149        14         7
# map00460        Cyanoamino acid metabolism  0.007149        40        23
# map00061           Fatty acid biosynthesis  0.017255        10         5
# map00643               Styrene degradation  0.017939        18         9
# map00360          Phenylalanine metabolism  0.029064        55        16
# map00350               Tyrosine metabolism  0.029064        53        11
# ingenza00007  IG-Amino-acid Biosynthesis 2  0.029064         6         5
#
#               F_coverage
# map00930           63.16
# map00622           41.67
# map00642           50.00
# map00460           57.50
# map00061           50.00
# map00643           50.00
# map00360           29.09
# map00350           20.75
# ingenza00007       83.33

# %% [markdown]
# #### Run GSEA

# %%
gsea = GSEA(ds_plasma, num_resamples=num_resamples, method=GSEA_RANKING_SNR, case=case, control=control)
gsea_df = gsea.get_pathway_df()
gsea_df.sort_values(significant_column, inplace=True)
# Out:
# 2020-01-31 12:02:55.691 | DEBUG    | pals.GSEA:get_pathway_df:51 - Calculating GSEA
# 2020-01-31 12:02:55.692 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:283 - Setting the zero intensity values in the dataframe
# 2020-01-31 12:02:55.875 | DEBUG    | pals.GSEA:get_pathway_df:80 - Running comparison case=Stage1 control=Control
# 2020-01-31 12:03:10.758 | DEBUG    | pals.feature_extraction:_calculate_coverage_df:304 - Calculating dataset formula coverage

# %%
gsea_df
# Out:
#                                                     pw_name  \
# map00622                                 Xylene degradation
# map05200                                 Pathways in cancer
# map00903                    Limonene and pinene degradation
# map00140                       Steroid hormone biosynthesis
# map04961  Endocrine and other factor-regulated calcium r...
# ...                                                     ...
# map00943                          Isoflavonoid biosynthesis
# map04726                               Serotonergic synapse
# map00940                       Phenylpropanoid biosynthesis
# map05132                               Salmonella infection
# map04978                                 Mineral absorption
#
#           Stage1/Control p-value  PiMP_KEGG Stage1/Control comb_p  \
# map00622                0.010000                         0.016569
# map05200                0.000000                         0.020711
# map00903                0.010204                         0.033138
# map00140                0.034884                         0.047636
# map04961                0.000000                         0.236108
# ...                          ...                              ...
# map00943                0.840336                         1.000000
# map04726                0.950413                         1.000000
# map00940                0.019231                         1.000000
# map05132                0.908397                         1.000000
# map04978                0.859813                         1.000000
#
#           Stage1/Control ES_score  unq_pw_F  tot_ds_F  F_coverage
# map00622                 0.660550        24        10       41.67
# map05200                 0.781554        15         4       26.67
# map00903                 0.671105        17         5       29.41
# map00140                 0.704274        45         6       13.33
# map04961                 0.999363         7         1       14.29
# ...                           ...       ...       ...         ...
# map00943                 0.646272        31         1        3.23
# map04726                 0.233454        20         3       15.00
# map00940                -0.505356        50        12       24.00
# map05132                 0.558955         2         1       50.00
# map04978                 0.199213        26        13       50.00
#
# [206 rows x 7 columns]

# %%
_select_significant_entries(gsea_df, significant_column, 0.25, N)
# Out:
#                                                     pw_name   p_value  \
# map00622                                 Xylene degradation  0.016569
# map05200                                 Pathways in cancer  0.020711
# map00903                    Limonene and pinene degradation  0.033138
# map00140                       Steroid hormone biosynthesis  0.047636
# map04961  Endocrine and other factor-regulated calcium r...  0.236108
# map07226  Progesterone, androgen and estrogen receptor a...  0.236108
# map00981                        Insect hormone biosynthesis  0.249916
#
#           unq_pw_F  tot_ds_F  F_coverage
# map00622        24        10       41.67
# map05200        15         4       26.67
# map00903        17         5       29.41
# map00140        45         6       13.33
# map04961         7         1       14.29
# map07226         5         1       20.00
# map00981        21         3       14.29
