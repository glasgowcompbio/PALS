# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from loguru import logger
import seaborn as sns
import pandas as pd

# %%
import os
import sys
sys.path.append('..')

# %%
from pals.pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, download_from_pimp
from pals.evaluation import _select_significant_entries, _compute_prec_rec_f1
from pals.common import save_obj, set_log_level_debug, set_log_level_info, set_log_level_warning, DATABASE_PIMP_KEGG, SIGNIFICANT_THRESHOLD
from pals.feature_extraction import DataSource
from pals.PALS import PALS
from pals.ORA import ORA
from pals.GSEA import GSEA
from pals.GSEApy import GSEApy

# %% [markdown]
# # HAT Data Analysis

# %% [markdown]
# ### Load data

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id_plasma = 636
int_df_plasma, annotation_df_plasma, experimental_design_plasma = download_from_pimp(token, PIMP_HOST, analysis_id_plasma, 'kegg')
# Out:
# 2020-01-30 13:37:03.995 | DEBUG    | pals.pimp_tools:download_from_pimp:119 - Trying to load data from temp file: C:\Users\joewa\AppData\Local\Temp\pimp_analysis_636.p

# %% [markdown]
# ### Create Data Sources

# %%
database_name = DATABASE_PIMP_KEGG
ds_plasma = DataSource(int_df_plasma, annotation_df_plasma, experimental_design_plasma, database_name)
# Out:
# 2020-01-30 13:37:07.462 | DEBUG    | pals.feature_extraction:__init__:42 - Using PiMP_KEGG as database
# 2020-01-30 13:37:07.463 | DEBUG    | pals.feature_extraction:get_database:105 - Loading C:\Users\joewa\Work\git\PALS\pals\data\PiMP_KEGG.json.zip
# 2020-01-30 13:37:07.484 | DEBUG    | pals.feature_extraction:__init__:55 - Mapping pathway to unique ids
# 2020-01-30 13:37:07.489 | DEBUG    | pals.feature_extraction:__init__:69 - Creating dataset to pathway mapping
# 2020-01-30 13:37:07.816 | DEBUG    | pals.feature_extraction:__init__:97 - Computing unique id counts

# %% [markdown]
# ### Run the different methods

# %%
significant_column = 'PiMP_KEGG Stage1/Control comb_p'
pals_plage_weight = 5
pals_hg_weight = 1
pals_num_resamples = 1000
pals_resample = True if pals_num_resamples > 0 else False
case = 'Stage1'
control = 'Control'
N = 20
threshold = SIGNIFICANT_THRESHOLD

# %% [markdown]
# #### Run PALS

# %%
pals = PALS(ds_plasma, plage_weight=pals_plage_weight, hg_weight=pals_hg_weight, num_resamples=pals_num_resamples)
pals_df = pals.get_pathway_df(resample=pals_resample)
pals_df.sort_values(significant_column, inplace=True)
# Out:
# 2020-01-30 13:37:11.049 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:283 - Setting the zero intensity values in the dataframe
# 2020-01-30 13:37:11.134 | DEBUG    | pals.feature_extraction:standardize_intensity_df:264 - Scaling the data across the sample: zero mean and unit variance
# 2020-01-30 13:37:11.190 | DEBUG    | pals.PALS:get_plage_activity_df:79 - Mean values of the rows in the DF is [ 0. -0.  0. ... -0. -0. -0.]
# 2020-01-30 13:37:11.190 | DEBUG    | pals.PALS:get_plage_activity_df:80 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
# 2020-01-30 13:37:13.196 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:91 - Calculating plage p-values with resampling
# 2020-01-30 13:37:13.197 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:98 - Comparison Stage2/Stage1
# 2020-01-30 13:37:13.197 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 0/1000
# 2020-01-30 13:37:13.297 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 100/1000
# 2020-01-30 13:37:13.393 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 200/1000
# 2020-01-30 13:37:13.489 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 300/1000
# 2020-01-30 13:37:13.590 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 400/1000
# 2020-01-30 13:37:13.689 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 500/1000
# 2020-01-30 13:37:13.791 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 600/1000
# 2020-01-30 13:37:13.888 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 700/1000
# 2020-01-30 13:37:13.983 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 800/1000
# 2020-01-30 13:37:14.084 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 900/1000
# 2020-01-30 13:37:14.184 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:112 - Total time 0
# 2020-01-30 13:37:14.296 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:98 - Comparison Stage1/Control
# 2020-01-30 13:37:14.296 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 0/1000
# 2020-01-30 13:37:14.393 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 100/1000
# 2020-01-30 13:37:14.491 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 200/1000
# 2020-01-30 13:37:14.592 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 300/1000
# 2020-01-30 13:37:14.690 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 400/1000
# 2020-01-30 13:37:14.788 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 500/1000
# 2020-01-30 13:37:14.887 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 600/1000
# 2020-01-30 13:37:14.984 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 700/1000
# 2020-01-30 13:37:15.083 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 800/1000
# 2020-01-30 13:37:15.184 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 900/1000
# 2020-01-30 13:37:15.283 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:112 - Total time 0
# 2020-01-30 13:37:15.398 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:98 - Comparison Stage2/Control
# 2020-01-30 13:37:15.399 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 0/1000
# 2020-01-30 13:37:15.496 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 100/1000
# 2020-01-30 13:37:15.595 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 200/1000
# 2020-01-30 13:37:15.693 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 300/1000
# 2020-01-30 13:37:15.793 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 400/1000
# 2020-01-30 13:37:15.893 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 500/1000
# 2020-01-30 13:37:15.989 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 600/1000
# 2020-01-30 13:37:16.086 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 700/1000
# 2020-01-30 13:37:16.184 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 800/1000
# 2020-01-30 13:37:16.282 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:106 - Resampling 900/1000
# 2020-01-30 13:37:16.380 | DEBUG    | pals.PALS:set_up_resample_plage_p_df:112 - Total time 0
# 2020-01-30 13:37:16.496 | DEBUG    | pals.feature_extraction:_calculate_coverage_df:304 - Calculating dataset formula coverage
# 2020-01-30 13:37:16.500 | DEBUG    | pals.PALS:calculate_hg_values:176 - Calculating the hyper-geometric p-values
# 2020-01-30 13:37:16.638 | DEBUG    | pals.PALS:calculate_hg_values:216 - Calculating the combined p-values

# %%
pals_df
# Out:
#                                                     pw_name  \
# map00902                         Monoterpenoid biosynthesis
# map07226  Progesterone, androgen and estrogen receptor a...
# map04961  Endocrine and other factor-regulated calcium r...
# map00903                    Limonene and pinene degradation
# map00930                            Caprolactam degradation
# ...                                                     ...
# map04976                                     Bile secretion
# map00280         Valine, leucine and isoleucine degradation
# map00780                                  Biotin metabolism
# map00365                               Furfural degradation
# map00460                         Cyanoamino acid metabolism
#
#           Stage2/Stage1 p-value  Stage1/Control p-value  \
# map00902           1.130117e-01                     0.0
# map07226           2.808243e-22                     0.0
# map04961           2.808243e-22                     0.0
# map00903           5.478326e-02                     0.0
# map00930           9.999998e-01                     0.0
# ...                         ...                     ...
# map04976           9.263869e-01                     1.0
# map00280           1.000000e+00                     1.0
# map00780           9.999990e-01                     1.0
# map00365           1.000000e+00                     1.0
# map00460           1.000000e+00                     1.0
#
#           Stage2/Control p-value  unq_pw_F  tot_ds_F  F_coverage  \
# map00902            1.100152e-06        19         5       26.32
# map07226            1.000000e+00         5         1       20.00
# map04961            1.000000e+00         7         1       14.29
# map00903            1.300117e-12        17         5       29.41
# map00930            0.000000e+00        19        12       63.16
# ...                          ...       ...       ...         ...
# map04976            9.999859e-01        89        12       13.48
# map00280            1.000000e+00        24         6       25.00
# map00780            9.998064e-01        15         4       26.67
# map00365            1.000000e+00        12         2       16.67
# map00460            1.000000e+00        40        23       57.50
#
#                     sf  exp_F  Ex_Cov  PiMP_KEGG Stage2/Stage1 comb_p  \
# map00902  4.650501e-02   2.05   10.79                    6.468664e-02
# map07226  4.359032e-01   0.54   10.80                    1.261265e-21
# map04961  5.514965e-01   0.76   10.86                    2.175169e-21
# map00903  2.960171e-02   1.84   10.82                    2.624585e-02
# map00930  5.218894e-08   2.05   10.79                    9.999564e-01
# ...                ...    ...     ...                             ...
# map04976  2.496155e-01   9.62   10.81                    9.012552e-01
# map00280  3.806430e-02   2.59   10.79                    1.000000e+00
# map00780  6.995551e-02   1.62   10.80                    9.999938e-01
# map00365  3.782977e-01   1.30   10.83                    1.000000e+00
# map00460  4.468022e-13   4.32   10.80                    1.000000e+00
#
#           PiMP_KEGG Stage1/Control comb_p  PiMP_KEGG Stage2/Control comb_p
# map00902                              0.0                     3.320337e-07
# map07226                              0.0                     1.000000e+00
# map04961                              0.0                     1.000000e+00
# map00903                              0.0                     2.381234e-13
# map00930                              0.0                     0.000000e+00
# ...                                   ...                              ...
# map04976                              1.0                     9.999646e-01
# map00280                              1.0                     1.000000e+00
# map00780                              1.0                     9.992893e-01
# map00365                              1.0                     1.000000e+00
# map00460                              1.0                     9.999995e-01
#
# [206 rows x 13 columns]

# %%
_select_significant_entries(pals_df, significant_column, threshold, None)
# Out:
#                                                         pw_name       p_value  \
# map00902                             Monoterpenoid biosynthesis  0.000000e+00
# map07226      Progesterone, androgen and estrogen receptor a...  0.000000e+00
# map04961      Endocrine and other factor-regulated calcium r...  0.000000e+00
# map00903                        Limonene and pinene degradation  0.000000e+00
# map00930                                Caprolactam degradation  0.000000e+00
# map00981                            Insect hormone biosynthesis  0.000000e+00
# map04913                                Ovarian steroidogenesis  7.886635e-18
# map05215                                        Prostate cancer  5.337436e-17
# map00622                                     Xylene degradation  2.034185e-10
# map00626                                Naphthalene degradation  1.182499e-08
# map00623                                    Toluene degradation  1.015040e-07
# map00982                      Drug metabolism - cytochrome P450  8.040613e-07
# map00660                    C5-Branched dibasic acid metabolism  5.241005e-05
# map00061                                Fatty acid biosynthesis  6.174631e-05
# map00592                        alpha-Linolenic acid metabolism  8.928884e-05
# map00440                 Phosphonate and phosphinate metabolism  1.602904e-04
# map00590                            Arachidonic acid metabolism  4.302523e-04
# map05211                                   Renal cell carcinoma  3.880269e-03
# map00281                                   Geraniol degradation  7.710390e-03
# map04626                             Plant-pathogen interaction  1.453476e-02
# map05111                       Vibrio cholerae pathogenic cycle  1.457149e-02
# map00901                           Indole alkaloid biosynthesis  1.471127e-02
# ingenza00009                         Pantathenoate biosynthesis  3.376730e-02
# map00642                               Ethylbenzene degradation  4.339635e-02
#
#                         sf  unq_pw_F  tot_ds_F  F_coverage
# map00902      4.650501e-02        19         5       26.32
# map07226      4.359032e-01         5         1       20.00
# map04961      5.514965e-01         7         1       14.29
# map00903      2.960171e-02        17         5       29.41
# map00930      5.218894e-08        19        12       63.16
# map00981      4.002601e-01        21         3       14.29
# map04913      5.630889e-01        17         2       11.76
# map05215      2.532519e-01         9         2       22.22
# map00622      9.271170e-05        24        10       41.67
# map00626      5.036634e-01        43         5       11.63
# map00623      4.102787e-01        30         4       13.33
# map00982      5.302196e-01        63         7       11.11
# map00660      6.812754e-02        21         5       23.81
# map00061      2.277381e-03        10         5       50.00
# map00592      4.570189e-02        25         6       24.00
# map00440      8.702634e-01        44         3        6.82
# map00590      6.252249e-01        19         2       10.53
# map05211      2.906386e-01         3         1       33.33
# map00281      4.939258e-01        15         2       13.33
# map04626      5.514965e-01         7         1       14.29
# map05111      2.906386e-01         3         1       33.33
# map00901      8.516562e-01        30         2        6.67
# ingenza00009  6.140288e-04         5         4       80.00
# map00642      2.830501e-04        14         7       50.00

# %% [markdown]
# #### Run ORA

# %%
ora = ORA(ds_plasma)
ora_df = ora.get_pathway_df()
ora_df.sort_values(significant_column, inplace=True)
# Out:
# 2020-01-30 13:37:19.405 | DEBUG    | pals.ORA:get_pathway_df:34 - Calculating ORA
# 2020-01-30 13:37:19.406 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:283 - Setting the zero intensity values in the dataframe
# 2020-01-30 13:37:34.538 | DEBUG    | pals.ORA:get_pathway_df:97 - Correcting for multiple t-tests
# 2020-01-30 13:37:34.546 | DEBUG    | pals.feature_extraction:_calculate_coverage_df:304 - Calculating dataset formula coverage

# %%
ora_df
# Out:
#                                         pw_name  Stage2/Stage1 p-value  \
# map00930                Caprolactam degradation               0.020308
# map00622                     Xylene degradation               0.037897
# map00460             Cyanoamino acid metabolism               0.007631
# map00642               Ethylbenzene degradation               0.361732
# map00061                Fatty acid biosynthesis               0.274202
# ...                                         ...                    ...
# map02060        Phosphotransferase system (PTS)               0.552178
# map00472  D-Arginine and D-ornithine metabolism               0.147941
# map00904               Diterpenoid biosynthesis               1.000000
# map00365                   Furfural degradation               1.000000
# map00071                 Fatty acid degradation               1.000000
#
#           Stage1/Control p-value  Stage2/Control p-value  \
# map00930            2.629191e-07            1.609888e-05
# map00622            2.634549e-05            3.445397e-07
# map00460            1.323420e-04            3.541736e-02
# map00642            1.388231e-04            2.024196e-06
# map00061            4.188068e-04            3.087144e-03
# ...                          ...                     ...
# map02060            6.401330e-01            5.521778e-01
# map00472            1.000000e+00            1.000000e+00
# map00904            1.000000e+00            7.153208e-01
# map00365            1.000000e+00            1.000000e+00
# map00071            1.000000e+00            1.000000e+00
#
#           PiMP_KEGG Stage2/Stage1 comb_p  PiMP_KEGG Stage1/Control comb_p  \
# map00930                        0.209176                         0.000054
# map00622                        0.281996                         0.002714
# map00460                        0.120925                         0.007149
# map00642                        0.856515                         0.007149
# map00061                        0.724174                         0.017255
# ...                                  ...                              ...
# map02060                        0.972210                         1.000000
# map00472                        0.555773                         1.000000
# map00904                        1.000000                         1.000000
# map00365                        1.000000                         1.000000
# map00071                        1.000000                         1.000000
#
#           PiMP_KEGG Stage2/Control comb_p  unq_pw_F  tot_ds_F  F_coverage
# map00930                         0.001105        19        12       63.16
# map00622                         0.000071        24        10       41.67
# map00460                         0.455999        40        23       57.50
# map00642                         0.000208        14         7       50.00
# map00061                         0.057814        10         5       50.00
# ...                                   ...       ...       ...         ...
# map02060                         1.000000        25         3       12.00
# map00472                         1.000000         5         3       60.00
# map00904                         1.000000        39         1        2.56
# map00365                         1.000000        12         2       16.67
# map00071                         1.000000        37         1        2.70
#
# [206 rows x 10 columns]

# %%
_select_significant_entries(ora_df, significant_column, threshold, None)
# Out:
#                                    pw_name   p_value  unq_pw_F  tot_ds_F  \
# map00930           Caprolactam degradation  0.000054        19        12
# map00622                Xylene degradation  0.002714        24        10
# map00460        Cyanoamino acid metabolism  0.007149        40        23
# map00642          Ethylbenzene degradation  0.007149        14         7
# map00061           Fatty acid biosynthesis  0.017255        10         5
# map00643               Styrene degradation  0.017939        18         9
# ingenza00007  IG-Amino-acid Biosynthesis 2  0.029064         6         5
# map00350               Tyrosine metabolism  0.029064        53        11
# map00360          Phenylalanine metabolism  0.029064        55        16
#
#               F_coverage
# map00930           63.16
# map00622           41.67
# map00460           57.50
# map00642           50.00
# map00061           50.00
# map00643           50.00
# ingenza00007       83.33
# map00350           20.75
# map00360           29.09

# %% [markdown]
# #### Run GSEA

# %%
gsea = GSEA(ds_plasma, random_sets=1000, pbar=True)
gsea_df = gsea.get_pathway_df()
gsea_df.sort_values(significant_column, inplace=True)

# %%
gsea_df

# %%
_select_significant_entries(gsea_df, significant_column, threshold, None)

# %% [markdown]
# #### Run GSEApy

# %%
gsea = GSEApy(ds_plasma, random_sets=100000, pbar=True)
gsea_df = gsea.get_pathway_df()
gsea_df.sort_values(significant_column, inplace=True)
# Out:
# 2020-01-30 14:01:44.086 | DEBUG    | pals.GSEApy:get_pathway_df:36 - Calculating GSEA
# 2020-01-30 14:01:44.087 | DEBUG    | pals.feature_extraction:change_zero_peak_ints:283 - Setting the zero intensity values in the dataframe
# 2020-01-30 14:01:44.193 | DEBUG    | pals.GSEApy:get_pathway_df:70 - Running comparison case=Stage2 control=Stage1
# 2020-01-30 14:01:44,194 Parsing data files for GSEA.............................
# 2020-01-30 14:01:44,199 Warning: dropping duplicated gene names, only keep the first values
# 2020-01-30 14:01:44,247 0000 gene_sets have been filtered out when max_size=1000 and min_size=1
# 2020-01-30 14:01:44,248 0206 gene_sets used for further statistical testing.....
# 2020-01-30 14:01:44,249 Start to run GSEA...Might take a while..................
# 2020-01-30 14:01:49,347 Start to generate GSEApy reports and figures............
# 2020-01-30 14:01:49,375 Congratulations. GSEApy ran successfully.................
#
# 2020-01-30 14:01:49.379 | DEBUG    | pals.GSEApy:get_pathway_df:70 - Running comparison case=Stage1 control=Control
# 2020-01-30 14:01:49,381 Parsing data files for GSEA.............................
# 2020-01-30 14:01:49,385 Warning: dropping duplicated gene names, only keep the first values
# 2020-01-30 14:01:49,431 0000 gene_sets have been filtered out when max_size=1000 and min_size=1
# 2020-01-30 14:01:49,433 0206 gene_sets used for further statistical testing.....
# 2020-01-30 14:01:49,434 Start to run GSEA...Might take a while..................
# 2020-01-30 14:01:54,548 Start to generate GSEApy reports and figures............
# 2020-01-30 14:01:54,570 Congratulations. GSEApy ran successfully.................
#
# 2020-01-30 14:01:54.576 | DEBUG    | pals.GSEApy:get_pathway_df:70 - Running comparison case=Stage2 control=Control
# 2020-01-30 14:01:54,577 Parsing data files for GSEA.............................
# 2020-01-30 14:01:54,582 Warning: dropping duplicated gene names, only keep the first values
# 2020-01-30 14:01:54,630 0000 gene_sets have been filtered out when max_size=1000 and min_size=1
# 2020-01-30 14:01:54,631 0206 gene_sets used for further statistical testing.....
# 2020-01-30 14:01:54,632 Start to run GSEA...Might take a while..................
# 2020-01-30 14:02:01,455 Start to generate GSEApy reports and figures............
# 2020-01-30 14:02:01,484 Congratulations. GSEApy ran successfully.................
#
# 2020-01-30 14:02:01.497 | DEBUG    | pals.feature_extraction:_calculate_coverage_df:304 - Calculating dataset formula coverage

# %%
gsea_df
# Out:
#                                               pw_name  Stage2/Stage1 p-value  \
# map00902                   Monoterpenoid biosynthesis               0.807692
# map00903              Limonene and pinene degradation               0.461538
# map00195                               Photosynthesis               0.126214
# map00140                 Steroid hormone biosynthesis               0.640000
# map05200                           Pathways in cancer               0.491071
# ...                                               ...                    ...
# map00290  Valine, leucine and isoleucine biosynthesis               0.469565
# map00600                      Sphingolipid metabolism               0.847059
# map04745                      Phototransduction - fly               0.317308
# map00280   Valine, leucine and isoleucine degradation               0.267857
# map00940                 Phenylpropanoid biosynthesis               0.767241
#
#           PiMP_KEGG Stage2/Stage1 comb_p  Stage2/Stage1 ES_score  \
# map00902                        0.955225               -0.370843
# map00903                        0.944106               -0.546529
# map00195                        1.000000                0.831826
# map00140                        1.000000               -0.371704
# map05200                        0.820281                0.510908
# ...                                  ...                     ...
# map00290                        1.000000               -0.451599
# map00600                        0.944017               -0.372072
# map04745                        0.731582                0.750589
# map00280                        0.999927               -0.503335
# map00940                        0.967532               -0.302950
#
#           Stage1/Control p-value  PiMP_KEGG Stage1/Control comb_p  \
# map00902                0.000000                         0.000000
# map00903                0.000000                         0.005569
# map00195                0.098765                         0.043626
# map00140                0.009346                         0.049427
# map05200                0.031250                         0.088644
# ...                          ...                              ...
# map00290                0.913978                         1.000000
# map00600                0.961538                         1.000000
# map04745                0.933962                         1.000000
# map00280                1.000000                         1.000000
# map00940                0.834862                         1.000000
#
#           Stage1/Control ES_score  Stage2/Control p-value  \
# map00902                 0.813284                0.798077
# map00903                 0.850344                0.360000
# map00195                 0.860000                0.109890
# map00140                 0.778952                0.693069
# map05200                 0.781559                0.508333
# ...                           ...                     ...
# map00290                -0.296155                0.495327
# map00600                -0.301807                0.900000
# map04745                -0.416364                0.309735
# map00280                -0.193309                0.305556
# map00940                -0.293198                0.778947
#
#           PiMP_KEGG Stage2/Control comb_p  Stage2/Control ES_score  unq_pw_F  \
# map00902                         0.960332                -0.370843        19
# map00903                         1.000000                -0.546529        17
# map00195                         0.869412                 0.831826        10
# map00140                         0.996190                -0.371704        45
# map05200                         0.917480                 0.510908        15
# ...                                   ...                      ...       ...
# map00290                         0.995080                -0.451599        17
# map00600                         0.968626                -0.372072        10
# map04745                         0.818028                 0.750589         6
# map00280                         1.000000                -0.503335        24
# map00940                         0.983127                -0.302950        50
#
#           tot_ds_F  F_coverage
# map00902         5       26.32
# map00903         5       29.41
# map00195         2       20.00
# map00140         6       13.33
# map05200         4       26.67
# ...            ...         ...
# map00290         9       52.94
# map00600         4       40.00
# map04745         2       33.33
# map00280         6       25.00
# map00940        12       24.00
#
# [206 rows x 13 columns]

# %%
_select_significant_entries(gsea_df, significant_column, threshold, None)
# Out:
#                                   pw_name   p_value  unq_pw_F  tot_ds_F  \
# map00902       Monoterpenoid biosynthesis  0.000000        19         5
# map00903  Limonene and pinene degradation  0.005569        17         5
# map00195                   Photosynthesis  0.043626        10         2
# map00140     Steroid hormone biosynthesis  0.049427        45         6
#
#           F_coverage
# map00902       26.32
# map00903       29.41
# map00195       20.00
# map00140       13.33
