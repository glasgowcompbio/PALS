# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib
import pickle

sys.path.append('..')

# %%
import pandas as pd

# %%
from pals.pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, get_ms1_intensities, get_ms1_peaks, get_annotation_df, get_experimental_design
from pals.feature_extraction import DataSource
from pals.pathway_analysis import PALS
from pals.common import *
# Out:
# 2019-11-25 14:38:19.447 | WARNING  | pals.reactome:get_neo4j_driver:14 - Using a default neo4j server: bolt://localhost:7687
# 2019-11-25 14:38:19.449 | WARNING  | pals.reactome:get_neo4j_driver:19 - Using a default neo4j username or password: neo4j
# 2019-11-25 14:38:20.520 | INFO     | pals.reactome:get_neo4j_driver:24 - Created graph database driver for bolt://localhost:7687 (neo4j)

# %% [markdown]
# ### Get PiMP Authentication Token

# %% [markdown]
# Generate token by logging in to PiMP

# %%
# username = 'joewandy' # PiMP username
# password = 'enter' # PiMP password
# host = 'localhost:8000' # server address and port
# token = get_authentication_token(host, username, password)

# %%
token = get_pimp_API_token_from_env()

# %% [markdown]
# # FlyMet Results

# %% [markdown]
# ### project 673 analysis 1423

# %%
analysis_id = 1423
int_df = get_ms1_intensities(token, PIMP_HOST, analysis_id)
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_ms1_intensities?analysis_id=1423 <Response [200]>

# %%
int_df
# Out:
#           59_F1.mzXML   59_F2.mzXML   59_F3.mzXML   59_F4.mzXML   59_M1.mzXML  \
# row_id
# 3348783  1.129905e+07  6.735284e+06  5.369894e+06  6.100683e+06  1.247392e+09
# 3348784           NaN           NaN           NaN           NaN  8.649787e+05
# 3348785  1.097933e+09  4.727063e+08  4.662468e+08  4.609308e+08  9.061941e+08
# 3348786  4.772335e+06  1.297121e+06  1.149646e+06  1.030103e+06  3.705817e+06
# 3348787  3.431013e+05  2.884913e+05  1.791161e+05  2.497849e+05  6.787022e+05
# ...               ...           ...           ...           ...           ...
# 3355040  1.310481e+04  1.096351e+04  1.365943e+04  1.131174e+04  1.074841e+04
# 3355041  1.154278e+04  1.101051e+04  8.648824e+03  8.048555e+03  6.359053e+03
# 3355042  1.583390e+04  1.205252e+04  1.464933e+04  1.315939e+04  1.326956e+04
# 3355043  1.073865e+04           NaN           NaN  2.835742e+03  7.826725e+03
# 3355044  1.043077e+04  1.086945e+04  1.250243e+04  1.230228e+04  1.225466e+04
#
#           59_M2.mzXML   59_M3.mzXML   59_M4.mzXML  128_F1.mzXML  128_F2.mzXML  \
# row_id
# 3348783  1.724628e+09  1.468391e+09  1.462318e+09  9.725379e+06  1.021242e+07
# 3348784  1.882536e+06  1.079620e+06  1.379000e+06           NaN           NaN
# 3348785  1.018493e+09  7.248828e+08  1.004667e+09  1.321629e+09  1.252032e+09
# 3348786  4.359371e+06  1.995390e+06  4.167161e+06  7.667926e+06  6.912828e+06
# 3348787  5.571722e+05  5.500731e+05  6.106119e+05  6.790332e+05  6.146051e+05
# ...               ...           ...           ...           ...           ...
# 3355040  1.165205e+04  1.098894e+04  1.216398e+04  1.513173e+04  1.050408e+04
# 3355041  8.354007e+03           NaN  7.313768e+03  1.509357e+04  1.054275e+04
# 3355042  1.109278e+04  1.270231e+04  1.393922e+04  1.156433e+04  1.337775e+04
# 3355043  9.710898e+03           NaN  6.520635e+03  9.918508e+03           NaN
# 3355044  1.059909e+04  1.237206e+04  1.260506e+04  1.513173e+04  1.093547e+04
#
#          ...  950_M3.mzXML  950_M4.mzXML  WILD_F1.mzXML  WILD_F2.mzXML  \
# row_id   ...
# 3348783  ...  5.971650e+08  1.026515e+09   1.111487e+07   1.599932e+07
# 3348784  ...  4.714755e+05  9.298195e+05            NaN            NaN
# 3348785  ...  6.046905e+08  1.005276e+09   1.295902e+09   1.477162e+09
# 3348786  ...  1.734096e+06  3.973322e+06   6.605909e+06   9.188424e+06
# 3348787  ...  2.276514e+05  5.160123e+05   5.556039e+05   6.685968e+05
# ...      ...           ...           ...            ...            ...
# 3355040  ...  1.365102e+04  1.277173e+04   1.256447e+04   1.187326e+04
# 3355041  ...  8.740254e+03  1.010659e+04   9.152615e+03   1.231351e+04
# 3355042  ...  1.701955e+04  1.365613e+04   1.179964e+04   1.350248e+04
# 3355043  ...           NaN  7.935059e+03            NaN   5.385872e+03
# 3355044  ...  1.210684e+04  1.277173e+04   9.935657e+03   1.174497e+04
#
#          WILD_F3.mzXML  WILD_F4.mzXML  WILD_M1.mzXML  WILD_M2.mzXML  \
# row_id
# 3348783   1.666487e+06   8.234750e+06   2.008886e+09   2.449737e+09
# 3348784            NaN            NaN   1.499379e+06   2.338675e+06
# 3348785   5.823542e+08   1.148187e+09   1.447192e+09   1.559472e+09
# 3348786   1.220138e+06   5.740234e+06   8.791082e+06   9.643355e+06
# 3348787   2.942377e+05   4.987555e+05   5.929966e+05   6.613704e+05
# ...                ...            ...            ...            ...
# 3355040   1.070781e+04   1.426384e+04   1.079904e+04   1.057351e+04
# 3355041   3.747290e+03   1.114439e+04   1.033611e+04   8.165541e+03
# 3355042   1.653589e+04   1.184799e+04   1.447806e+04   1.104725e+04
# 3355043            NaN            NaN   1.457465e+04   1.248557e+04
# 3355044   1.255373e+04   1.296340e+04   1.154215e+04   1.057351e+04
#
#          WILD_M3.mzXML  WILD_M4.mzXML
# row_id
# 3348783   1.258911e+09   2.053143e+09
# 3348784   1.319023e+06   1.835345e+06
# 3348785   9.896303e+08   1.325751e+09
# 3348786   4.190674e+06   7.021897e+06
# 3348787   3.209608e+05   5.714668e+05
# ...                ...            ...
# 3355040   1.443746e+04   1.153188e+04
# 3355041            NaN   5.403356e+03
# 3355042   1.205912e+04   1.067211e+04
# 3355043   4.197200e+03   1.020010e+04
# 3355044   1.164218e+04   1.315667e+04
#
# [6262 rows x 56 columns]

# %%
annotation_df = get_annotation_df(token, PIMP_HOST, analysis_id, 'kegg')
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_ms1_peaks?analysis_id=1423 <Response [200]>

# %%
annotation_df
# Out:
#         entity_id
# row_id
# 3348783    C05135
# 3348921    C05135
# 3350285    C05135
# 3352098    C05135
# 3352165    C05135
# ...           ...
# 3354466    C03659
# 3354477    C01018
# 3354492    C20697
# 3354771    C01018
# 3354937    C20450
#
# [8848 rows x 1 columns]

# %%
experimental_design = get_experimental_design(token, PIMP_HOST, analysis_id)
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_experimental_design?analysis_id=1423 <Response [200]>

# %%
experimental_design
# Out:
# {'comparisons': [{'case': 'CG16758_F',
#    'control': 'Wild_F',
#    'name': 'CG16758_F/Wild_F'},
#   {'case': 'CG16758_M', 'control': 'Wild_M', 'name': 'CG16758_M/Wild_M'},
#   {'case': 'CG18128_F', 'control': 'Wild_F', 'name': 'CG18128_F/Wild_F'},
#   {'case': 'CG18128_M', 'control': 'Wild_M', 'name': 'CG18128_M/Wild_M'},
#   {'case': 'CG1721_F', 'control': 'Wild_F', 'name': 'CG1721_F/Wild_F'},
#   {'case': 'CG1721_M', 'control': 'Wild_M', 'name': 'CG1721_M/Wild_M'},
#   {'case': 'CG7059_F', 'control': 'Wild_F', 'name': 'CG7059_F/Wild_F'},
#   {'case': 'CG7059_M', 'control': 'Wild_M', 'name': 'CG7059_M/Wild_M'},
#   {'case': 'CG5345_F', 'control': 'Wild_F', 'name': 'CG5345_F/Wild_F'},
#   {'case': 'CG5345_M', 'control': 'Wild_M', 'name': 'CG5345_M/Wild_M'},
#   {'case': 'CG6950_F', 'control': 'Wild_F', 'name': 'CG6950_F/Wild_F'},
#   {'case': 'CG6950_M', 'control': 'Wild_M', 'name': 'CG6950_M/Wild_M'}],
#  'groups': {'Wild_F': ['WILD_F1.mzXML',
#    'WILD_F3.mzXML',
#    'WILD_F2.mzXML',
#    'WILD_F4.mzXML'],
#   'CG6950_M': ['950_M2.mzXML', '950_M4.mzXML', '950_M1.mzXML', '950_M3.mzXML'],
#   'CG18128_M': ['128_M1.mzXML',
#    '128_M3.mzXML',
#    '128_M4.mzXML',
#    '128_M2.mzXML'],
#   'CG1721_M': ['721_M2.mzXML', '721_M1.mzXML', '721_M3.mzXML', '721_M4.mzXML'],
#   'CG6950_F': ['950_F2.mzXML', '950_F1.mzXML', '950_F4.mzXML', '950_F3.mzXML'],
#   'CG1721_F': ['721_F2.mzXML', '721_F1.mzXML', '721_F4.mzXML', '721_F3.mzXML'],
#   'CG18128_F': ['128_F1.mzXML',
#    '128_F3.mzXML',
#    '128_F4.mzXML',
#    '128_F2.mzXML'],
#   'CG16758_M': ['758_M4.mzXML',
#    '758_M1.mzXML',
#    '758_M2.mzXML',
#    '758_M3.mzXML'],
#   'CG7059_F': ['59_F2.mzXML', '59_F1.mzXML', '59_F3.mzXML', '59_F4.mzXML'],
#   'CG5345_M': ['345_M3.mzXML', '345_M1.mzXML', '345_M2.mzXML', '345_M4.mzXML'],
#   'CG5345_F': ['345_F4.mzXML', '345_F2.mzXML', '345_F3.mzXML', '345_F1.mzXML'],
#   'CG7059_M': ['59_M3.mzXML', '59_M4.mzXML', '59_M2.mzXML', '59_M1.mzXML'],
#   'CG16758_F': ['758_F1.mzXML',
#    '758_F4.mzXML',
#    '758_F2.mzXML',
#    '758_F3.mzXML'],
#   'Wild_M': ['WILD_M3.mzXML',
#    'WILD_M1.mzXML',
#    'WILD_M4.mzXML',
#    'WILD_M2.mzXML']}}

# %%
ds = DataSource(int_df, annotation_df, experimental_design, DATABASE_PIMP_KEGG)
# Out:
# 2019-11-25 14:38:50.428 | DEBUG    | pals.feature_extraction:__init__:34 - Loading C:\Users\joewa\Work\git\PALS\pals\data\PiMP_KEGG.json.zip
# 2019-11-25 14:38:50.447 | DEBUG    | pals.feature_extraction:__init__:85 - Mapping pathway to unique ids
# 2019-11-25 14:38:50.453 | DEBUG    | pals.feature_extraction:__init__:99 - Creating dataset to pathway mapping
# 2019-11-25 14:38:50.995 | DEBUG    | pals.feature_extraction:__init__:124 - Computing unique id counts

# %%
pals = PALS(ds, min_replace=5000)
pathway_df = pals.get_pathway_df()
# Out:
# 2019-11-25 14:38:51.065 | DEBUG    | pals.pathway_analysis:_change_zero_peak_ints:250 - Setting the zero intensity values in the dataframe
# 2019-11-25 14:38:51.146 | DEBUG    | pals.pathway_analysis:_standardize_intensity_df:230 - Scaling the data across the sample: zero mean and unit variance
# 2019-11-25 14:38:51.170 | DEBUG    | pals.pathway_analysis:get_plage_activity_df:69 - Mean values of the rows in the DF is [ 0. -0.  0. ... -0.  0. -0.]
# 2019-11-25 14:38:51.170 | DEBUG    | pals.pathway_analysis:get_plage_activity_df:70 - Variance in the rows of the DF is [0. 0. 0. ... 0. 0. 0.]
# 2019-11-25 14:38:53.670 | INFO     | pals.pathway_analysis:set_up_resample_plage_p_df:81 - Calculating plage p-values with resampling
# 2019-11-25 14:38:53.671 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG16758_F/Wild_F
# 2019-11-25 14:38:53.672 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:38:53.766 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:38:53.856 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:38:53.949 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:38:54.041 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:38:54.134 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:38:54.226 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:38:54.315 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:38:54.407 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:38:54.499 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:38:54.593 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# 2019-11-25 14:38:54.701 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG16758_M/Wild_M
# 2019-11-25 14:38:54.702 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:38:54.795 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:38:54.885 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:38:54.979 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:38:55.073 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:38:55.167 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:38:55.266 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:38:55.368 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:38:55.464 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:38:55.562 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:38:55.655 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:38:55.766 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG18128_F/Wild_F
# 2019-11-25 14:38:55.767 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:38:55.858 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:38:55.950 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:38:56.044 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:38:56.135 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:38:56.231 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:38:56.324 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:38:56.415 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:38:56.506 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:38:56.599 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:38:56.692 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:38:56.805 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG18128_M/Wild_M
# 2019-11-25 14:38:56.806 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:38:56.903 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:38:57.000 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:38:57.096 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:38:57.187 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:38:57.279 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:38:57.373 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:38:57.483 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:38:57.593 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:38:57.696 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:38:57.790 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:38:57.907 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG1721_F/Wild_F
# 2019-11-25 14:38:57.908 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:38:58.000 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:38:58.093 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:38:58.185 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:38:58.282 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:38:58.389 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:38:58.497 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:38:58.593 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:38:58.687 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:38:58.779 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:38:58.871 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:38:59.036 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG1721_M/Wild_M
# 2019-11-25 14:38:59.036 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:38:59.136 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:38:59.239 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:38:59.334 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:38:59.432 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:38:59.527 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:38:59.622 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:38:59.719 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:38:59.811 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:38:59.913 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:39:00.008 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:39:00.148 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG7059_F/Wild_F
# 2019-11-25 14:39:00.148 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:39:00.248 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:39:00.341 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:39:00.434 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:39:00.525 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:39:00.617 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:39:00.710 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:39:00.801 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:39:00.896 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:39:01.004 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:39:01.110 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:39:01.218 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG7059_M/Wild_M
# 2019-11-25 14:39:01.220 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:39:01.325 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:39:01.421 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:39:01.513 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:39:01.603 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:39:01.698 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:39:01.788 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:39:01.879 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:39:01.971 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:39:02.066 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:39:02.162 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:39:02.274 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG5345_F/Wild_F
# 2019-11-25 14:39:02.275 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:39:02.368 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:39:02.459 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:39:02.549 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:39:02.643 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:39:02.740 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:39:02.830 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:39:02.922 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:39:03.017 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:39:03.109 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:39:03.206 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:39:03.321 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG5345_M/Wild_M
# 2019-11-25 14:39:03.321 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:39:03.418 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:39:03.521 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:39:03.617 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:39:03.715 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:39:03.809 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:39:03.902 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:39:03.994 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:39:04.099 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:39:04.194 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:39:04.285 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:39:04.382 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG6950_F/Wild_F
# 2019-11-25 14:39:04.383 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:39:04.475 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:39:04.569 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:39:04.666 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:39:04.767 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:39:04.860 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:39:04.952 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:39:05.043 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:39:05.139 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:39:05.238 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:39:05.332 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:39:05.445 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:85 - Comparison CG6950_M/Wild_M
# 2019-11-25 14:39:05.445 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 0/1000
# 2019-11-25 14:39:05.540 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 100/1000
# 2019-11-25 14:39:05.645 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 200/1000
# 2019-11-25 14:39:05.749 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 300/1000
# 2019-11-25 14:39:05.846 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 400/1000
# 2019-11-25 14:39:05.940 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 500/1000
# 2019-11-25 14:39:06.033 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 600/1000
# 2019-11-25 14:39:06.127 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 700/1000
# 2019-11-25 14:39:06.223 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 800/1000
# 2019-11-25 14:39:06.316 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:93 - Resampling 900/1000
# 2019-11-25 14:39:06.409 | DEBUG    | pals.pathway_analysis:set_up_resample_plage_p_df:99 - Total time 0
# 2019-11-25 14:39:06.544 | INFO     | pals.pathway_analysis:_calculate_coverage_df:336 - Calculating dataset formula coverage
# 2019-11-25 14:39:06.547 | INFO     | pals.pathway_analysis:calculate_hg_values:160 - Calculating the hyper-geometric p-values
# 2019-11-25 14:39:06.718 | INFO     | pals.pathway_analysis:calculate_hg_values:192 - Calculating the combined p-values

# %%
pathway_df.head(20)
# Out:
#                                                     pw_name  \
# map04726                               Serotonergic synapse
# map04150                             mTOR signaling pathway
# map04744                                  Phototransduction
# map00982                  Drug metabolism - cytochrome P450
# map05133                                          Pertussis
# map00909      Sesquiterpenoid and triterpenoid biosynthesis
# map00340                               Histidine metabolism
# map07033                                    Anticonvulsants
# map00230                                  Purine metabolism
# map04142                                           Lysosome
# map04066                            HIF-1 signaling pathway
# map00945  Stilbenoid, diarylheptanoid and gingerol biosy...
# map00680                                 Methane metabolism
# map00565                             Ether lipid metabolism
# map05034                                         Alcoholism
# map04978                                 Mineral absorption
# map00231                             Puromycin biosynthesis
# map04261             Adrenergic signaling in cardiomyocytes
# map00402                         Benzoxazinoid biosynthesis
# map00410                            beta-Alanine metabolism
#
#           CG16758_F/Wild_F p-value  CG16758_M/Wild_M p-value  \
# map04726                  1.000000                  0.092406
# map04150                  1.000000                  1.000000
# map04744                  1.000000                  1.000000
# map00982                  1.000000                  0.413453
# map05133                  1.000000                  0.520471
# map00909                  1.000000                  0.118771
# map00340                  1.000000                  0.186274
# map07033                  0.949345                  0.355326
# map00230                  1.000000                  0.491479
# map04142                  1.000000                  0.999996
# map04066                  1.000000                  0.184063
# map00945                  0.999665                  0.719944
# map00680                  1.000000                  0.256174
# map00565                  0.999758                  0.366167
# map05034                  0.934259                  0.141007
# map04978                  1.000000                  0.383052
# map00231                  1.000000                  1.000000
# map04261                  1.000000                  0.513787
# map00402                  0.475488                  0.887688
# map00410                  1.000000                  0.194708
#
#           CG18128_F/Wild_F p-value  CG18128_M/Wild_M p-value  \
# map04726                  0.999642                  0.354650
# map04150                  0.809825                  1.000000
# map04744                  1.000000                  0.956995
# map00982                  0.999460                  0.628138
# map05133                  1.000000                  0.816489
# map00909                  0.514174                  0.100756
# map00340                  0.999986                  0.427580
# map07033                  1.000000                  0.316385
# map00230                  1.000000                  0.551429
# map04142                  0.922771                  0.979110
# map04066                  1.000000                  0.453297
# map00945                  1.000000                  0.529796
# map00680                  1.000000                  0.480218
# map00565                  0.789057                  0.821902
# map05034                  0.975343                  0.307679
# map04978                  1.000000                  0.414753
# map00231                  1.000000                  0.988510
# map04261                  1.000000                  0.379586
# map00402                  0.565461                  0.290072
# map00410                  0.999734                  0.401527
#
#           CG1721_F/Wild_F p-value  CG1721_M/Wild_M p-value  \
# map04726                 1.000000                 0.271109
# map04150                 1.000000                 1.000000
# map04744                 0.639376                 0.737966
# map00982                 1.000000                 0.893964
# map05133                 1.000000                 1.000000
# map00909                 1.000000                 0.771661
# map00340                 1.000000                 1.000000
# map07033                 0.425693                 1.000000
# map00230                 0.985901                 1.000000
# map04142                 0.994549                 1.000000
# map04066                 1.000000                 0.947661
# map00945                 0.765081                 1.000000
# map00680                 0.992896                 1.000000
# map00565                 0.382028                 1.000000
# map05034                 0.978998                 1.000000
# map04978                 0.736222                 1.000000
# map00231                 0.511272                 0.563205
# map04261                 1.000000                 0.999973
# map00402                 0.138988                 0.307982
# map00410                 1.000000                 1.000000
#
#           CG7059_F/Wild_F p-value  CG7059_M/Wild_M p-value  \
# map04726                 1.000000                 1.000000
# map04150                 0.512576                 1.000000
# map04744                 0.954651                 1.000000
# map00982                 0.998835                 0.999008
# map05133                 0.934377                 0.958455
# map00909                 0.451782                 0.680236
# map00340                 0.997434                 0.486528
# map07033                 0.930377                 0.758578
# map00230                 1.000000                 0.972223
# map04142                 1.000000                 0.865854
# map04066                 0.946937                 0.154576
# map00945                 1.000000                 0.270464
# map00680                 1.000000                 0.416210
# map00565                 0.998277                 0.938012
# map05034                 1.000000                 0.927427
# map04978                 1.000000                 0.649205
# map00231                 1.000000                 0.847177
# map04261                 0.990730                 0.297966
# map00402                 0.998804                 0.997826
# map00410                 0.999870                 0.408216
#
#           CG5345_F/Wild_F p-value  ...  PiMP_KEGG CG18128_F/Wild_F comb_p  \
# map04726                 1.000000  ...                           0.999367
# map04150                 0.280968  ...                           0.785723
# map04744                 0.997815  ...                           1.000000
# map00982                 1.000000  ...                           0.998676
# map05133                 0.693855  ...                           0.999999
# map00909                 1.000000  ...                           0.503656
# map00340                 0.999890  ...                           0.997582
# map07033                 1.000000  ...                           1.000000
# map00230                 1.000000  ...                           1.000000
# map04142                 0.999926  ...                           0.756799
# map04066                 0.752697  ...                           1.000000
# map00945                 1.000000  ...                           1.000000
# map00680                 1.000000  ...                           1.000000
# map00565                 0.972769  ...                           0.697514
# map05034                 1.000000  ...                           0.925066
# map04978                 1.000000  ...                           1.000000
# map00231                 1.000000  ...                           1.000000
# map04261                 1.000000  ...                           1.000000
# map00402                 1.000000  ...                           0.513682
# map00410                 0.986839  ...                           0.991646
#
#           PiMP_KEGG CG18128_M/Wild_M comb_p  PiMP_KEGG CG1721_F/Wild_F comb_p  \
# map04726                           0.322921                          1.000000
# map04150                           1.000000                          1.000000
# map04744                           0.950517                          0.624098
# map00982                           0.548168                          1.000000
# map05133                           0.668611                          1.000000
# map00909                           0.100601                          1.000000
# map00340                           0.070777                          1.000000
# map07033                           0.267451                          0.368549
# map00230                           0.292890                          0.930586
# map04142                           0.902497                          0.963765
# map04066                           0.259927                          1.000000
# map00945                           0.615192                          0.823369
# map00680                           0.315033                          0.975659
# map00565                           0.737099                          0.286165
# map05034                           0.163449                          0.934005
# map04978                           0.166663                          0.445590
# map00231                           0.985689                          0.494712
# map04261                           0.253369                          1.000000
# map00402                           0.251506                          0.116800
# map00410                           0.105924                          0.999990
#
#           PiMP_KEGG CG1721_M/Wild_M comb_p  PiMP_KEGG CG7059_F/Wild_F comb_p  \
# map04726                          0.244589                          1.000000
# map04150                          1.000000                          0.484990
# map04744                          0.722779                          0.947947
# map00982                          0.847108                          0.997331
# map05133                          1.000000                          0.848830
# map00909                          0.759343                          0.442557
# map00340                          1.000000                          0.926923
# map07033                          1.000000                          0.902840
# map00230                          1.000000                          1.000000
# map04142                          1.000000                          1.000000
# map04066                          0.856009                          0.854507
# map00945                          1.000000                          1.000000
# map00680                          1.000000                          1.000000
# map00565                          1.000000                          0.995308
# map05034                          1.000000                          1.000000
# map04978                          1.000000                          1.000000
# map00231                          0.545796                          1.000000
# map04261                          0.999838                          0.974150
# map00402                          0.267904                          0.997817
# map00410                          1.000000                          0.995010
#
#           PiMP_KEGG CG7059_M/Wild_M comb_p  PiMP_KEGG CG5345_F/Wild_F comb_p  \
# map04726                          1.000000                          1.000000
# map04150                          1.000000                          0.261980
# map04744                          1.000000                          0.997120
# map00982                          0.997694                          1.000000
# map05133                          0.894516                          0.519340
# map00909                          0.667703                          1.000000
# map00340                          0.092725                          0.990181
# map07033                          0.704062                          1.000000
# map00230                          0.886017                          1.000000
# map04142                          0.649972                          0.998745
# map04066                          0.063534                          0.556154
# map00945                          0.351986                          1.000000
# map00680                          0.260931                          1.000000
# map00565                          0.892165                          0.946899
# map05034                          0.826622                          1.000000
# map04978                          0.351769                          1.000000
# map00231                          0.832363                          1.000000
# map04261                          0.188544                          1.000000
# map00402                          0.996196                          1.000000
# map00410                          0.109054                          0.879869
#
#           PiMP_KEGG CG5345_M/Wild_M comb_p  PiMP_KEGG CG6950_F/Wild_F comb_p  \
# map04726                          0.999948                          1.000000
# map04150                          1.000000                          0.184805
# map04744                          1.000000                          0.721858
# map00982                          1.000000                          1.000000
# map05133                          0.283130                          0.295786
# map00909                          1.000000                          0.999999
# map00340                          0.048171                          0.518355
# map07033                          0.777183                          1.000000
# map00230                          1.000000                          1.000000
# map04142                          0.155171                          0.960906
# map04066                          0.057788                          0.409257
# map00945                          0.450244                          1.000000
# map00680                          0.202109                          0.795243
# map00565                          0.337321                          0.175137
# map05034                          0.999715                          0.828753
# map04978                          0.476439                          0.992375
# map00231                          0.992880                          0.813743
# map04261                          0.845827                          0.807565
# map00402                          1.000000                          0.758899
# map00410                          0.053029                          0.671118
#
#           PiMP_KEGG CG6950_M/Wild_M comb_p
# map04726                          0.826646
# map04150                          0.631778
# map04744                          1.000000
# map00982                          0.862484
# map05133                          0.846859
# map00909                          0.858738
# map00340                          0.421720
# map07033                          0.723759
# map00230                          1.000000
# map04142                          0.340997
# map04066                          0.188235
# map00945                          0.715895
# map00680                          0.431781
# map00565                          0.539183
# map05034                          0.351872
# map04978                          0.352679
# map00231                          0.754423
# map04261                          1.000000
# map00402                          0.724533
# map00410                          0.503896
#
# [20 rows x 31 columns]

# %%
pathway_df.sort_values('PiMP_KEGG CG6950_F/Wild_F comb_p')[['pw_name', 'CG6950_F/Wild_F p-value', 'PiMP_KEGG CG6950_F/Wild_F comb_p']]
# Out:
#                                                pw_name  \
# map00790                           Folate biosynthesis
# map00740                         Riboflavin metabolism
# map00040      Pentose and glucuronate interconversions
# map00232                           Caffeine metabolism
# map04672  Intestinal immune network for IgA production
# ...                                                ...
# map00230                             Purine metabolism
# map07014                                    Quinolones
# map00944             Flavone and flavonol biosynthesis
# map00450                     Selenocompound metabolism
# map04726                          Serotonergic synapse
#
#           CG6950_F/Wild_F p-value  PiMP_KEGG CG6950_F/Wild_F comb_p
# map00790                 0.000757                          0.000160
# map00740                 0.010592                          0.002887
# map00040                 0.103460                          0.006346
# map00232                 0.016317                          0.007824
# map04672                 0.065819                          0.032722
# ...                           ...                               ...
# map00230                 1.000000                          1.000000
# map07014                 1.000000                          1.000000
# map00944                 1.000000                          1.000000
# map00450                 1.000000                          1.000000
# map04726                 1.000000                          1.000000
#
# [247 rows x 3 columns]
