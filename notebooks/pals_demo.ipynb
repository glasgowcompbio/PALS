# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib
import pickle

sys.path.append('../pals')

# %%
import pandas as pd

# %%
from pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, get_ms1_intensities, get_ms1_peaks, get_formula_df, get_experimental_design
from feature_extraction import DataSource
from pathway_analysis import PALS

# %% [markdown]
# # Load data

# %%
database_name = 'kegg'

# %% [markdown]
# Generate token by logging in to PiMP

# %%
# username = 'joewandy' # PiMP username
# password = 'enter' # PiMP password
# host = 'localhost:8000' # server address and port
# token = get_authentication_token(host, username, password)

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id = 1321 # example beer analysis

# %%
int_df_filename = os.path.join(os.getcwd(), 'test_data', 'int_df.p')
try:
    int_df = pd.read_pickle(int_df_filename)
except FileNotFoundError:
    int_df = get_ms1_intensities(token, PIMP_HOST, analysis_id)
    int_df.to_pickle(int_df_filename)

int_df.head()
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_ms1_intensities?analysis_id=1321 <Response [200]>
#          Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# 3033929        2.235291e+09        2.000478e+09        2.170697e+09
# 3033930        4.433491e+07        4.287387e+07        4.894853e+07
# 3033931        1.723985e+09        1.764235e+09        1.585143e+09
# 3033932        6.254237e+08        6.503417e+08        5.914975e+08
# 3033933        1.075022e+09        9.293474e+08        1.092635e+09
#
#          Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# 3033929        2.242760e+09        2.279882e+09        1.959480e+09
# 3033930        4.760448e+07        4.217280e+07        3.908452e+07
# 3033931        1.543961e+09        1.579320e+09        1.555666e+09
# 3033932        4.635929e+08        4.298382e+08        4.038747e+08
# 3033933        1.130720e+09        1.118146e+09        1.192834e+09
#
#          Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# 3033929        2.079356e+09        2.110473e+09        2.243653e+09
# 3033930        3.825778e+07        3.770192e+07        4.087189e+07
# 3033931        1.698130e+09        1.481824e+09        1.508645e+09
# 3033932        4.292837e+08        3.708761e+08        4.778932e+08
# 3033933        1.231442e+09        1.262046e+09        1.460653e+09
#
#          Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# 3033929        1.817065e+09        1.746443e+09        1.779827e+09
# 3033930        3.330477e+07        3.153630e+07        3.102410e+07
# 3033931        1.642510e+09        1.723919e+09        1.697806e+09
# 3033932        3.903165e+08        4.080995e+08        4.309892e+08
# 3033933        1.009838e+09        9.085111e+08        9.967176e+08

# %%
formula_df_filename = os.path.join(os.getcwd(), 'test_data', 'formula_df.p')
try:
    formula_df = pd.read_pickle(formula_df_filename)
except FileNotFoundError:
    formula_df = get_formula_df(token, PIMP_HOST, analysis_id, database_name, polarity='positive')
    formula_df.to_pickle(formula_df_filename)

formula_df.head()
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_ms1_peaks?analysis_id=1321 <Response [200]>
#          sec_id        mass          rt  polarity  cmpd_id  formula   adduct  \
# pid
# 3033929       1  116.070550  577.986827  positive        2  C5H9NO2      M+H
# 3036581    2653  157.097190  469.781817  positive        2  C5H9NO2  M+ACN+H
# 3036855    2927  157.097154  569.557760  positive        2  C5H9NO2  M+ACN+H
# 3033929       1  116.070550  577.986827  positive        3   C3H6O2  M+ACN+H
# 3033929       1  116.070550  577.986827  positive        5  C5H9NO2      M+H
#
#          identified     rc_id             compound    db identifier  \
# pid
# 3033929        True  15367697            L-Proline  kegg     C00148
# 3036581        True  15390527            L-Proline  kegg     C00148
# 3036855        True  15392569            L-Proline  kegg     C00148
# 3033929        True  15367700           Propanoate  kegg     C00163
# 3033929        True  15367704  3-Acetamidopropanal  kegg     C18170
#
#                                                frank_annot  \
# pid
# 3033929  {'frank_cmpd_name': 'L-Proline', 'inchikey': N...
# 3036581                                               None
# 3036855                                               None
# 3033929  {'frank_cmpd_name': 'L-Proline', 'inchikey': N...
# 3033929  {'frank_cmpd_name': 'L-Proline', 'inchikey': N...
#
#                             inchikey
# pid
# 3033929  ONIBWKKTOPOVIA-BYPYZUCNSA-N
# 3036581  ONIBWKKTOPOVIA-BYPYZUCNSA-N
# 3036855  ONIBWKKTOPOVIA-BYPYZUCNSA-N
# 3033929  XBDQKXXYIPTUBI-UHFFFAOYSA-N
# 3033929  ARJPPNFIEQKVBB-UHFFFAOYSA-N

# %%
experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
try:
    experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
    with open(experimental_design_filename, 'rb') as f:
        experimental_design = pickle.load(f)
except FileNotFoundError:
    experimental_design = get_experimental_design(token, PIMP_HOST, analysis_id)
    with open(experimental_design_filename, 'wb') as f:
        pickle.dump(experimental_design, f)
        
experimental_design
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_experimental_design?analysis_id=1321 <Response [200]>
# {'comparisons': [{'case': 'beer1', 'control': 'beer2', 'name': 'beer1/beer2'},
#   {'case': 'beer3', 'control': 'beer4', 'name': 'beer3/beer4'}],
#  'groups': {'beer4': ['Beer_4_full3.mzXML',
#    'Beer_4_full2.mzXML',
#    'Beer_4_full1.mzXML'],
#   'beer3': ['Beer_3_full3.mzXML', 'Beer_3_full2.mzXML', 'Beer_3_full1.mzXML'],
#   'beer2': ['Beer_2_full3.mzXML', 'Beer_2_full1.mzXML', 'Beer_2_full2.mzXML'],
#   'beer1': ['Beer_1_full2.mzXML', 'Beer_1_full1.mzXML', 'Beer_1_full3.mzXML']}}

# %% [markdown]
# # Set-up KEGG Data Source

# %%
ds = DataSource(int_df, formula_df, experimental_design, database_name)
# Out:
# 2019-10-29 16:04:55.694 | DEBUG    | feature_extraction:__init__:24 - Loading C:\Users\joewa\Work\git\PALS\pals\data\kegg.json

# %% [markdown]
# # Set-up PALS Analysis

# %%
pals = PALS(ds, min_intensity=5000, num_resamples=500)

# %%
activity_df = pals.get_plage_activity_df()
activity_df
# Out:
# 2019-10-29 16:04:56.855 | DEBUG    | pathway_analysis:_change_zero_peak_ints:232 - Setting the zero intensity values in the dataframe
# 2019-10-29 16:04:56.888 | DEBUG    | pathway_analysis:_standardize_intensity_df:205 - Scaling the data across the sample: zero mean and unit variance
# 2019-10-29 16:04:56.897 | DEBUG    | pathway_analysis:_standardize_intensity_df:218 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-10-29 16:04:56.898 | DEBUG    | pathway_analysis:_standardize_intensity_df:219 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
#                                                        pw name  \
# Pathway ids
# map05204                               Chemical carcinogenesis
# map00945     Stilbenoid, diarylheptanoid and gingerol biosy...
# map05133                                             Pertussis
# map00630               Glyoxylate and dicarboxylate metabolism
# map04971                                Gastric acid secretion
# ...                                                        ...
# map00061                               Fatty acid biosynthesis
# map00633                              Nitrotoluene degradation
# map00460                            Cyanoamino acid metabolism
# map07229     Angiotensin receptor and endothelin receptor a...
# map05032                                    Morphine addiction
#
#              Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# Pathway ids
# map05204               0.122196           -0.024922            0.163056
# map00945               0.041457           -0.134889            0.060969
# map05133               0.678897            0.635445            0.511368
# map00630               0.135207            0.095897            0.097274
# map04971               0.150060           -0.537054            0.361751
# ...                         ...                 ...                 ...
# map00061              -0.681530           -1.260187           -0.157384
# map00633               0.035434           -0.052081            0.113923
# map00460              -0.114333           -0.153257           -0.138454
# map07229              -0.319186            0.194753            0.653303
# map05032               0.050742            0.239624           -0.030185
#
#              Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# Pathway ids
# map05204              -0.372108           -0.435128           -0.474277
# map00945              -0.216975           -0.192954           -0.106657
# map05133               0.152206            0.146002            0.152419
# map00630              -0.296609           -0.370700           -0.294633
# map04971               0.507736            0.093939            0.725309
# ...                         ...                 ...                 ...
# map00061               0.429501           -0.005009            0.805965
# map00633              -0.169521           -0.280401           -0.320492
# map00460               0.324407            0.303574            0.311525
# map07229               0.152896           -0.032244            0.660872
# map05032              -0.260724           -0.045430           -0.030411
#
#              Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# Pathway ids
# map05204              -0.262568           -0.282725           -0.138195
# map00945              -0.468973           -0.488755           -0.294233
# map05133              -0.021038           -0.063060           -0.049718
# map00630              -0.364338           -0.364911           -0.370765
# map04971               0.185912            0.347716            0.384850
# ...                         ...                 ...                 ...
# map00061              -0.211665            0.116893            1.054955
# map00633              -0.514672           -0.529943           -0.316949
# map00460               0.353373            0.402342            0.333251
# map07229               0.437385            0.143903            0.822189
# map05032               0.609646            0.733093            0.344159
#
#              Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# Pathway ids
# map05204               0.474577            0.544222            0.685873
# map00945               0.342099            0.668985            0.789926
# map05133              -0.767651           -0.590952           -0.783917
# map00630               0.576299            0.552414            0.604864
# map04971              -0.860628           -0.761720           -0.597871
# ...                         ...                 ...                 ...
# map00061              -0.445789           -0.108412            0.462661
# map00633               0.580656            0.648879            0.805167
# map00460              -0.525004           -0.533766           -0.563659
# map07229              -1.162649           -0.910977           -0.640243
# map05032              -0.405154           -0.568365           -0.636996
#
# [229 rows x 13 columns]

# %%
plage_df = pals.set_up_resample_plage_p_df(activity_df)
plage_df
# Out:
# 2019-10-29 16:04:58.002 | INFO     | pathway_analysis:set_up_resample_plage_p_df:58 - Calculating plage p-values with resampling
# 2019-10-29 16:04:58.002 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:62 - Comparison beer1/beer2
# 2019-10-29 16:04:58.003 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 0/500
# 2019-10-29 16:05:24.273 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 100/500
# 2019-10-29 16:05:50.971 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 200/500
# 2019-10-29 16:06:18.554 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 300/500
# 2019-10-29 16:06:45.341 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 400/500
# 2019-10-29 16:07:12.982 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:76 - Total time 134
# 2019-10-29 16:07:13.493 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:62 - Comparison beer3/beer4
# 2019-10-29 16:07:13.494 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 0/500
# 2019-10-29 16:07:41.586 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 100/500
# 2019-10-29 16:08:07.160 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 200/500
# 2019-10-29 16:08:34.306 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 300/500
# 2019-10-29 16:09:01.516 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 400/500
# 2019-10-29 16:09:28.821 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:76 - Total time 135
# 2019-10-29 16:09:29.294 | INFO     | pathway_analysis:calculate_coverage_df:305 - Calculating dataset formula coverage
#                                                     pw_name  \
# mapids
# map05204                            Chemical carcinogenesis
# map00945  Stilbenoid, diarylheptanoid and gingerol biosy...
# map05133                                          Pertussis
# map00630            Glyoxylate and dicarboxylate metabolism
# map04971                             Gastric acid secretion
# ...                                                     ...
# map00061                            Fatty acid biosynthesis
# map00633                           Nitrotoluene degradation
# map00460                         Cyanoamino acid metabolism
# map07229  Angiotensin receptor and endothelin receptor a...
# map05032                                 Morphine addiction
#
#           beer1/beer2 p-value  beer3/beer4 p-value  unq_pw_F  tot_ds_F  \
# mapids
# map05204             0.184515             0.081708        78        26
# map00945             0.665306             0.129836        25         9
# map05133             0.164547             0.076483         5         1
# map00630             0.107260             0.012073        48        13
# map04971             1.000000             0.076050        13         2
# ...                       ...                  ...       ...       ...
# map00061             0.516708             1.000000        10         1
# map00633             0.318740             0.070304        19         8
# map00460             0.055540             0.018800        40        30
# map07229             1.000000             0.164432         3         1
# map05032             0.904139             0.102765         8         3
#
#           F_coverage
# mapids
# map05204       33.33
# map00945       36.00
# map05133       20.00
# map00630       27.08
# map04971       15.38
# ...              ...
# map00061       10.00
# map00633       42.11
# map00460       75.00
# map07229       33.33
# map05032       37.50
#
# [229 rows x 6 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'plage_df.csv')
plage_df.to_csv(output)
output
# Out:
# 'C:\\Users\\joewa\\Work\\git\\PALS\\notebooks\\test_data\\plage_df.csv'

# %%
pathway_df = pals.calculate_hg_values(plage_df)
# Out:
# 2019-10-29 16:09:47.615 | INFO     | pathway_analysis:calculate_hg_values:137 - Calculating the hyper-geometric p-values
# 2019-10-29 16:09:47.819 | INFO     | pathway_analysis:calculate_hg_values:162 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                                     pw_name  \
# map05204                            Chemical carcinogenesis
# map00945  Stilbenoid, diarylheptanoid and gingerol biosy...
# map05133                                          Pertussis
# map00630            Glyoxylate and dicarboxylate metabolism
# map04971                             Gastric acid secretion
# ...                                                     ...
# map00061                            Fatty acid biosynthesis
# map00633                           Nitrotoluene degradation
# map00460                         Cyanoamino acid metabolism
# map07229  Angiotensin receptor and endothelin receptor a...
# map05032                                 Morphine addiction
#
#           beer1/beer2 p-value  beer3/beer4 p-value  unq_pw_F  tot_ds_F  \
# map05204             0.184515             0.081708        78        26
# map00945             0.665306             0.129836        25         9
# map05133             0.164547             0.076483         5         1
# map00630             0.107260             0.012073        48        13
# map04971             1.000000             0.076050        13         2
# ...                       ...                  ...       ...       ...
# map00061             0.516708             1.000000        10         1
# map00633             0.318740             0.070304        19         8
# map00460             0.055540             0.018800        40        30
# map07229             1.000000             0.164432         3         1
# map05032             0.904139             0.102765         8         3
#
#           F_coverage            sf  exp_F  Ex_Cov  beer1/beer2 comb_p  \
# map05204       33.33  4.527451e-02  19.68   25.23            0.112608
# map00945       36.00  9.455884e-02   6.31   25.24            0.564015
# map05133       20.00  4.715615e-01   1.26   25.20            0.165779
# map00630       27.08  3.445729e-01  12.11   25.23            0.097560
# map04971       15.38  7.260156e-01   3.28   25.23            1.000000
# ...              ...           ...    ...     ...                 ...
# map00061       10.00  8.080971e-01   2.52   25.20            0.583899
# map00633       42.11  4.261595e-02   4.79   25.21            0.211968
# map00460       75.00  1.326647e-11  10.09   25.22            0.002056
# map07229       33.33  2.654903e-01   0.76   25.33            1.000000
# map05032       37.50  1.696760e-01   2.02   25.25            0.862752
#
#           beer3/beer4 comb_p
# map05204            0.044703
# map00945            0.086470
# map05133            0.078480
# map00630            0.011026
# map04971            0.099132
# ...                      ...
# map00061            1.000000
# map00633            0.037338
# map00460            0.000410
# map07229            0.140001
# map05032            0.076538
#
# [229 rows x 11 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'pathway_df.csv')
pathway_df.to_csv(output)
output
# Out:
# 'C:\\Users\\joewa\\Work\\git\\PALS\\notebooks\\test_data\\pathway_df.csv'
