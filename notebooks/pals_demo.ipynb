# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib

sys.path.append('../pals')

# %%
import pandas as pd

# %%
from pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, get_ms1_intensities, get_ms1_peaks, get_formula_df
from feature_extraction import DataSource
from pathway_analysis import PALS

# %% [markdown]
# # Load data

# %% [markdown]
# Generate token by logging in to PiMP

# %%
# username = 'joewandy' # PiMP username
# password = 'enter' # PiMP password
# host = 'localhost:8000' # server address and port
# token = get_authentication_token(host, username, password)

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id = 1321 # example beer analysis

# %%
int_df_filename = os.path.join(os.getcwd(), 'test_data', 'int_df.p')
try:
    int_df = pd.read_pickle(int_df_filename)
except FileNotFoundError:
    int_df = get_ms1_intensities(token, PIMP_HOST, analysis_id)
    int_df.to_pickle(int_df_filename)

int_df.head()
# Out:
#          Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# 3033929        2.235291e+09        2.000478e+09        2.170697e+09
# 3033930        4.433491e+07        4.287387e+07        4.894853e+07
# 3033931        1.723985e+09        1.764235e+09        1.585143e+09
# 3033932        6.254237e+08        6.503417e+08        5.914975e+08
# 3033933        1.075022e+09        9.293474e+08        1.092635e+09
#
#          Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# 3033929        2.242760e+09        2.279882e+09        1.959480e+09
# 3033930        4.760448e+07        4.217280e+07        3.908452e+07
# 3033931        1.543961e+09        1.579320e+09        1.555666e+09
# 3033932        4.635929e+08        4.298382e+08        4.038747e+08
# 3033933        1.130720e+09        1.118146e+09        1.192834e+09
#
#          Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# 3033929        2.079356e+09        2.110473e+09        2.243653e+09
# 3033930        3.825778e+07        3.770192e+07        4.087189e+07
# 3033931        1.698130e+09        1.481824e+09        1.508645e+09
# 3033932        4.292837e+08        3.708761e+08        4.778932e+08
# 3033933        1.231442e+09        1.262046e+09        1.460653e+09
#
#          Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# 3033929        1.817065e+09        1.746443e+09        1.779827e+09
# 3033930        3.330477e+07        3.153630e+07        3.102410e+07
# 3033931        1.642510e+09        1.723919e+09        1.697806e+09
# 3033932        3.903165e+08        4.080995e+08        4.309892e+08
# 3033933        1.009838e+09        9.085111e+08        9.967176e+08

# %%
int_df.loc[3040968]
# Out:
# Beer_1_full1.mzXML    191345.43750
# Beer_1_full2.mzXML    114476.37500
# Beer_1_full3.mzXML    135545.34375
# Beer_2_full1.mzXML             NaN
# Beer_2_full2.mzXML             NaN
# Beer_2_full3.mzXML             NaN
# Beer_3_full1.mzXML             NaN
# Beer_3_full2.mzXML             NaN
# Beer_3_full3.mzXML             NaN
# Beer_4_full1.mzXML             NaN
# Beer_4_full2.mzXML             NaN
# Beer_4_full3.mzXML             NaN
# Name: 3040968, dtype: float64

# %%
formula_df_filename = os.path.join(os.getcwd(), 'test_data', 'formula_df.p')
try:
    formula_df = pd.read_pickle(formula_df_filename)
except FileNotFoundError:
    formula_df = get_formula_df(token, PIMP_HOST, analysis_id)
    formula_df.to_pickle('formula_df.p')

formula_df.head()
# Out:
#            db identifier  formula
# pid
# 3033929  hmdb  HMDB34208  C5H9NO2
# 3036581  hmdb  HMDB34208  C5H9NO2
# 3036855  hmdb  HMDB34208  C5H9NO2
# 3038249  hmdb  HMDB34208  C5H9NO2
# 3033929  hmdb  HMDB00162  C5H9NO2

# %%
experiment_design = {
    'groups': {
        'beer1': ['Beer_1_full1.mzXML', 'Beer_1_full2.mzXML', 'Beer_1_full3.mzXML'],
        'beer2': ['Beer_2_full1.mzXML', 'Beer_2_full2.mzXML', 'Beer_2_full3.mzXML'],
        'beer3': ['Beer_3_full1.mzXML', 'Beer_3_full2.mzXML', 'Beer_3_full3.mzXML'],
        'beer4': ['Beer_4_full1.mzXML', 'Beer_4_full2.mzXML', 'Beer_4_full3.mzXML'],
    },
    'comparisons': [
        {
            'name': 'beer1/beer2',
            'case': 'beer1',
            'control': 'beer2'
        },        
        {
            'name': 'beer3/beer4',
            'case': 'beer3',
            'control': 'beer4'
        },                
    ]
}

# %% [markdown]
# # Set-up PALS Analysis

# %%
ds = DataSource(int_df, formula_df, experiment_design, database_name='kegg')
# Out:
# 2019-09-25 13:38:45.636 | DEBUG    | feature_extraction:__init__:24 - Loading C:\Users\joewa\Work\git\PALS\pals\data\kegg.json

# %%
pals = PALS(ds, min_intensity=5000, num_resamples=500)

# %%
activity_df = pals.get_plage_activity_df()
activity_df
# Out:
# 2019-09-25 13:38:46.845 | DEBUG    | pathway_analysis:_change_zero_peak_ints:232 - Setting the zero intensity values in the dataframe
# 2019-09-25 13:38:46.873 | DEBUG    | pathway_analysis:_standardize_intensity_df:205 - Scaling the data across the sample: zero mean and unit variance
# 2019-09-25 13:38:46.880 | DEBUG    | pathway_analysis:_standardize_intensity_df:218 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-09-25 13:38:46.881 | DEBUG    | pathway_analysis:_standardize_intensity_df:219 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
#                                       pw name  Beer_1_full1.mzXML  \
# Pathway ids
# ingenza00007     IG-Amino-acid Biosynthesis 2            0.263669
# map01051           Biosynthesis of ansamycins            0.253022
# map00402           Benzoxazinoid biosynthesis           -0.736055
# map04976                       Bile secretion           -0.352355
# map00900      Terpenoid backbone biosynthesis            0.504266
# ...                                       ...                 ...
# map00640                Propanoate metabolism           -0.524332
# map04111                   Cell cycle - yeast           -0.006434
# map07011                          Penicillins            0.227627
# map00010         Glycolysis / Gluconeogenesis            0.296674
# map00062                Fatty acid elongation           -0.319961
#
#               Beer_1_full2.mzXML  Beer_1_full3.mzXML  Beer_2_full1.mzXML  \
# Pathway ids
# ingenza00007            0.187365            0.306593           -0.460182
# map01051                0.308315            0.250116           -0.208555
# map00402               -0.597802           -0.685732            0.437853
# map04976               -0.441831           -0.315502            0.255690
# map00900                0.469856            0.541813           -0.456269
# ...                          ...                 ...                 ...
# map00640               -0.373759           -0.451440            0.242844
# map04111                0.160731            0.100175            0.397342
# map07011               -0.292492            0.159689            0.234420
# map00010                0.283708            0.340206            0.330664
# map00062                0.510557            0.299951            0.311231
#
#               Beer_2_full2.mzXML  Beer_2_full3.mzXML  Beer_3_full1.mzXML  \
# Pathway ids
# ingenza00007           -0.533728           -0.532693           -0.159428
# map01051               -0.280498           -0.214890            0.379466
# map00402                0.511491            0.504818           -0.235427
# map04976                0.208314            0.207608           -0.354780
# map00900               -0.502469           -0.376558           -0.011178
# ...                          ...                 ...                 ...
# map00640                0.294527            0.269335           -0.261373
# map04111                0.296042            0.278561            0.333344
# map07011                0.000646           -0.151676           -0.598995
# map00010                0.338202            0.244056            0.025705
# map00062                0.082720           -0.309495            0.252601
#
#               Beer_3_full2.mzXML  Beer_3_full3.mzXML  Beer_4_full1.mzXML  \
# Pathway ids
# ingenza00007           -0.221997           -0.026864            0.342805
# map01051                0.400231            0.531792           -0.580774
# map00402               -0.193896           -0.299671            0.476862
# map04976               -0.389102           -0.269384            0.497308
# map00900               -0.004378            0.075747           -0.078900
# ...                          ...                 ...                 ...
# map00640               -0.205368           -0.396562            0.506947
# map04111                0.269441            0.602917           -0.857337
# map07011               -0.918964           -0.801896            0.344107
# map00010                0.031351            0.117860           -0.659264
# map00062                0.249898            0.553824           -0.569508
#
#               Beer_4_full2.mzXML  Beer_4_full3.mzXML
# Pathway ids
# ingenza00007            0.393389            0.441071
# map01051               -0.492698           -0.345526
# map00402                0.403499            0.414060
# map04976                0.494296            0.459740
# map00900               -0.156159           -0.005771
# ...                          ...                 ...
# map00640                0.528012            0.371169
# map04111               -0.758894           -0.815887
# map07011                0.876485            0.921050
# map00010               -0.684640           -0.664522
# map00062               -0.582820           -0.478997
#
# [238 rows x 13 columns]

# %%
plage_df = pals.set_up_resample_plage_p_df(activity_df)
plage_df
# Out:
# 2019-09-25 13:38:48.077 | INFO     | pathway_analysis:set_up_resample_plage_p_df:58 - Calculating plage p-values with resampling
# 2019-09-25 13:38:48.078 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:62 - Comparison beer1/beer2
# 2019-09-25 13:38:48.078 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 0/500
# 2019-09-25 13:39:13.607 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 100/500
# 2019-09-25 13:39:39.537 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 200/500
# 2019-09-25 13:40:06.098 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 300/500
# 2019-09-25 13:40:32.054 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 400/500
# 2019-09-25 13:40:58.057 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:76 - Total time 129
# 2019-09-25 13:40:58.533 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:62 - Comparison beer3/beer4
# 2019-09-25 13:40:58.533 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 0/500
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# 2019-09-25 13:41:25.078 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 100/500
# 2019-09-25 13:41:50.029 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 200/500
# 2019-09-25 13:42:15.751 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 300/500
# 2019-09-25 13:42:40.695 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 400/500
# 2019-09-25 13:43:06.275 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:76 - Total time 127
# 2019-09-25 13:43:06.662 | INFO     | pathway_analysis:calculate_coverage_df:305 - Calculating dataset formula coverage
#                                       pw_name  beer1/beer2 p-value  \
# mapids
# ingenza00007     IG-Amino-acid Biosynthesis 2             0.094049
# map01051           Biosynthesis of ansamycins             0.098259
# map00402           Benzoxazinoid biosynthesis             0.072554
# map04976                       Bile secretion             0.110940
# map00900      Terpenoid backbone biosynthesis             0.078358
# ...                                       ...                  ...
# map00640                Propanoate metabolism             0.104791
# map04111                   Cell cycle - yeast             0.351059
# map07011                          Penicillins             1.000000
# map00010         Glycolysis / Gluconeogenesis             1.000000
# map00062                Fatty acid elongation             1.000000
#
#               beer3/beer4 p-value  unq_pw_F  tot_ds_F  F_coverage
# mapids
# ingenza00007             0.107099         6         6      100.00
# map01051                 0.070697        30         5       16.67
# map00402                 0.044092         9         6       66.67
# map04976                 0.034324        89        25       28.09
# map00900                 0.644828        31         6       19.35
# ...                           ...       ...       ...         ...
# map00640                 0.084376        28        16       57.14
# map04111                 0.066734         2         0        0.00
# map07011                 0.126603         2         1       50.00
# map00010                 0.028392        20         8       40.00
# map00062                 0.096025        28         2        7.14
#
# [238 rows x 6 columns]

# %%
pathway_df = pals.calculate_hg_values(plage_df)
# Out:
# 2019-09-25 13:43:06.741 | INFO     | pathway_analysis:calculate_hg_values:137 - Calculating the hyper-geometric p-values
# 2019-09-25 13:43:06.910 | INFO     | pathway_analysis:calculate_hg_values:162 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                       pw_name  beer1/beer2 p-value  \
# ingenza00007     IG-Amino-acid Biosynthesis 2             0.094049
# map01051           Biosynthesis of ansamycins             0.098259
# map00402           Benzoxazinoid biosynthesis             0.072554
# map04976                       Bile secretion             0.110940
# map00900      Terpenoid backbone biosynthesis             0.078358
# ...                                       ...                  ...
# map00640                Propanoate metabolism             0.104791
# map04111                   Cell cycle - yeast             0.351059
# map07011                          Penicillins             1.000000
# map00010         Glycolysis / Gluconeogenesis             1.000000
# map00062                Fatty acid elongation             1.000000
#
#               beer3/beer4 p-value  unq_pw_F  tot_ds_F  F_coverage        sf  \
# ingenza00007             0.107099         6         6      100.00  0.000170
# map01051                 0.070697        30         5       16.67  0.922740
# map00402                 0.044092         9         6       66.67  0.008556
# map04976                 0.034324        89        25       28.09  0.550742
# map00900                 0.644828        31         6       19.35  0.863634
# ...                           ...       ...       ...         ...       ...
# map00640                 0.084376        28        16       57.14  0.000789
# map04111                 0.066734         2         0        0.00  0.642338
# map07011                 0.126603         2         1       50.00  0.203509
# map00010                 0.028392        20         8       40.00  0.124076
# map00062                 0.096025        28         2        7.14  0.996226
#
#               exp_F  Ex_Cov  beer1/beer2 comb_p  beer3/beer4 comb_p
# ingenza00007   1.74   29.00            0.023109            0.027384
# map01051       8.70   29.00            0.161764            0.122446
# map00402       2.61   29.00            0.028958            0.016196
# map04976      25.82   29.01            0.120436            0.039173
# map00900       8.99   29.00            0.120277            0.718800
# ...             ...     ...                 ...                 ...
# map00640       8.12   29.00            0.032152            0.024464
# map04111       0.58   29.00            0.380751            0.080772
# map07011       0.58   29.00            1.000000            0.099743
# map00010       5.80   29.00            1.000000            0.018109
# map00062       8.12   29.00            1.000000            0.225047
#
# [238 rows x 11 columns]
