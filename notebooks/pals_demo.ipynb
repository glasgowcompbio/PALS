# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib
import pickle

sys.path.append('../pals')

# %%
import pandas as pd

# %%
from pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, get_ms1_intensities, get_ms1_peaks, get_formula_df, get_experimental_design
from feature_extraction import DataSource
from pathway_analysis import PALS

# %% [markdown]
# # Load data

# %% [markdown]
# Generate token by logging in to PiMP

# %%
# username = 'joewandy' # PiMP username
# password = 'enter' # PiMP password
# host = 'localhost:8000' # server address and port
# token = get_authentication_token(host, username, password)

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id = 1321 # example beer analysis

# %%
int_df_filename = os.path.join(os.getcwd(), 'test_data', 'int_df.p')
try:
    int_df = pd.read_pickle(int_df_filename)
except FileNotFoundError:
    int_df = get_ms1_intensities(token, PIMP_HOST, analysis_id)
    int_df.to_pickle(int_df_filename)

int_df.head()
# Out:
#          Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# 3033929        2.235291e+09        2.000478e+09        2.170697e+09
# 3033930        4.433491e+07        4.287387e+07        4.894853e+07
# 3033931        1.723985e+09        1.764235e+09        1.585143e+09
# 3033932        6.254237e+08        6.503417e+08        5.914975e+08
# 3033933        1.075022e+09        9.293474e+08        1.092635e+09
#
#          Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# 3033929        2.242760e+09        2.279882e+09        1.959480e+09
# 3033930        4.760448e+07        4.217280e+07        3.908452e+07
# 3033931        1.543961e+09        1.579320e+09        1.555666e+09
# 3033932        4.635929e+08        4.298382e+08        4.038747e+08
# 3033933        1.130720e+09        1.118146e+09        1.192834e+09
#
#          Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# 3033929        2.079356e+09        2.110473e+09        2.243653e+09
# 3033930        3.825778e+07        3.770192e+07        4.087189e+07
# 3033931        1.698130e+09        1.481824e+09        1.508645e+09
# 3033932        4.292837e+08        3.708761e+08        4.778932e+08
# 3033933        1.231442e+09        1.262046e+09        1.460653e+09
#
#          Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# 3033929        1.817065e+09        1.746443e+09        1.779827e+09
# 3033930        3.330477e+07        3.153630e+07        3.102410e+07
# 3033931        1.642510e+09        1.723919e+09        1.697806e+09
# 3033932        3.903165e+08        4.080995e+08        4.309892e+08
# 3033933        1.009838e+09        9.085111e+08        9.967176e+08

# %%
formula_df_filename = os.path.join(os.getcwd(), 'test_data', 'formula_df.p')
try:
    formula_df = pd.read_pickle(formula_df_filename)
except FileNotFoundError:
    formula_df = get_formula_df(token, PIMP_HOST, analysis_id)
    formula_df.to_pickle('formula_df.p')

formula_df.head()
# Out:
#            db identifier  formula
# pid
# 3033929  hmdb  HMDB34208  C5H9NO2
# 3036581  hmdb  HMDB34208  C5H9NO2
# 3036855  hmdb  HMDB34208  C5H9NO2
# 3038249  hmdb  HMDB34208  C5H9NO2
# 3033929  hmdb  HMDB00162  C5H9NO2

# %%
experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
try:
    experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
    with open(experimental_design_filename, 'rb') as f:
        experimental_design = pickle.load(f)
except FileNotFoundError:
    experimental_design = get_experimental_design(token, PIMP_HOST, analysis_id)
    with open(experimental_design_filename, 'wb') as f:
        pickle.dump(experimental_design, f)

# %%
experimental_design
# Out:
# {'comparisons': [{'case': 'beer1', 'control': 'beer2', 'name': 'beer1/beer2'},
#   {'case': 'beer3', 'control': 'beer4', 'name': 'beer3/beer4'}],
#  'groups': {'beer4': ['Beer_4_full3.mzXML',
#    'Beer_4_full2.mzXML',
#    'Beer_4_full1.mzXML'],
#   'beer3': ['Beer_3_full3.mzXML', 'Beer_3_full2.mzXML', 'Beer_3_full1.mzXML'],
#   'beer2': ['Beer_2_full3.mzXML', 'Beer_2_full1.mzXML', 'Beer_2_full2.mzXML'],
#   'beer1': ['Beer_1_full2.mzXML', 'Beer_1_full1.mzXML', 'Beer_1_full3.mzXML']}}

# %% [markdown]
# # Set-up PALS Analysis

# %%
ds = DataSource(int_df, formula_df, experimental_design, database_name='kegg')
# Out:
# 2019-10-28 11:26:55.446 | DEBUG    | feature_extraction:__init__:24 - Loading C:\Users\joewa\Work\git\PALS\pals\data\kegg.json

# %%
pals = PALS(ds, min_intensity=5000, num_resamples=500)

# %%
activity_df = pals.get_plage_activity_df()
activity_df
# Out:
# 2019-10-28 11:27:01.777 | DEBUG    | pathway_analysis:_change_zero_peak_ints:232 - Setting the zero intensity values in the dataframe
# 2019-10-28 11:27:01.859 | DEBUG    | pathway_analysis:_standardize_intensity_df:205 - Scaling the data across the sample: zero mean and unit variance
# 2019-10-28 11:27:01.880 | DEBUG    | pathway_analysis:_standardize_intensity_df:218 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-10-28 11:27:01.884 | DEBUG    | pathway_analysis:_standardize_intensity_df:219 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
#                                                        pw name  \
# Pathway ids
# map05143                               African trypanosomiasis
# map00350                                   Tyrosine metabolism
# map00471                D-Glutamine and D-glutamate metabolism
# map04915                            Estrogen signaling pathway
# map00642                              Ethylbenzene degradation
# ...                                                        ...
# map04070                 Phosphatidylinositol signaling system
# map04111                                    Cell cycle - yeast
# map04723                  Retrograde endocannabinoid signaling
# map07225     Glucocorticoid and meneralocorticoid receptor ...
# map04974                      Protein digestion and absorption
#
#              Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# Pathway ids
# map05143               0.037773           -0.184129            0.055488
# map00350               0.289527            0.362744            0.252238
# map00471               0.291376            0.139590            0.207059
# map04915               0.144515            0.175845            0.225877
# map00642              -0.246150           -0.163631           -0.258231
# ...                         ...                 ...                 ...
# map04070              -0.404419           -0.421453           -0.414690
# map04111              -0.006434            0.160731            0.100175
# map04723               0.062923            0.020491            0.102829
# map07225               0.963967            0.934091            0.875042
# map04974              -0.230327           -0.193480           -0.164986
#
#              Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# Pathway ids
# map05143              -0.430682           -0.369160           -0.501579
# map00350              -0.295386           -0.222753           -0.154678
# map00471              -0.314899           -0.449626           -0.408032
# map04915              -0.464802           -0.455986           -0.459414
# map00642               0.592905            0.618916            0.637517
# ...                         ...                 ...                 ...
# map04070              -0.351470           -0.351817           -0.248602
# map04111               0.397342            0.296042            0.278561
# map04723              -0.349890           -0.360309           -0.379749
# map07225              -0.421650           -0.544690           -0.389231
# map04974               0.496209            0.505827            0.497679
#
#              Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# Pathway ids
# map05143              -0.357647           -0.163865           -0.108555
# map00350               0.381827            0.410490            0.301220
# map00471              -0.450940           -0.535296           -0.322498
# map04915              -0.492532           -0.464295           -0.442494
# map00642              -0.240181           -0.260303           -0.332467
# ...                         ...                 ...                 ...
# map04070               0.003240            0.041895            0.006014
# map04111               0.333344            0.269441            0.602917
# map04723              -0.413356           -0.355344           -0.405105
# map07225              -0.105968           -0.174625           -0.267033
# map04974               0.223330            0.249073            0.295059
#
#              Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# Pathway ids
# map05143               0.652512            0.679081            0.690762
# map00350              -0.438664           -0.452152           -0.434414
# map00471               0.506672            0.594792            0.741803
# map04915               0.688366            0.753994            0.790926
# map00642              -0.071048           -0.142688           -0.134639
# ...                         ...                 ...                 ...
# map04070               0.694027            0.737845            0.709431
# map04111              -0.857337           -0.758894           -0.815887
# map04723               0.671274            0.697594            0.708640
# map07225              -0.358778           -0.241596           -0.269529
# map04974              -0.516289           -0.574272           -0.587822
#
# [238 rows x 13 columns]

# %%
plage_df = pals.set_up_resample_plage_p_df(activity_df)
plage_df
# Out:
# 2019-10-28 11:27:07.530 | INFO     | pathway_analysis:set_up_resample_plage_p_df:58 - Calculating plage p-values with resampling
# 2019-10-28 11:27:07.532 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:62 - Comparison beer1/beer2
# 2019-10-28 11:27:07.533 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 0/500
# 2019-10-28 11:28:20.736 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 100/500
# 2019-10-28 11:29:31.002 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 200/500
# 2019-10-28 11:30:44.483 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 300/500
# 2019-10-28 11:32:00.988 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 400/500
# 2019-10-28 11:33:17.307 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:76 - Total time 369
# 2019-10-28 11:33:18.592 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:62 - Comparison beer3/beer4
# 2019-10-28 11:33:18.593 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 0/500
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# c:\users\joewa\.virtualenvs\pals-4ls44jcw\lib\site-packages\scipy\stats\_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# 2019-10-28 11:34:34.819 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 100/500
# 2019-10-28 11:35:49.636 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 200/500
# 2019-10-28 11:37:05.655 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 300/500
# 2019-10-28 11:38:20.299 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:70 - Resampling 400/500
# 2019-10-28 11:39:35.324 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:76 - Total time 376
# 2019-10-28 11:39:36.450 | INFO     | pathway_analysis:calculate_coverage_df:305 - Calculating dataset formula coverage
#                                                     pw_name  \
# mapids
# map05143                            African trypanosomiasis
# map00350                                Tyrosine metabolism
# map00471             D-Glutamine and D-glutamate metabolism
# map04915                         Estrogen signaling pathway
# map00642                           Ethylbenzene degradation
# ...                                                     ...
# map04070              Phosphatidylinositol signaling system
# map04111                                 Cell cycle - yeast
# map04723               Retrograde endocannabinoid signaling
# map07225  Glucocorticoid and meneralocorticoid receptor ...
# map04974                   Protein digestion and absorption
#
#           beer1/beer2 p-value  beer3/beer4 p-value  unq_pw_F  tot_ds_F  \
# mapids
# map05143             0.294516             0.076869         7         3
# map00350             0.149899             0.030247        53        42
# map00471             0.149042             0.078429         7         4
# map04915             0.067900             0.021456         7         1
# map00642             0.070062             0.233091        14        10
# ...                       ...                  ...       ...       ...
# map04070             0.501927             0.019880         9         2
# map04111             0.350552             0.071888         2         0
# map04723             0.098977             0.014790        15         7
# map07225             0.071042             0.703851         3         2
# map04974             0.053616             0.027042        42        28
#
#           F_coverage
# mapids
# map05143       42.86
# map00350       79.25
# map00471       57.14
# map04915       14.29
# map00642       71.43
# ...              ...
# map04070       22.22
# map04111        0.00
# map04723       46.67
# map07225       66.67
# map04974       66.67
#
# [238 rows x 6 columns]

# %%
output
# Out:
# 'C:\\Users\\joewa\\Work\\git\\PALS\\notebooks\\test_data\\plage_df.csv'

# %%
output = os.path.join(os.getcwd(), 'test_data', 'plage_df.csv')
plage_df.to_csv(output)

# %%
pathway_df = pals.calculate_hg_values(plage_df)
# Out:
# 2019-10-28 11:39:36.659 | INFO     | pathway_analysis:calculate_hg_values:137 - Calculating the hyper-geometric p-values
# 2019-10-28 11:39:37.162 | INFO     | pathway_analysis:calculate_hg_values:162 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                                     pw_name  \
# map05143                            African trypanosomiasis
# map00350                                Tyrosine metabolism
# map00471             D-Glutamine and D-glutamate metabolism
# map04915                         Estrogen signaling pathway
# map00642                           Ethylbenzene degradation
# ...                                                     ...
# map04070              Phosphatidylinositol signaling system
# map04111                                 Cell cycle - yeast
# map04723               Retrograde endocannabinoid signaling
# map07225  Glucocorticoid and meneralocorticoid receptor ...
# map04974                   Protein digestion and absorption
#
#           beer1/beer2 p-value  beer3/beer4 p-value  unq_pw_F  tot_ds_F  \
# map05143             0.294516             0.076869         7         3
# map00350             0.149899             0.030247        53        42
# map00471             0.149042             0.078429         7         4
# map04915             0.067900             0.021456         7         1
# map00642             0.070062             0.233091        14        10
# ...                       ...                  ...       ...       ...
# map04070             0.501927             0.019880         9         2
# map04111             0.350552             0.071888         2         0
# map04723             0.098977             0.014790        15         7
# map07225             0.071042             0.703851         3         2
# map04974             0.053616             0.027042        42        28
#
#           F_coverage            sf  exp_F  Ex_Cov  beer1/beer2 comb_p  \
# map05143       42.86  1.761629e-01   2.03    29.0            0.238185
# map00350       79.25  1.002741e-14  15.37    29.0            0.005917
# map00471       57.14  5.033628e-02   2.03    29.0            0.089751
# map04915       14.29  7.249243e-01   2.03    29.0            0.089238
# map00642       71.43  4.710541e-04   4.06    29.0            0.018073
# ...              ...           ...    ...     ...                 ...
# map04070       22.22  5.905696e-01   2.61    29.0            0.519799
# map04111        0.00  6.423378e-01   0.58    29.0            0.380240
# map04723       46.67  6.167200e-02   4.35    29.0            0.058839
# map07225       66.67  7.624094e-02   0.87    29.0            0.042700
# map04974       66.67  1.635097e-07  12.18    29.0            0.004925
#
#           beer3/beer4 comb_p
# map05143            0.056921
# map00350            0.000417
# map00471            0.043617
# map04915            0.030877
# map00642            0.086416
# ...                      ...
# map04070            0.024340
# map04111            0.086606
# map04723            0.007433
# map07225            0.596580
# map04974            0.001924
#
# [238 rows x 11 columns]
