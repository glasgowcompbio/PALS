# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib
import pickle

sys.path.append('../pals')

# %%
import pandas as pd

# %%
from pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, get_ms1_intensities, get_ms1_peaks, get_formula_df, get_experimental_design
from feature_extraction import DataSource
from pathway_analysis import PALS

# %% [markdown]
# # Load data

# %%
database_name = 'kegg'

# %% [markdown]
# Generate token by logging in to PiMP

# %%
# username = 'joewandy' # PiMP username
# password = 'enter' # PiMP password
# host = 'localhost:8000' # server address and port
# token = get_authentication_token(host, username, password)

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id = 1321 # example beer analysis

# %%
int_df_filename = os.path.join(os.getcwd(), 'test_data', 'int_df.p')
try:
    int_df = pd.read_pickle(int_df_filename)
except FileNotFoundError:
    int_df = get_ms1_intensities(token, PIMP_HOST, analysis_id)
    int_df.to_pickle(int_df_filename)

int_df.head()
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_ms1_intensities?analysis_id=1321 <Response [200]>
#          Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# row_id
# 3033929        2.235291e+09        2.000478e+09        2.170697e+09
# 3033930        4.433491e+07        4.287387e+07        4.894853e+07
# 3033931        1.723985e+09        1.764235e+09        1.585143e+09
# 3033932        6.254237e+08        6.503417e+08        5.914975e+08
# 3033933        1.075022e+09        9.293474e+08        1.092635e+09
#
#          Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# row_id
# 3033929        2.242760e+09        2.279882e+09        1.959480e+09
# 3033930        4.760448e+07        4.217280e+07        3.908452e+07
# 3033931        1.543961e+09        1.579320e+09        1.555666e+09
# 3033932        4.635929e+08        4.298382e+08        4.038747e+08
# 3033933        1.130720e+09        1.118146e+09        1.192834e+09
#
#          Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# row_id
# 3033929        2.079356e+09        2.110473e+09        2.243653e+09
# 3033930        3.825778e+07        3.770192e+07        4.087189e+07
# 3033931        1.698130e+09        1.481824e+09        1.508645e+09
# 3033932        4.292837e+08        3.708761e+08        4.778932e+08
# 3033933        1.231442e+09        1.262046e+09        1.460653e+09
#
#          Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# row_id
# 3033929        1.817065e+09        1.746443e+09        1.779827e+09
# 3033930        3.330477e+07        3.153630e+07        3.102410e+07
# 3033931        1.642510e+09        1.723919e+09        1.697806e+09
# 3033932        3.903165e+08        4.080995e+08        4.309892e+08
# 3033933        1.009838e+09        9.085111e+08        9.967176e+08

# %%
formula_df_filename = os.path.join(os.getcwd(), 'test_data', 'formula_df.p')
try:
    formula_df = pd.read_pickle(formula_df_filename)
except FileNotFoundError:
    formula_df = get_formula_df(token, PIMP_HOST, analysis_id, database_name, polarity='positive')
    formula_df.to_pickle(formula_df_filename)

formula_df.head()
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_ms1_peaks?analysis_id=1321 <Response [200]>
#         entity_id
# row_id
# 3033929    C00148
# 3036581    C00148
# 3036855    C00148
# 3038249    C00148
# 3033929    C00163

# %%
experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
try:
    experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
    with open(experimental_design_filename, 'rb') as f:
        experimental_design = pickle.load(f)
except FileNotFoundError:
    experimental_design = get_experimental_design(token, PIMP_HOST, analysis_id)
    with open(experimental_design_filename, 'wb') as f:
        pickle.dump(experimental_design, f)
        
experimental_design
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_experimental_design?analysis_id=1321 <Response [200]>
# {'comparisons': [{'case': 'beer1', 'control': 'beer2', 'name': 'beer1/beer2'},
#   {'case': 'beer3', 'control': 'beer4', 'name': 'beer3/beer4'}],
#  'groups': {'beer4': ['Beer_4_full3.mzXML',
#    'Beer_4_full2.mzXML',
#    'Beer_4_full1.mzXML'],
#   'beer3': ['Beer_3_full3.mzXML', 'Beer_3_full2.mzXML', 'Beer_3_full1.mzXML'],
#   'beer2': ['Beer_2_full3.mzXML', 'Beer_2_full1.mzXML', 'Beer_2_full2.mzXML'],
#   'beer1': ['Beer_1_full2.mzXML', 'Beer_1_full1.mzXML', 'Beer_1_full3.mzXML']}}

# %% [markdown]
# # Set-up KEGG Data Source

# %%
ds = DataSource(int_df, formula_df, experimental_design, database_name)
# Out:
# 2019-10-30 22:02:12.387 | DEBUG    | feature_extraction:__init__:28 - Loading /home/joewandy/git/PALS/pals/data/kegg.json

# %% [markdown]
# # Set-up PALS Analysis

# %%
pals = PALS(ds, min_replace=5000, num_resamples=500)

# %%
activity_df = pals.get_plage_activity_df()
activity_df
# Out:
# 2019-10-30 22:02:15.186 | DEBUG    | pathway_analysis:_change_zero_peak_ints:243 - Setting the zero intensity values in the dataframe
# 2019-10-30 22:02:15.223 | DEBUG    | pathway_analysis:_standardize_intensity_df:217 - Scaling the data across the sample: zero mean and unit variance
# 2019-10-30 22:02:15.231 | DEBUG    | pathway_analysis:_standardize_intensity_df:229 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-10-30 22:02:15.232 | DEBUG    | pathway_analysis:_standardize_intensity_df:230 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
#                                                    pw name  \
# Pathway ids
# map00051                   Fructose and mannose metabolism
# map07232      Potassium channel blocking and opening drugs
# map00010                      Glycolysis / Gluconeogenesis
# map04626                        Plant-pathogen interaction
# map04726                              Serotonergic synapse
# ...                                                    ...
# map00270                Cysteine and methionine metabolism
# map04930                         Type II diabetes mellitus
# map05204                           Chemical carcinogenesis
# map00942                          Anthocyanin biosynthesis
# map07227     Histamine H2/H3 receptor agonists/antagonists
#
#              Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# Pathway ids
# map00051              -0.236780           -0.208168           -0.247665
# map07232              -0.709094           -0.735175           -0.683822
# map00010               0.277307            0.246524            0.321167
# map04626              -0.108662            0.011175            0.203120
# map04726               0.653154            0.751441            0.586765
# ...                         ...                 ...                 ...
# map00270               0.166028            0.097307            0.161346
# map04930               0.062137            0.178450            0.009795
# map05204               0.136851            0.027640            0.168538
# map00942              -0.314692           -1.291212            0.201712
# map07227              -0.920821            0.379637           -0.873143
#
#              Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# Pathway ids
# map00051              -0.397355           -0.439309           -0.360497
# map07232               0.928083            0.854990            1.018371
# map00010               0.387165            0.399970            0.292816
# map04626              -0.808164           -0.570265            0.054773
# map04726              -0.078374           -0.100623            0.139543
# ...                         ...                 ...                 ...
# map00270              -0.434696           -0.511479           -0.474801
# map04930              -0.639208           -0.734853           -0.564963
# map05204              -0.410504           -0.443479           -0.447836
# map00942              -0.026023            0.084119           -0.967483
# map07227              -0.349875           -0.187644           -0.520062
#
#              Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# Pathway ids
# map00051               0.070748            0.043260           -0.038722
# map07232               0.038907            0.092642            0.181136
# map00010              -0.024253           -0.026879            0.073653
# map04626              -0.012979           -0.299946            0.445347
# map04726              -0.076644           -0.225899           -0.349086
# ...                         ...                 ...                 ...
# map00270              -0.236638           -0.273937           -0.159875
# map04930               0.240651            0.227063            0.134440
# map05204              -0.263377           -0.238244           -0.156844
# map00942               0.018624            0.761336            0.973530
# map07227               0.084067            0.070588           -0.224172
#
#              Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# Pathway ids
# map00051               0.625452            0.632694            0.556341
# map07232              -0.328679           -0.328679           -0.328679
# map00010              -0.632469           -0.674344           -0.640657
# map04626              -0.005134           -0.068363            1.159098
# map04726              -0.468090           -0.465122           -0.367066
# ...                         ...                 ...                 ...
# map00270               0.470283            0.574388            0.622074
# map04930               0.241470            0.400607            0.444413
# map05204               0.452790            0.528884            0.645578
# map00942              -0.057549            0.176870            0.440768
# map07227               1.100925            0.800792            0.639707
#
# [226 rows x 13 columns]

# %%
plage_df = pals.set_up_resample_plage_p_df(activity_df)
plage_df
# Out:
# 2019-10-30 22:02:17.120 | INFO     | pathway_analysis:set_up_resample_plage_p_df:69 - Calculating plage p-values with resampling
# 2019-10-30 22:02:17.123 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:73 - Comparison beer1/beer2
# 2019-10-30 22:02:17.125 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 0/500
# 2019-10-30 22:02:17.329 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 100/500
# 2019-10-30 22:02:17.449 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 200/500
# 2019-10-30 22:02:17.556 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 300/500
# 2019-10-30 22:02:17.667 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 400/500
# 2019-10-30 22:02:17.769 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:87 - Total time 0
# 2019-10-30 22:02:17.918 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:73 - Comparison beer3/beer4
# 2019-10-30 22:02:17.919 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 0/500
# ../pals/pathway_analysis.py:308: RuntimeWarning: invalid value encountered in true_divide
#   tvalues = (m1 - m2) / se_total
# 2019-10-30 22:02:18.080 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 100/500
# 2019-10-30 22:02:18.182 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 200/500
# 2019-10-30 22:02:18.289 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 300/500
# 2019-10-30 22:02:18.407 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:81 - Resampling 400/500
# 2019-10-30 22:02:18.514 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:87 - Total time 0
# 2019-10-30 22:02:18.661 | INFO     | pathway_analysis:_calculate_coverage_df:328 - Calculating dataset formula coverage
#                                                 pw_name  beer1/beer2 p-value  \
# mapids
# map00051                Fructose and mannose metabolism             0.217957
# map07232   Potassium channel blocking and opening drugs             0.044913
# map00010                   Glycolysis / Gluconeogenesis             0.857148
# map04626                     Plant-pathogen interaction             0.928035
# map04726                           Serotonergic synapse             0.191750
# ...                                                 ...                  ...
# map00270             Cysteine and methionine metabolism             0.079247
# map04930                      Type II diabetes mellitus             0.140658
# map05204                        Chemical carcinogenesis             0.120720
# map00942                       Anthocyanin biosynthesis             1.000000
# map07227  Histamine H2/H3 receptor agonists/antagonists             1.000000
#
#           beer3/beer4 p-value  unq_pw_F  tot_ds_F  F_coverage
# mapids
# map00051             0.061012        17         9       52.94
# map07232             0.082334         5         1       20.00
# map00010             0.041737        20         5       25.00
# map04626             1.000000         7         1       14.29
# map04726             0.479746        20        10       50.00
# ...                       ...       ...       ...         ...
# map00270             0.062316        52        21       40.38
# map04930             0.529109         5         2       40.00
# map05204             0.075321        78        13       16.67
# map00942             0.985992        50         1        2.00
# map07227             0.197647        10         1       10.00
#
# [226 rows x 6 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'plage_df.csv')
plage_df.to_csv(output)
output
# Out:
# '/home/joewandy/git/PALS/notebooks/test_data/plage_df.csv'

# %%
pathway_df = pals.calculate_hg_values(plage_df)
# Out:
# 2019-10-30 22:02:53.951 | INFO     | pathway_analysis:calculate_hg_values:148 - Calculating the hyper-geometric p-values
# 2019-10-30 22:02:54.130 | INFO     | pathway_analysis:calculate_hg_values:180 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                                 pw_name  beer1/beer2 p-value  \
# map00051                Fructose and mannose metabolism             0.217957
# map07232   Potassium channel blocking and opening drugs             0.044913
# map00010                   Glycolysis / Gluconeogenesis             0.857148
# map04626                     Plant-pathogen interaction             0.928035
# map04726                           Serotonergic synapse             0.191750
# ...                                                 ...                  ...
# map00270             Cysteine and methionine metabolism             0.079247
# map04930                      Type II diabetes mellitus             0.140658
# map05204                        Chemical carcinogenesis             0.120720
# map00942                       Anthocyanin biosynthesis             1.000000
# map07227  Histamine H2/H3 receptor agonists/antagonists             1.000000
#
#           beer3/beer4 p-value  unq_pw_F  tot_ds_F  F_coverage        sf  \
# map00051             0.061012        17         9       52.94  0.002127
# map07232             0.082334         5         1       20.00  0.400780
# map00010             0.041737        20         5       25.00  0.319348
# map04626             1.000000         7         1       14.29  0.562067
# map04726             0.479746        20        10       50.00  0.002384
# ...                       ...       ...       ...         ...       ...
# map00270             0.062316        52        21       40.38  0.001214
# map04930             0.529109         5         2       40.00  0.128750
# map05204             0.075321        78        13       16.67  0.871671
# map00942             0.985992        50         1        2.00  0.999964
# map07227             0.197647        10         1       10.00  0.741182
#
#           exp_F  Ex_Cov  beer1/beer2 comb_p  beer3/beer4 comb_p
# map00051   3.79   22.29            0.092650            0.018904
# map07232   1.11   22.20            0.043387            0.078997
# map00010   4.46   22.30            0.830156            0.036779
# map04626   1.56   22.29            0.928344            1.000000
# map04726   4.46   22.30            0.079561            0.273155
# ...         ...     ...                 ...                 ...
# map00270  11.59   22.29            0.023997            0.017845
# map04930   1.11   22.20            0.100534            0.440203
# map05204  17.38   22.28            0.177174            0.117635
# map00942  11.14   22.28            1.000000            0.998318
# map07227   2.23   22.30            1.000000            0.239888
#
# [226 rows x 11 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'pathway_df.csv')
pathway_df.to_csv(output)
output
# Out:
# '/home/joewandy/git/PALS/notebooks/test_data/pathway_df.csv'
