# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib
import pickle

sys.path.append('../pals')

# %%
import pandas as pd

# %%
from pimp_tools import get_pimp_API_token_from_env, PIMP_HOST, get_ms1_intensities, get_ms1_peaks, get_formula_df, get_experimental_design
from feature_extraction import DataSource
from pathway_analysis import PALS

# %% [markdown]
# # Load data

# %%
database_name = 'kegg'

# %% [markdown]
# Generate token by logging in to PiMP

# %%
# username = 'joewandy' # PiMP username
# password = 'enter' # PiMP password
# host = 'localhost:8000' # server address and port
# token = get_authentication_token(host, username, password)

# %% [markdown]
# Assume token is stored in environmental variable *PIMP_API_TOKEN*

# %%
token = get_pimp_API_token_from_env()

# %%
analysis_id = 1321 # example beer analysis

# %%
int_df_filename = os.path.join(os.getcwd(), 'test_data', 'int_df.p')
try:
    int_df = pd.read_pickle(int_df_filename)
except FileNotFoundError:
    int_df = get_ms1_intensities(token, PIMP_HOST, analysis_id)
    int_df.to_pickle(int_df_filename)

int_df.head()
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_ms1_intensities?analysis_id=1321 <Response [200]>
#          Beer_1_full1.mzXML  Beer_1_full2.mzXML  Beer_1_full3.mzXML  \
# 3033929        2.235291e+09        2.000478e+09        2.170697e+09
# 3033930        4.433491e+07        4.287387e+07        4.894853e+07
# 3033931        1.723985e+09        1.764235e+09        1.585143e+09
# 3033932        6.254237e+08        6.503417e+08        5.914975e+08
# 3033933        1.075022e+09        9.293474e+08        1.092635e+09
#
#          Beer_2_full1.mzXML  Beer_2_full2.mzXML  Beer_2_full3.mzXML  \
# 3033929        2.242760e+09        2.279882e+09        1.959480e+09
# 3033930        4.760448e+07        4.217280e+07        3.908452e+07
# 3033931        1.543961e+09        1.579320e+09        1.555666e+09
# 3033932        4.635929e+08        4.298382e+08        4.038747e+08
# 3033933        1.130720e+09        1.118146e+09        1.192834e+09
#
#          Beer_3_full1.mzXML  Beer_3_full2.mzXML  Beer_3_full3.mzXML  \
# 3033929        2.079356e+09        2.110473e+09        2.243653e+09
# 3033930        3.825778e+07        3.770192e+07        4.087189e+07
# 3033931        1.698130e+09        1.481824e+09        1.508645e+09
# 3033932        4.292837e+08        3.708761e+08        4.778932e+08
# 3033933        1.231442e+09        1.262046e+09        1.460653e+09
#
#          Beer_4_full1.mzXML  Beer_4_full2.mzXML  Beer_4_full3.mzXML
# 3033929        1.817065e+09        1.746443e+09        1.779827e+09
# 3033930        3.330477e+07        3.153630e+07        3.102410e+07
# 3033931        1.642510e+09        1.723919e+09        1.697806e+09
# 3033932        3.903165e+08        4.080995e+08        4.309892e+08
# 3033933        1.009838e+09        9.085111e+08        9.967176e+08

# %%
formula_df_filename = os.path.join(os.getcwd(), 'test_data', 'formula_df.p')
try:
    formula_df = pd.read_pickle(formula_df_filename)
except FileNotFoundError:
    formula_df = get_formula_df(token, PIMP_HOST, analysis_id, database_name, polarity='positive')
    formula_df.to_pickle(formula_df_filename)

formula_df.head()
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_ms1_peaks?analysis_id=1321 <Response [200]>
#          sec_id        mass          rt  polarity  cmpd_id unique_id   adduct  \
# row_id
# 3033929       1  116.070550  577.986827  positive        2   C5H9NO2      M+H
# 3036581    2653  157.097190  469.781817  positive        2   C5H9NO2  M+ACN+H
# 3036855    2927  157.097154  569.557760  positive        2   C5H9NO2  M+ACN+H
# 3038249    4321  114.055969  577.210902  negative        2   C5H9NO2      M-H
# 3033929       1  116.070550  577.986827  positive        3    C3H6O2  M+ACN+H
#
#          identified     rc_id    compound    db entity_id  \
# row_id
# 3033929        True  15367697   L-Proline  kegg    C00148
# 3036581        True  15390527   L-Proline  kegg    C00148
# 3036855        True  15392569   L-Proline  kegg    C00148
# 3038249        True  15402470   L-Proline  kegg    C00148
# 3033929        True  15367700  Propanoate  kegg    C00163
#
#                                                frank_annot  \
# row_id
# 3033929  {'frank_cmpd_name': 'L-Proline', 'inchikey': N...
# 3036581                                               None
# 3036855                                               None
# 3038249                                               None
# 3033929  {'frank_cmpd_name': 'L-Proline', 'inchikey': N...
#
#                             inchikey
# row_id
# 3033929  ONIBWKKTOPOVIA-BYPYZUCNSA-N
# 3036581  ONIBWKKTOPOVIA-BYPYZUCNSA-N
# 3036855  ONIBWKKTOPOVIA-BYPYZUCNSA-N
# 3038249  ONIBWKKTOPOVIA-BYPYZUCNSA-N
# 3033929  XBDQKXXYIPTUBI-UHFFFAOYSA-N

# %%
experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
try:
    experimental_design_filename = os.path.join(os.getcwd(), 'test_data', 'experimental_design.p')
    with open(experimental_design_filename, 'rb') as f:
        experimental_design = pickle.load(f)
except FileNotFoundError:
    experimental_design = get_experimental_design(token, PIMP_HOST, analysis_id)
    with open(experimental_design_filename, 'wb') as f:
        pickle.dump(experimental_design, f)
        
experimental_design
# Out:
# http://polyomics.mvls.gla.ac.uk/export/get_experimental_design?analysis_id=1321 <Response [200]>
# {'comparisons': [{'case': 'beer1', 'control': 'beer2', 'name': 'beer1/beer2'},
#   {'case': 'beer3', 'control': 'beer4', 'name': 'beer3/beer4'}],
#  'groups': {'beer4': ['Beer_4_full3.mzXML',
#    'Beer_4_full2.mzXML',
#    'Beer_4_full1.mzXML'],
#   'beer3': ['Beer_3_full3.mzXML', 'Beer_3_full2.mzXML', 'Beer_3_full1.mzXML'],
#   'beer2': ['Beer_2_full3.mzXML', 'Beer_2_full1.mzXML', 'Beer_2_full2.mzXML'],
#   'beer1': ['Beer_1_full2.mzXML', 'Beer_1_full1.mzXML', 'Beer_1_full3.mzXML']}}

# %% [markdown]
# # Set-up KEGG Data Source

# %%
ds = DataSource(int_df, formula_df, experimental_design, database_name)
# Out:
# 2019-10-30 14:37:07.384 | DEBUG    | feature_extraction:__init__:24 - Loading /home/joewandy/git/PALS/pals/data/kegg.json

# %% [markdown]
# # Set-up PALS Analysis

# %%
pals = PALS(ds, min_replace=5000, num_resamples=500)

# %%
activity_df = pals.get_plage_activity_df()
activity_df
# Out:
# 2019-10-30 14:37:10.140 | DEBUG    | pathway_analysis:_change_zero_peak_ints:239 - Setting the zero intensity values in the dataframe
# 2019-10-30 14:37:10.176 | DEBUG    | pathway_analysis:_standardize_intensity_df:212 - Scaling the data across the sample: zero mean and unit variance
# 2019-10-30 14:37:10.185 | DEBUG    | pathway_analysis:_standardize_intensity_df:225 - Mean values of the rows in the DF is [ 0.  0. -0. ... -0. -0. -0.]
# 2019-10-30 14:37:10.186 | DEBUG    | pathway_analysis:_standardize_intensity_df:226 - Variance in the rows of the DF is [1. 1. 1. ... 1. 1. 1.]
#                                   pw name  Beer_1_full1.mzXML  \
# Pathway ids
# map05012              Parkinson's disease            0.042117
# ingenza00003                KIV Synthesis            0.122320
# ingenza00001         Glycerol Utilisation           -0.133697
# map04730             Long-term depression            0.721003
# map04626       Plant-pathogen interaction           -0.108662
# ...                                   ...                 ...
# map00590      Arachidonic acid metabolism            0.664353
# map07033                  Anticonvulsants            0.494183
# map04971           Gastric acid secretion           -0.920821
# map05146                       Amoebiasis            0.245916
# map00902       Monoterpenoid biosynthesis            0.358425
#
#               Beer_1_full2.mzXML  Beer_1_full3.mzXML  Beer_2_full1.mzXML  \
# Pathway ids
# map05012               -0.069642            0.076953            0.080161
# ingenza00003           -0.111537            0.160061           -0.027054
# ingenza00001            0.026740           -0.215009            0.062752
# map04730                0.624199            0.651539           -0.503173
# map04626                0.011175            0.203120           -0.808164
# ...                          ...                 ...                 ...
# map00590                0.781839            0.637379           -0.052103
# map07033                0.227265            0.352513           -0.715258
# map04971                0.379637           -0.873143           -0.349875
# map05146                0.184697            0.209837           -0.616993
# map00902                0.306901            0.279949            0.068152
#
#               Beer_2_full2.mzXML  Beer_2_full3.mzXML  Beer_3_full1.mzXML  \
# Pathway ids
# map05012               -0.085852           -0.094464           -0.539034
# ingenza00003           -0.160889           -0.145318           -0.539882
# ingenza00001            0.132144            0.285194           -0.499739
# map04730               -0.561980           -0.550388           -0.535185
# map04626               -0.570265            0.054773           -0.012979
# ...                          ...                 ...                 ...
# map00590               -0.037756            0.099034           -0.008452
# map07033               -0.804111           -0.706295           -0.123672
# map04971               -0.187644           -0.520062            0.084067
# map05146               -0.639292           -0.633359           -0.285664
# map00902                0.110241            0.250540           -0.704944
#
#               Beer_3_full2.mzXML  Beer_3_full3.mzXML  Beer_4_full1.mzXML  \
# Pathway ids
# map05012               -0.639061           -0.342899            0.422353
# ingenza00003           -0.507523           -0.298415            0.377185
# ingenza00001           -0.508644           -0.827241            0.620363
# map04730               -0.526405           -0.423775            0.357156
# map04626               -0.299946            0.445347           -0.005134
# ...                          ...                 ...                 ...
# map00590               -0.158991           -0.301291           -0.568394
# map07033                0.016648           -0.123027            0.336287
# map04971                0.070588           -0.224172            1.100925
# map05146               -0.148425           -0.242181            0.688866
# map00902               -0.688078           -0.785789            0.230951
#
#               Beer_4_full2.mzXML  Beer_4_full3.mzXML
# Pathway ids
# map05012                0.535947            0.613423
# ingenza00003            0.537356            0.593695
# ingenza00001            0.565916            0.491222
# map04730                0.307239            0.439770
# map04626               -0.068363            1.159098
# ...                          ...                 ...
# map00590               -0.571009           -0.484609
# map07033                0.527287            0.518180
# map04971                0.800792            0.639707
# map05146                0.660072            0.576527
# map00902                0.329401            0.244252
#
# [226 rows x 13 columns]

# %%
plage_df = pals.set_up_resample_plage_p_df(activity_df)
plage_df
# Out:
# 2019-10-30 14:37:14.947 | INFO     | pathway_analysis:set_up_resample_plage_p_df:60 - Calculating plage p-values with resampling
# 2019-10-30 14:37:14.948 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:64 - Comparison beer1/beer2
# 2019-10-30 14:37:14.948 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:72 - Resampling 0/500
# 2019-10-30 14:37:37.733 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:72 - Resampling 100/500
# 2019-10-30 14:37:59.799 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:72 - Resampling 200/500
# 2019-10-30 14:38:22.203 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:72 - Resampling 300/500
# 2019-10-30 14:38:45.117 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:72 - Resampling 400/500
# 2019-10-30 14:39:52.966 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:78 - Total time 158
# 2019-10-30 14:39:53.921 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:64 - Comparison beer3/beer4
# 2019-10-30 14:39:53.922 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:72 - Resampling 0/500
# 2019-10-30 14:40:46.501 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:72 - Resampling 100/500
# 2019-10-30 14:41:26.067 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:72 - Resampling 200/500
# 2019-10-30 14:42:17.069 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:72 - Resampling 300/500
# 2019-10-30 14:43:03.757 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:72 - Resampling 400/500
# 2019-10-30 14:43:37.487 | DEBUG    | pathway_analysis:set_up_resample_plage_p_df:78 - Total time 223
# 2019-10-30 14:43:37.853 | INFO     | pathway_analysis:calculate_coverage_df:312 - Calculating dataset formula coverage
#                                   pw_name  beer1/beer2 p-value  \
# mapids
# map05012              Parkinson's disease             1.000000
# ingenza00003                KIV Synthesis             0.929011
# ingenza00001         Glycerol Utilisation             0.572844
# map04730             Long-term depression             0.055931
# map04626       Plant-pathogen interaction             0.939666
# ...                                   ...                  ...
# map00590      Arachidonic acid metabolism             0.160483
# map07033                  Anticonvulsants             0.131471
# map04971           Gastric acid secretion             1.000000
# map05146                       Amoebiasis             0.046100
# map00902       Monoterpenoid biosynthesis             0.559037
#
#               beer3/beer4 p-value  unq_pw_F  tot_ds_F  F_coverage
# mapids
# map05012                 0.088902        15         5       33.33
# ingenza00003             0.093916         6         5       83.33
# ingenza00001             0.086032         3         2       66.67
# map04730                 0.049359         7         2       28.57
# map04626                 1.000000         7         1       14.29
# ...                           ...       ...       ...         ...
# map00590                 0.251305        19        10       52.63
# map07033                 0.138919         4         2       50.00
# map04971                 0.198666        13         1        7.69
# map05146                 0.049110         8         2       25.00
# map00902                 0.033077        19         9       47.37
#
# [226 rows x 6 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'plage_df.csv')
plage_df.to_csv(output)
output
# Out:
# '/home/joewandy/git/PALS/notebooks/test_data/plage_df.csv'

# %%
pathway_df = pals.calculate_hg_values(plage_df)
# Out:
# 2019-10-30 14:43:37.900 | INFO     | pathway_analysis:calculate_hg_values:139 - Calculating the hyper-geometric p-values
# 2019-10-30 14:43:38.057 | INFO     | pathway_analysis:calculate_hg_values:169 - Calculating the combined p-values

# %%
pathway_df
# Out:
#                                   pw_name  beer1/beer2 p-value  \
# map05012              Parkinson's disease             1.000000
# ingenza00003                KIV Synthesis             0.929011
# ingenza00001         Glycerol Utilisation             0.572844
# map04730             Long-term depression             0.055931
# map04626       Plant-pathogen interaction             0.939666
# ...                                   ...                  ...
# map00590      Arachidonic acid metabolism             0.160483
# map07033                  Anticonvulsants             0.131471
# map04971           Gastric acid secretion             1.000000
# map05146                       Amoebiasis             0.046100
# map00902       Monoterpenoid biosynthesis             0.559037
#
#               beer3/beer4 p-value  unq_pw_F  tot_ds_F  F_coverage        sf  \
# map05012                 0.088902        15         5       33.33  0.123522
# ingenza00003             0.093916         6         5       83.33  0.000677
# ingenza00001             0.086032         3         2       66.67  0.036616
# map04730                 0.049359         7         2       28.57  0.254428
# map04626                 1.000000         7         1       14.29  0.561104
# ...                           ...       ...       ...         ...       ...
# map00590                 0.251305        19        10       52.63  0.001397
# map07033                 0.138919         4         2       50.00  0.076516
# map04971                 0.198666        13         1        7.69  0.853037
# map05146                 0.049110         8         2       25.00  0.322650
# map00902                 0.033077        19         9       47.37  0.005728
#
#               exp_F  Ex_Cov  beer1/beer2 comb_p  beer3/beer4 comb_p
# map05012       3.34   22.27            1.000000            0.060764
# ingenza00003   1.34   22.33            0.791461            0.027436
# ingenza00001   0.67   22.33            0.432007            0.045476
# map04730       1.56   22.29            0.045651            0.040180
# map04626       1.56   22.29            0.939668            1.000000
# ...             ...     ...                 ...                 ...
# map00590       4.23   22.26            0.059439            0.106811
# map07033       0.89   22.25            0.084108            0.089418
# map04971       2.89   22.23            1.000000            0.266273
# map05146       1.78   22.25            0.040800            0.043475
# map00902       4.23   22.26            0.363084            0.010793
#
# [226 rows x 11 columns]

# %%
output = os.path.join(os.getcwd(), 'test_data', 'pathway_df.csv')
pathway_df.to_csv(output)
output
# Out:
# '/home/joewandy/git/PALS/notebooks/test_data/pathway_df.csv'
